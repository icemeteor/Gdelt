# %%
import pandas as pd
import numpy as np
from lib.utility import get_text, ProcessPipeline

import pickle

from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor

# %% [markdown]
# # Part 1: get raw text data

# %%
### read pickle file
with open('outputs/step2_news_raw.pickle', 'rb') as handle:
    texts = pickle.load(handle)

# %%
pipeline = ProcessPipeline(texts)

textsProcessed = pipeline.run(return_str=False)
# Out:
# language is en
# language is en
# language is de
# language is bg
# Not able to detect language
# language is en
# language is vi
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is ar
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is es
# language is ko
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pl
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sl
# language is es
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is pt
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is ro
# Not able to detect language
# language is es
# Not able to detect language
# Not able to detect language
# language is es
# language is en
# language is es
# language is es
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is de
# language is ko
# language is ko
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is he
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# Not able to detect language
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is id
# language is ko
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is ar
# language is hr
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# Not able to detect language
# language is pl
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is ar
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is zh-tw
# language is en
# language is en
# language is en
# language is nl
# Not able to detect language
# language is es
# Not able to detect language
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ar
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is hu
# language is hu
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is it
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is ar
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is he
# language is ko
# language is en
# language is en
# Not able to detect language
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is bg
# language is nl
# language is el
# Not able to detect language
# language is es
# language is en
# language is en
# Not able to detect language
# language is he
# language is en
# language is de
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is pl
# language is en
# Not able to detect language
# Not able to detect language
# language is tr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# language is es
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is pt
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is tr
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is pl
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is pt
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is fr
# language is ko
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sv
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is da
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is ru
# language is zh-cn
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is de
# language is de
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is hu
# language is zh-cn
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hu
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is zh-cn
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is tr
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is zh-cn
# language is en
# language is en
# language is en
# language is en
# language is en
# language is zh-cn
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ru
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is ru
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is tr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is es
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is de
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is he
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is ar
# language is pt
# language is hu
# language is fr
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is pt
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hu
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is es
# language is pt
# language is cs
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is it
# language is en
# Not able to detect language
# language is zh-tw
# Not able to detect language
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is en
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is de
# language is es
# Not able to detect language
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is it
# language is en
# Not able to detect language
# language is bg
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is hu
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is de
# language is fr
# language is en
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is de
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is de
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is pt
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is de
# language is da
# language is en
# language is en
# language is en
# language is en
# language is de
# language is fr
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# language is en
# language is en
# Not able to detect language
# language is el
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sv
# language is en
# language is en
# language is pt
# language is ru
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is hr
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is id
# language is fr
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is es
# language is en
# language is en
# language is en
# language is fr
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# Not able to detect language
# language is en
# Not able to detect language
# language is hu
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is fr
# language is es
# language is ar
# language is ar
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is el
# language is en
# Not able to detect language
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is he
# language is en
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# Not able to detect language
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is hu
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is es
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is tr
# Not able to detect language
# Not able to detect language
# language is tr
# language is tr
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# Not able to detect language
# language is en
# language is tr
# language is en
# language is en
# language is en
# language is fi
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# Not able to detect language
# language is de
# language is sv
# language is en
# language is en
# language is en
# language is pl
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is en
# language is de
# language is fr
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is ar
# language is de
# language is en

# %%
textsProcessed[0][:10]
# Out:
# ['forum',
#  'address',
#  'one',
#  'press',
#  'issu',
#  'lifetim',
#  'global',
#  'energi',
#  'climat',
#  'chang']

# %% [markdown]
# # Part 2: Sequence Tagging

# %% [markdown]
# ## 2.1 NLTK sequence tagging

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
print(pos_tag(textsProcessed[0]))
# Out:
# [('forum', 'NN'), ('address', 'NN'), ('one', 'CD'), ('press', 'NN'), ('issu', 'NN'), ('lifetim', 'NN'), ('global', 'JJ'), ('energi', 'NN'), ('climat', 'NN'), ('chang', 'NN'), ('india’', 'NN'), ('develop', 'VB'), ('undoubtedli', 'JJ'), ('fuell', 'NN'), ('increas', 'NNS'), ('energi', 'VBP'), ('consumpt', 'JJ'), ('econom', 'NN'), ('develop', 'VB'), ('beli', 'JJ'), ('grow', 'NN'), ('problem', 'NN'), ('climat', 'NN'), ('chang', 'NN'), ('caus', 'VBP'), ('CO', 'NNP'), ('emiss', 'JJ'), ('includ', 'NN'), ('increas', 'NNS'), ('earth’', 'VBP'), ('mean', 'JJ'), ('surfac', 'NN'), ('temperatur', 'NN'), ('also', 'RB'), ('known', 'VBN'), ('global', 'JJ'), ('warm', 'NN'), ('rise', 'NN'), ('sea', 'NN'), ('level', 'NN'), ('acidif', 'NN'), ('extrem', 'VBP'), ('weather', 'NN'), ('event', 'NN'), ('increas', 'NNS'), ('global', 'JJ'), ('temperatur', 'JJ'), ('loss', 'NN'), ('polar', 'JJ'), ('ice', 'NN'), ('strongli', 'NN'), ('link', 'VBP'), ('anthropogen', 'NN'), ('activ', 'NN'), ('particularli', 'NN'), ('CO', 'NNP'), ('emiss', 'JJ'), ('consensu', 'NN'), ('among', 'IN'), ('research', 'NN'), ('link', 'NN'), ('extrem', 'IN'), ('weather', 'JJ'), ('event', 'NN'), ('forest', 'JJS'), ('fire', 'NN'), ('cyclon', 'NN'), ('drought', 'NN'), ('etc', 'FW'), ('anthropogen', 'NN'), ('caus', 'NN'), ('concern', 'NN'), ('timelin', 'NN'), ('expect', 'VBP'), ('global', 'JJ'), ('temperatur', 'NN'), ('increas', 'NNS'), ('degre', 'VBP'), ('C', 'NNP'), ('emiss', 'JJ'), ('continu', 'NN'), ('well', 'RB'), ('within', 'IN'), ('lifetim', 'JJ'), ('u', 'JJ'), ('read', 'VBN'), ('articl', 'JJ'), ('million', 'CD'), ('indian', 'JJ'), ('live', 'JJ'), ('electr', 'NN'), ('grid', 'JJ'), ('solar', 'JJ'), ('energi', 'NN'), ('potenti', 'NN'), ('transform', 'NN'), ('life', 'NN'), ('contribut', 'NN'), ('emiss', 'JJ'), ('global', 'JJ'), ('energi', 'NN'), ('forum', 'NN'), ('video', 'VBZ'), ('public', 'JJ'), ('avail', 'NN')]

# %%
ex = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %%
def tagSec(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
print(tagSec(ex))
# Out:
# [('European', 'JJ'), ('authorities', 'NNS'), ('fined', 'VBD'), ('Google', 'NNP'), ('a', 'DT'), ('record', 'NN'), ('$', '$'), ('5.1', 'CD'), ('billion', 'CD'), ('on', 'IN'), ('Wednesday', 'NNP'), ('for', 'IN'), ('abusing', 'VBG'), ('its', 'PRP$'), ('power', 'NN'), ('in', 'IN'), ('the', 'DT'), ('mobile', 'JJ'), ('phone', 'NN'), ('market', 'NN'), ('and', 'CC'), ('ordered', 'VBD'), ('the', 'DT'), ('company', 'NN'), ('to', 'TO'), ('alter', 'VB'), ('its', 'PRP$'), ('practices', 'NNS')]

# %%
### Explain of tags
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %% [markdown]
# ## 2.2 Spacy nlp: Tagging, entity recognition

# %% [markdown]
# !python -m spacy download en <br>
# Tutorial: https://spacy.io/models/

# %%
from pprint import pprint

import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = spacy.load('en')

# %%
pipeline = ProcessPipeline()
textsSummarized = list(map(pipeline.summarize,texts))

# %%
eg = textsSummarized[0]
eg
# Out:
# 'The forum addressed one of the most pressing issues of our lifetimes - global energy and climate change.\nIndia’s development will undoubtedly be fuelled by an increase in energy consumption, but this economic development belies a growing problem - climate change caused by CO2 emissions.\nThis includes increase in Earth’s mean surface temperature (also known as global warming), rise in sea level and acidification, extreme weather events, and so on.\nWhile the increase in global temperature and loss of polar ice has been strongly linked to anthropogenic activities (particularly CO2 emissions), there is no consensus among researchers about the link between extreme weather events such as forest fires, cyclones, droughts etc and anthropogenic causes.\nNow, concerning the timeline, it is expected that global temperatures will increase by over 2 degrees C by 2040 if emissions continue as before, well within our lifetimes for most of us reading this article.\nMillions of Indians live off the electricity grid and solar energy has the potential to transform their lives while not contributing to emissions.\nGlobal Energy Forum videos are now public and are available at https://gef.stanford.edu/videos\n[5] https://economictimes.indiatimes.com/news/economy/indicators/co2-emissions-cost-india-usd-210-billion-every-year-study/articleshow/65961331.cms\n[6] http://www.businesstoday.in/current/economy-politics/india-achieves-20-gw-solar-capacity-goal-4-years-ahead-deadline/story/269266.html\n[7] https://www.atkearney.com/energy/article?/a/solar-power-and-india-s-energy-future'

# %% [markdown]
# #### Token api

# %%
doc = nlp(eg)

# %%
for token in doc:
    print((token.text,token.lemma_,token.is_stop,token.pos_,token.tag_))
# Out:
# ('The', 'the', False, 'DET', 'DT')
# ('forum', 'forum', False, 'NOUN', 'NN')
# ('addressed', 'address', False, 'VERB', 'VBD')
# ('one', 'one', True, 'NUM', 'CD')
# ('of', 'of', True, 'ADP', 'IN')
# ('the', 'the', True, 'DET', 'DT')
# ('most', 'most', True, 'ADV', 'RBS')
# ('pressing', 'pressing', False, 'ADJ', 'JJ')
# ('issues', 'issue', False, 'NOUN', 'NNS')
# ('of', 'of', True, 'ADP', 'IN')
# ('our', '-PRON-', True, 'ADJ', 'PRP$')
# ('lifetimes', 'lifetime', False, 'NOUN', 'NNS')
# ('-', '-', False, 'PUNCT', 'HYPH')
# ('global', 'global', False, 'ADJ', 'JJ')
# ('energy', 'energy', False, 'NOUN', 'NN')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('climate', 'climate', False, 'NOUN', 'NN')
# ('change', 'change', False, 'NOUN', 'NN')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('India', 'india', False, 'PROPN', 'NNP')
# ('’s', '’s', False, 'PART', 'POS')
# ('development', 'development', False, 'NOUN', 'NN')
# ('will', 'will', True, 'VERB', 'MD')
# ('undoubtedly', 'undoubtedly', False, 'ADV', 'RB')
# ('be', 'be', True, 'VERB', 'VB')
# ('fuelled', 'fuel', False, 'VERB', 'VBN')
# ('by', 'by', True, 'ADP', 'IN')
# ('an', 'an', True, 'DET', 'DT')
# ('increase', 'increase', False, 'NOUN', 'NN')
# ('in', 'in', True, 'ADP', 'IN')
# ('energy', 'energy', False, 'NOUN', 'NN')
# ('consumption', 'consumption', False, 'NOUN', 'NN')
# (',', ',', False, 'PUNCT', ',')
# ('but', 'but', True, 'CCONJ', 'CC')
# ('this', 'this', True, 'DET', 'DT')
# ('economic', 'economic', False, 'ADJ', 'JJ')
# ('development', 'development', False, 'NOUN', 'NN')
# ('belies', 'belie', False, 'VERB', 'VBZ')
# ('a', 'a', True, 'DET', 'DT')
# ('growing', 'grow', False, 'VERB', 'VBG')
# ('problem', 'problem', False, 'NOUN', 'NN')
# ('-', '-', False, 'PUNCT', 'HYPH')
# ('climate', 'climate', False, 'NOUN', 'NN')
# ('change', 'change', False, 'NOUN', 'NN')
# ('caused', 'cause', False, 'VERB', 'VBN')
# ('by', 'by', True, 'ADP', 'IN')
# ('CO2', 'co2', False, 'PROPN', 'NNP')
# ('emissions', 'emission', False, 'NOUN', 'NNS')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('This', 'this', False, 'DET', 'DT')
# ('includes', 'include', False, 'VERB', 'VBZ')
# ('increase', 'increase', False, 'NOUN', 'NN')
# ('in', 'in', True, 'ADP', 'IN')
# ('Earth', 'earth', False, 'PROPN', 'NNP')
# ('’s', '’s', False, 'PART', 'POS')
# ('mean', 'mean', False, 'ADJ', 'JJ')
# ('surface', 'surface', False, 'NOUN', 'NN')
# ('temperature', 'temperature', False, 'NOUN', 'NN')
# ('(', '(', False, 'PUNCT', '-LRB-')
# ('also', 'also', True, 'ADV', 'RB')
# ('known', 'know', False, 'VERB', 'VBN')
# ('as', 'as', True, 'ADP', 'IN')
# ('global', 'global', False, 'ADJ', 'JJ')
# ('warming', 'warming', False, 'NOUN', 'NN')
# (')', ')', False, 'PUNCT', '-RRB-')
# (',', ',', False, 'PUNCT', ',')
# ('rise', 'rise', False, 'VERB', 'VB')
# ('in', 'in', True, 'ADP', 'IN')
# ('sea', 'sea', False, 'NOUN', 'NN')
# ('level', 'level', False, 'NOUN', 'NN')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('acidification', 'acidification', False, 'NOUN', 'NN')
# (',', ',', False, 'PUNCT', ',')
# ('extreme', 'extreme', False, 'ADJ', 'JJ')
# ('weather', 'weather', False, 'NOUN', 'NN')
# ('events', 'event', False, 'NOUN', 'NNS')
# (',', ',', False, 'PUNCT', ',')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('so', 'so', True, 'ADV', 'RB')
# ('on', 'on', True, 'ADV', 'RB')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('While', 'while', False, 'ADP', 'IN')
# ('the', 'the', True, 'DET', 'DT')
# ('increase', 'increase', False, 'NOUN', 'NN')
# ('in', 'in', True, 'ADP', 'IN')
# ('global', 'global', False, 'ADJ', 'JJ')
# ('temperature', 'temperature', False, 'NOUN', 'NN')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('loss', 'loss', False, 'NOUN', 'NN')
# ('of', 'of', True, 'ADP', 'IN')
# ('polar', 'polar', False, 'ADJ', 'JJ')
# ('ice', 'ice', False, 'NOUN', 'NN')
# ('has', 'have', True, 'VERB', 'VBZ')
# ('been', 'be', True, 'VERB', 'VBN')
# ('strongly', 'strongly', False, 'ADV', 'RB')
# ('linked', 'link', False, 'VERB', 'VBN')
# ('to', 'to', True, 'ADP', 'IN')
# ('anthropogenic', 'anthropogenic', False, 'ADJ', 'JJ')
# ('activities', 'activity', False, 'NOUN', 'NNS')
# ('(', '(', False, 'PUNCT', '-LRB-')
# ('particularly', 'particularly', False, 'ADV', 'RB')
# ('CO2', 'co2', False, 'PROPN', 'NNP')
# ('emissions', 'emission', False, 'NOUN', 'NNS')
# (')', ')', False, 'PUNCT', '-RRB-')
# (',', ',', False, 'PUNCT', ',')
# ('there', 'there', True, 'ADV', 'EX')
# ('is', 'be', True, 'VERB', 'VBZ')
# ('no', 'no', True, 'DET', 'DT')
# ('consensus', 'consensus', False, 'NOUN', 'NN')
# ('among', 'among', True, 'ADP', 'IN')
# ('researchers', 'researcher', False, 'NOUN', 'NNS')
# ('about', 'about', True, 'ADP', 'IN')
# ('the', 'the', True, 'DET', 'DT')
# ('link', 'link', False, 'NOUN', 'NN')
# ('between', 'between', True, 'ADP', 'IN')
# ('extreme', 'extreme', False, 'ADJ', 'JJ')
# ('weather', 'weather', False, 'NOUN', 'NN')
# ('events', 'event', False, 'NOUN', 'NNS')
# ('such', 'such', True, 'ADJ', 'JJ')
# ('as', 'as', True, 'ADP', 'IN')
# ('forest', 'forest', False, 'NOUN', 'NN')
# ('fires', 'fire', False, 'NOUN', 'NNS')
# (',', ',', False, 'PUNCT', ',')
# ('cyclones', 'cyclone', False, 'NOUN', 'NNS')
# (',', ',', False, 'PUNCT', ',')
# ('droughts', 'drought', False, 'NOUN', 'NNS')
# ('etc', 'etc', False, 'X', 'FW')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('anthropogenic', 'anthropogenic', False, 'ADJ', 'JJ')
# ('causes', 'cause', False, 'NOUN', 'NNS')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('Now', 'now', False, 'ADV', 'RB')
# (',', ',', False, 'PUNCT', ',')
# ('concerning', 'concern', False, 'VERB', 'VBG')
# ('the', 'the', True, 'DET', 'DT')
# ('timeline', 'timeline', False, 'NOUN', 'NN')
# (',', ',', False, 'PUNCT', ',')
# ('it', '-PRON-', True, 'PRON', 'PRP')
# ('is', 'be', True, 'VERB', 'VBZ')
# ('expected', 'expect', False, 'VERB', 'VBN')
# ('that', 'that', True, 'ADP', 'IN')
# ('global', 'global', False, 'ADJ', 'JJ')
# ('temperatures', 'temperature', False, 'NOUN', 'NNS')
# ('will', 'will', True, 'VERB', 'MD')
# ('increase', 'increase', False, 'VERB', 'VB')
# ('by', 'by', True, 'ADP', 'IN')
# ('over', 'over', True, 'ADP', 'IN')
# ('2', '2', False, 'NUM', 'CD')
# ('degrees', 'degree', False, 'NOUN', 'NNS')
# ('C', 'c', False, 'NOUN', 'NN')
# ('by', 'by', True, 'ADP', 'IN')
# ('2040', '2040', False, 'NUM', 'CD')
# ('if', 'if', True, 'ADP', 'IN')
# ('emissions', 'emission', False, 'NOUN', 'NNS')
# ('continue', 'continue', False, 'VERB', 'VBP')
# ('as', 'as', True, 'ADP', 'IN')
# ('before', 'before', True, 'ADV', 'RB')
# (',', ',', False, 'PUNCT', ',')
# ('well', 'well', True, 'INTJ', 'UH')
# ('within', 'within', True, 'ADP', 'IN')
# ('our', '-PRON-', True, 'ADJ', 'PRP$')
# ('lifetimes', 'lifetime', False, 'NOUN', 'NNS')
# ('for', 'for', True, 'ADP', 'IN')
# ('most', 'most', True, 'ADJ', 'JJS')
# ('of', 'of', True, 'ADP', 'IN')
# ('us', '-PRON-', True, 'PRON', 'PRP')
# ('reading', 'read', False, 'VERB', 'VBG')
# ('this', 'this', True, 'DET', 'DT')
# ('article', 'article', False, 'NOUN', 'NN')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('Millions', 'millions', False, 'PROPN', 'NNPS')
# ('of', 'of', True, 'ADP', 'IN')
# ('Indians', 'indians', False, 'PROPN', 'NNPS')
# ('live', 'live', False, 'VERB', 'VBP')
# ('off', 'off', True, 'ADP', 'IN')
# ('the', 'the', True, 'DET', 'DT')
# ('electricity', 'electricity', False, 'NOUN', 'NN')
# ('grid', 'grid', False, 'NOUN', 'NN')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('solar', 'solar', False, 'ADJ', 'JJ')
# ('energy', 'energy', False, 'NOUN', 'NN')
# ('has', 'have', True, 'VERB', 'VBZ')
# ('the', 'the', True, 'DET', 'DT')
# ('potential', 'potential', False, 'NOUN', 'NN')
# ('to', 'to', True, 'PART', 'TO')
# ('transform', 'transform', False, 'VERB', 'VB')
# ('their', '-PRON-', True, 'ADJ', 'PRP$')
# ('lives', 'life', False, 'NOUN', 'NNS')
# ('while', 'while', True, 'ADP', 'IN')
# ('not', 'not', True, 'ADV', 'RB')
# ('contributing', 'contribute', False, 'VERB', 'VBG')
# ('to', 'to', True, 'ADP', 'IN')
# ('emissions', 'emission', False, 'NOUN', 'NNS')
# ('.', '.', False, 'PUNCT', '.')
# ('\n', '\n', False, 'SPACE', '')
# ('Global', 'global', False, 'PROPN', 'NNP')
# ('Energy', 'energy', False, 'PROPN', 'NNP')
# ('Forum', 'forum', False, 'PROPN', 'NNP')
# ('videos', 'video', False, 'NOUN', 'NNS')
# ('are', 'be', True, 'VERB', 'VBP')
# ('now', 'now', True, 'ADV', 'RB')
# ('public', 'public', False, 'ADJ', 'JJ')
# ('and', 'and', True, 'CCONJ', 'CC')
# ('are', 'be', True, 'VERB', 'VBP')
# ('available', 'available', False, 'ADJ', 'JJ')
# ('at', 'at', True, 'ADP', 'IN')
# ('https://gef.stanford.edu/videos', 'https://gef.stanford.edu/video', False, 'NOUN', 'NNS')
# ('\n', '\n', False, 'SPACE', '')
# ('[', '[', False, 'PUNCT', '-LRB-')
# ('5', '5', False, 'NUM', 'CD')
# (']', ']', False, 'PUNCT', '-RRB-')
# ('https://economictimes.indiatimes.com/news/economy/indicators/co2-emissions-cost-india-usd-210-billion-every-year-study/articleshow/65961331.cms', 'https://economictimes.indiatimes.com/news/economy/indicators/co2-emissions-cost-india-usd-210-billion-every-year-study/articleshow/65961331.cms', False, 'NOUN', 'NN')
# ('\n', '\n', False, 'SPACE', '')
# ('[', '[', False, 'PUNCT', '-LRB-')
# ('6', '6', False, 'NUM', 'CD')
# (']', ']', False, 'PUNCT', '-RRB-')
# ('http://www.businesstoday.in/current/economy-politics/india-achieves-20-gw-solar-capacity-goal-4-years-ahead-deadline/story/269266.html', 'http://www.businesstoday.in/current/economy-politics/india-achieves-20-gw-solar-capacity-goal-4-years-ahead-deadline/story/269266.html', False, 'PROPN', 'NNP')
# ('\n', '\n', False, 'SPACE', '')
# ('[', '[', False, 'PUNCT', '-LRB-')
# ('7', '7', False, 'NUM', 'CD')
# (']', ']', False, 'PUNCT', '-RRB-')
# ('https://www.atkearney.com/energy/article?/a/solar-power-and-india-s-energy-future', 'https://www.atkearney.com/energy/article?/a/solar-power-and-india-s-energy-future', False, 'NOUN', 'NN')

# %% [markdown]
# #### Entity api

# %%
for X in doc.ents:
    print((X.text, X.label_))
# Out:
# ('one', 'CARDINAL')
# ('\n', 'GPE')
# ('India', 'GPE')
# ('CO2', 'ORG')
# ('\n', 'GPE')
# ('Earth', 'LOC')
# ('\n', 'GPE')
# ('CO2', 'ORG')
# ('\n', 'GPE')
# ('Now', 'DATE')
# ('2 degrees C by', 'QUANTITY')
# ('2040', 'DATE')
# ('Millions', 'CARDINAL')
# ('Indians', 'NORP')
# ('\n', 'GPE')
# ('Global Energy Forum', 'ORG')
# ('\n', 'GPE')
# ('5', 'CARDINAL')
# ('6', 'CARDINAL')
# ('7', 'CARDINAL')

# %% [markdown]
# #### Sentence api

# %%
### Show doc sentences
sentences = [sen for sen in  doc.sents]
sentences
# Out:
# [The forum addressed one of the most pressing issues of our lifetimes - global energy and climate change.,
#  India’s development will undoubtedly be fuelled by an increase in energy consumption, but this economic development belies a growing problem - climate change caused by CO2 emissions.,
#  This includes increase in Earth,
#  ’s mean surface temperature (also known as global warming), rise in sea level and acidification, extreme weather events, and so on.,
#  While the increase in global temperature and loss of polar ice has been strongly linked to anthropogenic activities (particularly CO2 emissions), there is no consensus among researchers about the link between extreme weather events such as forest fires, cyclones, droughts etc and anthropogenic causes.,
#  Now, concerning the timeline, it is expected that global temperatures will increase by over 2 degrees C by 2040 if emissions continue as before, well within our lifetimes for most of us reading this article.,
#  Millions of Indians live off the electricity grid and solar energy has the potential to transform their lives while not contributing to emissions.,
#  Global Energy Forum videos are now public and are available at https://gef.stanford.edu/videos
#  [5] https://economictimes.indiatimes.com/news/economy/indicators/co2-emissions-cost-india-usd-210-billion-every-year-study/articleshow/65961331.cms,
#  [6] http://www.businesstoday.in/current/economy-politics/india-achieves-20-gw-solar-capacity-goal-4-years-ahead-deadline/story/269266.html
#  [7] https://www.atkearney.com/energy/article?/a/solar-power-and-india-s-energy-future]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(The, 'O', ''),
#  (forum, 'O', ''),
#  (addressed, 'O', ''),
#  (one, 'B', 'CARDINAL'),
#  (of, 'O', ''),
#  (the, 'O', ''),
#  (most, 'O', ''),
#  (pressing, 'O', ''),
#  (issues, 'O', ''),
#  (of, 'O', ''),
#  (our, 'O', ''),
#  (lifetimes, 'O', ''),
#  (-, 'O', ''),
#  (global, 'O', ''),
#  (energy, 'O', ''),
#  (and, 'O', ''),
#  (climate, 'O', ''),
#  (change, 'O', ''),
#  (., 'O', ''),
#  (
# , 'B', 'GPE'),
#  (India, 'B', 'GPE'),
#  (’s, 'O', ''),
#  (development, 'O', ''),
#  (will, 'O', ''),
#  (undoubtedly, 'O', ''),
#  (be, 'O', ''),
#  (fuelled, 'O', ''),
#  (by, 'O', ''),
#  (an, 'O', ''),
#  (increase, 'O', ''),
#  (in, 'O', ''),
#  (energy, 'O', ''),
#  (consumption, 'O', ''),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (this, 'O', ''),
#  (economic, 'O', ''),
#  (development, 'O', ''),
#  (belies, 'O', ''),
#  (a, 'O', ''),
#  (growing, 'O', ''),
#  (problem, 'O', ''),
#  (-, 'O', ''),
#  (climate, 'O', ''),
#  (change, 'O', ''),
#  (caused, 'O', ''),
#  (by, 'O', ''),
#  (CO2, 'B', 'ORG'),
#  (emissions, 'O', ''),
#  (., 'O', ''),
#  (
# , 'B', 'GPE'),
#  (This, 'O', ''),
#  (includes, 'O', ''),
#  (increase, 'O', ''),
#  (in, 'O', ''),
#  (Earth, 'B', 'LOC'),
#  (’s, 'O', ''),
#  (mean, 'O', ''),
#  (surface, 'O', ''),
#  (temperature, 'O', ''),
#  ((, 'O', ''),
#  (also, 'O', ''),
#  (known, 'O', ''),
#  (as, 'O', ''),
#  (global, 'O', ''),
#  (warming, 'O', ''),
#  (), 'O', ''),
#  (,, 'O', ''),
#  (rise, 'O', ''),
#  (in, 'O', ''),
#  (sea, 'O', ''),
#  (level, 'O', ''),
#  (and, 'O', ''),
#  (acidification, 'O', ''),
#  (,, 'O', ''),
#  (extreme, 'O', ''),
#  (weather, 'O', ''),
#  (events, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (so, 'O', ''),
#  (on, 'O', ''),
#  (., 'O', ''),
#  (
# , 'B', 'GPE'),
#  (While, 'O', ''),
#  (the, 'O', ''),
#  (increase, 'O', ''),
#  (in, 'O', ''),
#  (global, 'O', ''),
#  (temperature, 'O', ''),
#  (and, 'O', ''),
#  (loss, 'O', ''),
#  (of, 'O', ''),
#  (polar, 'O', ''),
#  (ice, 'O', ''),
#  (has, 'O', ''),
#  (been, 'O', ''),
#  (strongly, 'O', ''),
#  (linked, 'O', ''),
#  (to, 'O', ''),
#  (anthropogenic, 'O', ''),
#  (activities, 'O', ''),
#  ((, 'O', ''),
#  (particularly, 'O', ''),
#  (CO2, 'B', 'ORG'),
#  (emissions, 'O', ''),
#  (), 'O', ''),
#  (,, 'O', ''),
#  (there, 'O', ''),
#  (is, 'O', ''),
#  (no, 'O', ''),
#  (consensus, 'O', ''),
#  (among, 'O', ''),
#  (researchers, 'O', ''),
#  (about, 'O', ''),
#  (the, 'O', ''),
#  (link, 'O', ''),
#  (between, 'O', ''),
#  (extreme, 'O', ''),
#  (weather, 'O', ''),
#  (events, 'O', ''),
#  (such, 'O', ''),
#  (as, 'O', ''),
#  (forest, 'O', ''),
#  (fires, 'O', ''),
#  (,, 'O', ''),
#  (cyclones, 'O', ''),
#  (,, 'O', ''),
#  (droughts, 'O', ''),
#  (etc, 'O', ''),
#  (and, 'O', ''),
#  (anthropogenic, 'O', ''),
#  (causes, 'O', ''),
#  (., 'O', ''),
#  (
# , 'B', 'GPE'),
#  (Now, 'B', 'DATE'),
#  (,, 'O', ''),
#  (concerning, 'O', ''),
#  (the, 'O', ''),
#  (timeline, 'O', ''),
#  (,, 'O', ''),
#  (it, 'O', ''),
#  (is, 'O', ''),
#  (expected, 'O', ''),
#  (that, 'O', ''),
#  (global, 'O', ''),
#  (temperatures, 'O', ''),
#  (will, 'O', ''),
#  (increase, 'O', ''),
#  (by, 'O', ''),
#  (over, 'O', ''),
#  (2, 'B', 'QUANTITY'),
#  (degrees, 'I', 'QUANTITY'),
#  (C, 'I', 'QUANTITY'),
#  (by, 'I', 'QUANTITY'),
#  (2040, 'B', 'DATE'),
#  (if, 'O', ''),
#  (emissions, 'O', ''),
#  (continue, 'O', ''),
#  (as, 'O', ''),
#  (before, 'O', ''),
#  (,, 'O', ''),
#  (well, 'O', ''),
#  (within, 'O', ''),
#  (our, 'O', ''),
#  (lifetimes, 'O', ''),
#  (for, 'O', ''),
#  (most, 'O', ''),
#  (of, 'O', ''),
#  (us, 'O', ''),
#  (reading, 'O', ''),
#  (this, 'O', ''),
#  (article, 'O', ''),
#  (., 'O', ''),
#  (
# , 'O', ''),
#  (Millions, 'B', 'CARDINAL'),
#  (of, 'O', ''),
#  (Indians, 'B', 'NORP'),
#  (live, 'O', ''),
#  (off, 'O', ''),
#  (the, 'O', ''),
#  (electricity, 'O', ''),
#  (grid, 'O', ''),
#  (and, 'O', ''),
#  (solar, 'O', ''),
#  (energy, 'O', ''),
#  (has, 'O', ''),
#  (the, 'O', ''),
#  (potential, 'O', ''),
#  (to, 'O', ''),
#  (transform, 'O', ''),
#  (their, 'O', ''),
#  (lives, 'O', ''),
#  (while, 'O', ''),
#  (not, 'O', ''),
#  (contributing, 'O', ''),
#  (to, 'O', ''),
#  (emissions, 'O', ''),
#  (., 'O', ''),
#  (
# , 'B', 'GPE'),
#  (Global, 'B', 'ORG'),
#  (Energy, 'I', 'ORG'),
#  (Forum, 'I', 'ORG'),
#  (videos, 'O', ''),
#  (are, 'O', ''),
#  (now, 'O', ''),
#  (public, 'O', ''),
#  (and, 'O', ''),
#  (are, 'O', ''),
#  (available, 'O', ''),
#  (at, 'O', ''),
#  (https://gef.stanford.edu/videos, 'O', ''),
#  (
# , 'B', 'GPE'),
#  ([, 'O', ''),
#  (5, 'B', 'CARDINAL'),
#  (], 'O', ''),
#  (https://economictimes.indiatimes.com/news/economy/indicators/co2-emissions-cost-india-usd-210-billion-every-year-study/articleshow/65961331.cms,
#   'O',
#   ''),
#  (
# , 'O', ''),
#  ([, 'O', ''),
#  (6, 'B', 'CARDINAL'),
#  (], 'O', ''),
#  (http://www.businesstoday.in/current/economy-politics/india-achieves-20-gw-solar-capacity-goal-4-years-ahead-deadline/story/269266.html,
#   'O',
#   ''),
#  (
# , 'O', ''),
#  ([, 'O', ''),
#  (7, 'B', 'CARDINAL'),
#  (], 'O', ''),
#  (https://www.atkearney.com/energy/article?/a/solar-power-and-india-s-energy-future,
#   'O',
#   '')]

# %% [markdown]
# #### Visualization

# %%
### Display sentence relationship with entity style
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">The forum addressed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most pressing issues of our lifetimes - global energy and climate change.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div>

# %%
### Display sentence relationship
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True, options = {'distance': 100})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="582-0" class="displacy" width="1850" height="437.0" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">forum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">addressed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">pressing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">issues</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">lifetimes -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">energy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">climate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">change.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-0" stroke-width="2px" d="M70,302.0 C70,252.0 125.0,252.0 125.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-1" stroke-width="2px" d="M170,302.0 C170,252.0 225.0,252.0 225.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,304.0 L162,292.0 178,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-2" stroke-width="2px" d="M270,302.0 C270,252.0 325.0,252.0 325.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M325.0,304.0 L333.0,292.0 317.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-3" stroke-width="2px" d="M370,302.0 C370,252.0 425.0,252.0 425.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M425.0,304.0 L433.0,292.0 417.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-4" stroke-width="2px" d="M570,302.0 C570,152.0 835.0,152.0 835.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,304.0 L562,292.0 578,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-5" stroke-width="2px" d="M670,302.0 C670,252.0 725.0,252.0 725.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-582-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,304.0 L662,292.0 678,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-582-0-6" stroke-width="2px" d="M770,302.0 C770,252.0 825.0,252.0 825.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %%
### Display whole doc
displacy.render(doc,jupyter=True,style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">The forum addressed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most pressing issues of our lifetimes - global energy and climate change.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s development will undoubtedly be fuelled by an increase in energy consumption, but this economic development belies a growing problem - climate change caused by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CO2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  emissions.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# This includes increase in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ’s mean surface temperature (also known as global warming), rise in sea level and acidification, extreme weather events, and so on.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# While the increase in global temperature and loss of polar ice has been strongly linked to anthropogenic activities (particularly
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     CO2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  emissions), there is no consensus among researchers about the link between extreme weather events such as forest fires, cyclones, droughts etc and anthropogenic causes.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Now
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , concerning the timeline, it is expected that global temperatures will increase by over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2 degrees C by
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2040
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  if emissions continue as before, well within our lifetimes for most of us reading this article.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Indians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  live off the electricity grid and solar energy has the potential to transform their lives while not contributing to emissions.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Global Energy Forum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  videos are now public and are available at https://gef.stanford.edu/videos
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# [
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webk

# %% [markdown]
# # Part 3: Modulize

# %% [markdown]
# ### Target fields:
# - POS: Verb    --> Topic modeling
# - Entity: keyword extraction  --> Topic modeling + Keyword extraction
# - Sentiment: For sentiment analysis --> sentiment analysis

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = spacy.load('en')

class nlpPipeline:
    def __init__(self,texts):
        ### texts is list of strings
        self.texts = texts
        
    def run(self,workers=6):
        with ProcessPoolExecutor(max_workers=workers) as executor:
            res = executor.map(self.process, self.texts)
        return list(res)      
        
    def process(self,text):
        ### text is string type
        nlp = spacy.load('en')
        doc = nlp(text)
        featureDic = {}
        entDic = self.extract_entity(doc)
        POSDic = self.extract_POS(doc,["VERB"])
        featureDic.update(entDic)
        featureDic.update(POSDic)
        return featureDic
        
    def extract_entity(self,doc):
        entDic = {}
        for ent in doc.ents:
            if ent.text != "\n" and ent.label_ != "CARDINAL":
                if ent.text in entDic:
                    entDic[ent.text]['count'] = entDic[ent.text]['count'] + 1  
                else:
                    tmpDic = {ent.text:{"count":1,"label":ent.label_}}
                    entDic.update(tmpDic)
        return entDic
    
    def extract_POS(self,doc,targetPOSs=["VERB"]):
        POSDic = {}
        for token in doc:
            if token.is_stop == False and token.pos_ in targetPOSs :
                if token.text in POSDic:
                    POSDic[token.text]['count'] = POSDic[token.text]['count'] + 1  
                else:
                    tmpDic = {token.text:{"count":1,"POS":token.pos_}}
                    POSDic.update(tmpDic)
        return POSDic

# %%
pipeline = nlpPipeline(textsSummarized)

# %%
pipeline.process(textsSummarized[0])
# Out:
# {'India': {'count': 1, 'label': 'GPE'},
#  'CO2': {'count': 2, 'label': 'ORG'},
#  'Earth': {'count': 1, 'label': 'LOC'},
#  'Now': {'count': 1, 'label': 'DATE'},
#  '2 degrees C by': {'count': 1, 'label': 'QUANTITY'},
#  '2040': {'count': 1, 'label': 'DATE'},
#  'Indians': {'count': 1, 'label': 'NORP'},
#  'Global Energy Forum': {'count': 1, 'label': 'ORG'},
#  'addressed': {'count': 1, 'POS': 'VERB'},
#  'fuelled': {'count': 1, 'POS': 'VERB'},
#  'belies': {'count': 1, 'POS': 'VERB'},
#  'growing': {'count': 1, 'POS': 'VERB'},
#  'caused': {'count': 1, 'POS': 'VERB'},
#  'includes': {'count': 1, 'POS': 'VERB'},
#  'known': {'count': 1, 'POS': 'VERB'},
#  'rise': {'count': 1, 'POS': 'VERB'},
#  'linked': {'count': 1, 'POS': 'VERB'},
#  'concerning': {'count': 1, 'POS': 'VERB'},
#  'expected': {'count': 1, 'POS': 'VERB'},
#  'increase': {'count': 1, 'POS': 'VERB'},
#  'continue': {'count': 1, 'POS': 'VERB'},
#  'reading': {'count': 1, 'POS': 'VERB'},
#  'live': {'count': 1, 'POS': 'VERB'},
#  'transform': {'count': 1, 'POS': 'VERB'},
#  'contributing': {'count': 1, 'POS': 'VERB'}}

# %%
nlpDic = pipeline.run()

# %%
nlpDic
# Out:
# [{'India': {'count': 1, 'label': 'GPE'},
#   'CO2': {'count': 2, 'label': 'ORG'},
#   'Earth': {'count': 1, 'label': 'LOC'},
#   'Now': {'count': 1, 'label': 'DATE'},
#   '2 degrees C by': {'count': 1, 'label': 'QUANTITY'},
#   '2040': {'count': 1, 'label': 'DATE'},
#   'Indians': {'count': 1, 'label': 'NORP'},
#   'Global Energy Forum': {'count': 1, 'label': 'ORG'},
#   'addressed': {'count': 1, 'POS': 'VERB'},
#   'fuelled': {'count': 1, 'POS': 'VERB'},
#   'belies': {'count': 1, 'POS': 'VERB'},
#   'growing': {'count': 1, 'POS': 'VERB'},
#   'caused': {'count': 1, 'POS': 'VERB'},
#   'includes': {'count': 1, 'POS': 'VERB'},
#   'known': {'count': 1, 'POS': 'VERB'},
#   'rise': {'count': 1, 'POS': 'VERB'},
#   'linked': {'count': 1, 'POS': 'VERB'},
#   'concerning': {'count': 1, 'POS': 'VERB'},
#   'expected': {'count': 1, 'POS': 'VERB'},
#   'increase': {'count': 1, 'POS': 'VERB'},
#   'continue': {'count': 1, 'POS': 'VERB'},
#   'reading': {'count': 1, 'POS': 'VERB'},
#   'live': {'count': 1, 'POS': 'VERB'},
#   'transform': {'count': 1, 'POS': 'VERB'},
#   'contributing': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Това': {'count': 1, 'label': 'PERSON'},
#   '2018': {'count': 2, 'label': 'DATE'},
#   'Проблемите': {'count': 1, 'label': 'ORG'},
#   '2017': {'count': 1, 'label': 'DATE'},
#   'Ваксините': {'count': 1, 'label': 'ORG'},
#   'Гейтс.\n': {'count': 1, 'label': 'EVENT'},
#   'Надявах': {'count': 1, 'label': 'PERSON'},
#   'Испанския': {'count': 1, 'label': 'LOC'},
#   'епидемия.\n': {'count': 1, 'label': 'ORG'},
#   'Напредък': {'count': 1, 'label': 'ORG'},
#   'Алцхаймер': {'count': 1, 'label': 'PERSON'},
#   'своя': {'count': 1, 'POS': 'VERB'},
#   'например': {'count': 1, 'POS': 'VERB'},
#   'могат': {'count': 1, 'POS': 'VERB'},
#   'отколкото': {'count': 1, 'POS': 'VERB'},
#   'казва': {'count': 2, 'POS': 'VERB'},
#   'хората': {'count': 1, 'POS': 'VERB'},
#   'други': {'count': 1, 'POS': 'VERB'},
#   'костват': {'count': 1, 'POS': 'VERB'}},
#  {'Georgia Power': {'count': 1, 'label': 'ORG'},
#   '540 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   'Georgia': {'count': 1, 'label': 'GPE'},
#   'REDI': {'count': 1, 'label': 'ORG'},
#   'Wilson Mallard': {'count': 1, 'label': 'PERSON'},
#   'Renewable Development for Georgia Power': {'count': 1, 'label': 'ORG'},
#   'seeking': {'count': 1, 'POS': 'VERB'},
#   'obtain': {'count': 1, 'POS': 'VERB'},
#   'diversify': {'count': 1, 'POS': 'VERB'},
#   'built': {'count': 1, 'POS': 'VERB'},
#   'continue': {'count': 1, 'POS': 'VERB'},
#   'procure': {'count': 1, 'POS': 'VERB'},
#   'maximize': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 1, 'POS': 'VERB'}},
#  {'the year': {'count': 1, 'label': 'DATE'},
#   'Washington DC': {'count': 1, 'label': 'GPE'},
#   'current 50%': {'count': 1, 'label': 'PERCENT'},
#   'the following years': {'count': 1, 'label': 'DATE'},
#   '1.68 GW': {'count': 1, 'label': 'PERCENT'},
#   'around 20%': {'count': 1, 'label': 'PERCENT'},
#   'the Clean Energy DC Omnibus Amendment Act': {'count': 1, 'label': 'ORG'},
#   'gave': {'count': 1, 'POS': 'VERB'},
#   'gets': {'count': 1, 'POS': 'VERB'},
#   'going': {'count': 1, 'POS': 'VERB'},
#   'increase': {'count': 1, 'POS': 'VERB'},
#   'installed': {'count': 1, 'POS': 'VERB'},
#   'meet': {'count': 1, 'POS': 'VERB'},
#   'supported': {'count': 1, 'POS': 'VERB'},
#   'notes': {'count': 1, 'POS': 'VERB'},
#   'increases': {'count': 1, 'POS': 'VERB'},
#   'assist': {'count': 1, 'POS': 'VERB'},
#   'promotes': {'count': 1, 'POS': 'VERB'},
#   'related': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Stephan Hebel': {'count': 1, 'label': 'PERSON'},
#   'Bilanz': {'count': 1, 'label': 'ORG'},
#   'Hätte Merkel': {'count': 1, 'label': 'PERSON'},
#   'Politik': {'count': 1, 'label': 'PERSON'},
#   'Deutschen': {'count': 1, 'label': 'PERSON'},
#   'mit': {'count': 1, 'POS': 'VERB'},
#   'ginge': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Việt': {'count': 1, 'label': 'PERSON'},
#   '70%': {'count': 1, 'label': 'PERCENT'},
#   'Hiện': {'count': 1, 'POS': 'VERB'},
#   'khảo': {'count': 1, 'POS': 'VERB'},
#   'rào': {'count': 1, 'POS': 'VERB'},
#   'ứng': {'count': 1, 'POS': 'VERB'},
#   'công': {'count': 1, 'POS': 'VERB'}},
#  {'2019': {'count': 1, 'label': 'DATE'},
#   'Barchart Solutions': {'count': 1, 'label': 'ORG'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'delayed': {'count': 1, 'POS': 'VERB'},
#   'hosted': {'count': 1, 'POS': 'VERB'}},
#  {'North America’s': {'count': 1, 'label': 'LOC'},
#   'Distributed Solar': {'count': 1, 'label': 'ORG'},
#   'today': {'count': 1, 'label': 'DATE'},
#   'Goldman Sachs’ Alternative Energy Investing Group': {'count': 1,
#    'label': 'ORG'},
#   'ENGIE': {'count': 2, 'label': 'ORG'},
#   'Andrew Ratts': {'count': 1, 'label': 'PERSON'},
#   'Picture': {'count': 1, 'label': 'ORG'},
#   'Katherine Gillespie': {'count': 1, 'label': 'PERSON'},
#   'Matthew Bonovich': {'count': 1, 'label': 'PERSON'},
#   'AJ Gatesman': {'count': 1, 'label': 'PERSON'},
#   'Alexander Robinson': {'count': 1, 'label': 'PERSON'},
#   'announced': {'count': 1, 'POS': 'VERB'},
#   'managed': {'count': 1, 'POS': 'VERB'},
#   'advised': {'count': 1, 'POS': 'VERB'},
#   'including': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Yingli Green Energy Holding Company Limited': {'count': 2, 'label': 'ORG'},
#   '1998': {'count': 2, 'label': 'DATE'},
#   'Baoding': {'count': 2, 'label': 'PERSON'},
#   "the People's Republic of China": {'count': 2, 'label': 'GPE'},
#   'Yingli Green Energy': {'count': 4, 'label': 'ORG'},
#   'NYSE': {'count': 3, 'label': 'ORG'},
#   "Yingli Green Energy's": {'count': 6, 'label': 'ORG'},
#   'the New York Stock Exchange': {'count': 1, 'label': 'ORG'},
#   'YGE': {'count': 3, 'label': 'ORG'},
#   'Monday, December 28th 2015': {'count': 1, 'label': 'DATE'},
#   'Yingli Green Energy Holding Co Ltd': {'count': 1, 'label': 'ORG'},
#   'Tuesday, December, 19th': {'count': 1, 'label': 'DATE'},
#   '0.25': {'count': 1, 'label': 'MONEY'},
#   'the next year': {'count': 1, 'label': 'DATE'},
#   'Media': {'count': 1, 'label': 'ORG'},
#   'InfoTrie Sentiment Analysis': {'count': 1, 'label': 'ORG'},
#   'Dengyuan Song': {'count': 1, 'label': 'PERSON'},
#   'Age 60': {'count': 1, 'label': 'DATE'},
#   'founded': {'count': 2, 'POS': 'VERB'},
#   'headquartered': {'count': 2, 'POS': 'VERB'},
#   'Asked': {'count': 1, 'POS': 'VERB'},
#   'split': {'count': 1, 'POS': 'VERB'},
#   'released': {'count': 1, 'POS': 'VERB'},
#   'issued': {'count': 1, 'POS': 'VERB'},
#   'anticipate': {'count': 1, 'POS': 'VERB'},
#   'reach': {'count': 1, 'POS': 'VERB'},
#   'trended': {'count': 1, 'POS': 'VERB'},
#   'reports': {'count': 1, 'POS': 'VERB'},
#   'gave': {'count': 1, 'POS': 'VERB'},
#   'meaning': {'count': 1, 'POS': 'VERB'},
#   'includes': {'count': 1, 'POS': 'VERB'},
#   'folowing': {'count': 1, 'POS': 'VERB'},
#   'buy': {'count': 1, 'POS': 'VERB'}},
#  {'ZAP': {'count': 2, 'label': 'ORG'},
#   'OTCMKTS': {'count': 1, 'label': 'FAC'},
#   'ZAAP': {'count': 4, 'label': 'PERSON'},
#   'InfoTrie Sentiment': {'count': 1, 'label': 'PERSON'},
#   'Age 37': {'count': 1, 'label': 'DATE'},
#   'Michael Ringstad': {'count': 1, 'label': 'PERSON'},
#   'Interim': {'count': 1, 'label': 'PERSON'},
#   'Age 64': {'count': 1, 'label': 'DATE'},
#   '\nVote "Outperform': {'count': 1, 'label': 'ORG'},
#   'markets': {'count': 1, 'POS': 'VERB'},
#   'Has': {'count': 1, 'POS': 'VERB'},
#   'receiving': {'count': 1, 'POS': 'VERB'},
#   'headlines': {'count': 1, 'POS': 'VERB'},
#   'trended': {'count': 1, 'POS': 'VERB'},
#   'reports': {'count': 1, 'POS': 'VERB'},
#   'ranks': {'count': 1, 'POS': 'VERB'},
#   'traded': {'count': 1, 'POS': 'VERB'},
#   'assigned': {'count': 1, 'POS': 'VERB'},
#   'indicating': {'count': 1, 'POS': 'VERB'},
#   'believe': {'count': 2, 'POS': 'VERB'},
#   'outperform': {'count': 1, 'POS': 'VERB'},
#   'underperform': {'count': 1, 'POS': 'VERB'}},
#  {'Southern Company': {'count': 4, 'label': 'ORG'},
#   '0.32%': {'count': 1, 'label': 'PERCENT'},
#   'America': {'count': 1, 'label': 'GPE'},
#   '46,000 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   '1,500 billion cubic feet': {'count': 1, 'label': 'QUANTITY'},
#   'December 31, 2017': {'count': 1, 'label': 'DATE'},
#   'View': {'count': 1, 'label': 'ORG'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'serving': {'count': 1, 'POS': 'VERB'},
#   'cautions': {'count': 1, 'POS': 'VERB'},
#   'cause': {'count': 1, 'POS': 'VERB'},
#   'differ': {'count': 1, 'POS': 'VERB'},
#   'looking': {'count': 3, 'POS': 'VERB'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'cautioned': {'count': 1, 'POS': 'VERB'},
#   'realized': {'count': 1, 'POS': 'VERB'},
#   'disclaim': {'count': 1, 'POS': 'VERB'},
#   'update': {'count': 1, 'POS': 'VERB'},
#   'download': {'count': 1, 'POS': 'VERB'}},
#  {'ESA': {'count': 1, 'label': 'ORG'},
#   'European Space Agency': {'count': 1, 'label': 'ORG'}},
#  {'ESA': {'count': 1, 'label': 'ORG'},
#   'European Space Agency': {'count': 1, 'label': 'ORG'}},
#  {},
#  {'Southern Company': {'count': 3, 'label': 'ORG'},
#   'NYSE': {'count': 1, 'label': 'ORG'},
#   'America': {'count': 2, 'label': 'GPE'},
#   '46,000 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   '1,500 billion cubic feet': {'count': 1, 'label': 'QUANTITY'},
#   'December 31, 2017': {'count': 1, 'label': 'DATE'},
#   'forward‐looking': {'count': 2, 'POS': 'VERB'},
#   'View': {'count': 1, 'label': 'ORG'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'serving': {'count': 2, 'POS': 'VERB'},
#   'provides': {'count': 1, 'POS': 'VERB'},
#   'recognized': {'count': 1, 'POS': 'VERB'},
#   'customized': {'count': 1, 'POS': 'VERB'},
#   'cautioned': {'count': 1, 'POS': 'VERB'},
#   'realized': {'count': 1, 'POS': 'VERB'},
#   'disclaim': {'count': 1, 'POS': 'VERB'},
#   'update': {'count': 1, 'POS': 'VERB'},
#   'download': {'count': 1, 'POS': 'VERB'}},
#  {'Southern Company': {'count': 4, 'label': 'ORG'},
#   'NYSE': {'count': 1, 'label': 'ORG'},
#   'America': {'count': 2, 'label': 'GPE'},
#   '46,000 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   '1,500 billion cubic feet': {'count': 1, 'label': 'QUANTITY'},
#   'December 31, 2017': {'count': 1, 'label': 'DATE'},
#   'forward‐looking': {'count': 3, 'POS': 'VERB'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'serving': {'count': 2, 'POS': 'VERB'},
#   'provides': {'count': 1, 'POS': 'VERB'},
#   'recognized': {'count': 1, 'POS': 'VERB'},
#   'customized': {'count': 1, 'POS': 'VERB'},
#   'cautions': {'count': 1, 'POS': 'VERB'},
#   'cause': {'count': 1, 'POS': 'VERB'},
#   'differ': {'count': 1, 'POS': 'VERB'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'cautioned': {'count': 1, 'POS': 'VERB'},
#   'realized': {'count': 1, 'POS': 'VERB'},
#   'disclaim': {'count': 1, 'POS': 'VERB'},
#   'update': {'count': 1, 'POS': 'VERB'}},
#  {'Southern Company': {'count': 4, 'label': 'ORG'},
#   'NYSE': {'count': 1, 'label': 'ORG'},
#   'America': {'count': 2, 'label': 'GPE'},
#   '46,000 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   '1,500 billion cubic feet': {'count': 1, 'label': 'QUANTITY'},
#   'December 31, 2017': {'count': 1, 'label': 'DATE'},
#   'forward‐looking': {'count': 3, 'POS': 'VERB'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'serving': {'count': 2, 'POS': 'VERB'},
#   'provides': {'count': 1, 'POS': 'VERB'},
#   'recognized': {'count': 1, 'POS': 'VERB'},
#   'customized': {'count': 1, 'POS': 'VERB'},
#   'cautions': {'count': 1, 'POS': 'VERB'},
#   'cause': {'count': 1, 'POS': 'VERB'},
#   'differ': {'count': 1, 'POS': 'VERB'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'cautioned': {'count': 1, 'POS': 'VERB'},
#   'realized': {'count': 1, 'POS': 'VERB'},
#   'disclaim': {'count': 1, 'POS': 'VERB'},
#   'update': {'count': 1, 'POS': 'VERB'}},
#  {'Southern Company': {'count': 4, 'label': 'ORG'},
#   'NYSE': {'count': 1, 'label': 'ORG'},
#   'America': {'count': 2, 'label': 'GPE'},
#   '46,000 megawatts': {'count': 1, 'label': 'QUANTITY'},
#   '1,500 billion cubic feet': {'count': 1, 'label': 'QUANTITY'},
#   'December 31, 2017': {'count': 1, 'label': 'DATE'},
#   'forward‐looking': {'count': 3, 'POS': 'VERB'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'serving': {'count': 2, 'POS': 'VERB'},
#   'provides': {'count': 1, 'POS': 'VERB'},
#   'recognized': {'count': 1, 'POS': 'VERB'},
#   'customized': {'count': 1, 'POS': 'VERB'},
#   'cautions': {'count': 1, 'POS': 'VERB'},
#   'cause': {'count': 1, 'POS': 'VERB'},
#   'differ': {'count': 1, 'POS': 'VERB'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'cautioned': {'count': 1, 'POS': 'VERB'},
#   'realized': {'count': 1, 'POS': 'VERB'},
#   'disclaim': {'count': 1, 'POS': 'VERB'},
#   'update': {'count': 1, 'POS': 'VERB'}},
#  {'CLACKAMAS': {'count': 1, 'label': 'ORG'},
#   'Oregon': {'count': 3, 'label': 'GPE'},
#   'the U.S. Military': {'count': 1, 'label': 'ORG'},
#   'the Department of Defense': {'count': 1, 'label': 'ORG'},
#   'DOD': {'count': 3, 'label': 'ORG'},
#   'the Oregon National Guard': {'count': 3, 'label': 'ORG'},
#   '2011': {'count': 1, 'label': 'DATE'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'the Net Zero Program': {'count': 1, 'label': 'ORG'},
#   'National Guard': {'count': 1, 'label': 'ORG'},
#   'Kenneth Safe': {'count': 1, 'label': 'PERSON'},
#   'the Oregon Army National Guard': {'count': 2, 'label': 'ORG'},
#   '2015': {'count': 2, 'label': 'DATE'},
#   'Executive Order': {'count': 1, 'label': 'ORG'},
#   '13693': {'count': 1, 'label': 'DATE'},
#   '2025': {'count': 2, 'label': 'DATE'},
#   'around two percent': {'count': 1, 'label': 'PERCENT'},
#   'every year': {'count': 1, 'label': 'DATE'},
#   'Safe': {'count': 1, 'label': 'ORG'},
#   'Jeff Mach': {'count': 1, 'label': 'PERSON'},
#   'U.S. Environmental Protection Agency': {'count': 1, 'label': 'ORG'},
#   'Clean Power Plan': {'count': 1, 'label': 'PRODUCT'},
#   'the next decade': {'count': 1, 'label': 'DATE'},
#   '2030': {'count': 1, 'label': 'DATE'},
#   'well over 400 billion': {'count': 1, 'label': 'MONEY'},
#   'kilowatt hours': {'count': 1, 'label': 'TIME'},
#   'annually': {'count': 1, 'label': 'DATE'},
#   'U.S.': {'count': 1, 'label': 'GPE'},
#   'Congress': {'count': 1, 'label': 'ORG'},
#   '25 percent': {'count': 1, 'label': 'PERCENT'},
#   'cutting': {'count': 1, 'POS': 'VERB'},
#   'complete': {'count': 1, 'POS': 'VERB'},
#   'factored': {'count': 1, 'POS': 'VERB'},
#   'securing': {'count': 1, 'POS': 'VERB'},
#   'began': {'count': 1, 'POS': 'VERB'},
#   'chosen': {'count': 1, 'POS': 'VERB'},
#   'participate': {'count': 1, 'POS': 'VERB'},
#   'allowed': {'count': 1, 'POS': 'VERB'},
#   'reduce': {'count': 1, 'POS': 'VERB'},
#   'awarded': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 3, 'POS': 'VERB'},
#   'Having': {'count': 1, 'POS': 'VERB'},
#   'enable': {'count': 1, 'POS': 'VERB'},
#   'respond': {'count': 1, 'POS': 'VERB'},
#   'operating': {'count': 2, 'POS': 'VERB'},
#   'written': {'count': 1, 'POS': 'VERB'},
#   'specified': {'count': 1, 'POS': 'VERB'},
#   'targeted': {'count': 1, 'POS': 'VERB'},
#   'increasing': {'count': 1, 'POS': 'VERB'},
#   'compounded': {'count': 1, 'POS': 'VERB'},
#   'working': {'count': 1, 'POS': 'VERB'},
#   'factoring': {'count': 1, 'POS': 'VERB'},
#   'help': {'count': 2, 'POS': 'VERB'},
#   'gone': {'count': 1, 'POS': 'VERB'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'found': {'count': 1, 'POS': 'VERB'},
#   'play': {'count': 1, 'POS': 'VERB'},
#   'expanded': {'count': 1, 'POS': 'VERB'},
#   'generate': {'count': 1, 'POS': 'VERB'},
#   'planning': {'count': 1, 'POS': 'VERB'},
#   'having': {'count': 1, 'POS': 'VERB'},
#   'augment': {'count': 1, 'POS': 'VERB'},
#   'installing': {'count': 1, 'POS': 'VERB'},
#   'reducing': {'count': 1, 'POS': 'VERB'},
#   'meet': {'count': 1, 'POS': 'VERB'},
#   'set': {'count': 1, 'POS': 'VERB'}},
#  {'this evening': {'count': 2, 'label': 'TIME'},
#   'midnight': {'count': 2, 'label': 'TIME'},
#   'Clear': {'count': 1, 'POS': 'VERB'}},
#  {'Weltklimarates': {'count': 1, 'label': 'NORP'},
#   'Herbst': {'count': 1, 'label': 'PERSON'},
#   'Klimakrise': {'count': 1, 'label': 'LOC'},
#   'Lebensweise': {'count': 1, 'label': 'LOC'},
#   'Erdbeben': {'count': 1, 'label': 'GPE'},
#   'Klimawandel': {'count': 1, 'label': 'PERSON'},
#   'Negativen': {'count': 1, 'label': 'PRODUCT'},
#   'Erwärmung': {'count': 1, 'label': 'PERSON'},
#   'Sicht': {'count': 1, 'label': 'PERSON'},
#   'Hand': {'count': 1, 'label': 'GPE'},
#   'Zukunft': {'count': 1, 'label': 'GPE'},
#   'Kinder': {'count': 1, 'label': 'PERSON'},
#   'Wir': {'count': 1, 'POS': 'VERB'},
#   'Ausbau': {'count': 1, 'label': 'PERSON'},
#   'Energien': {'count': 2, 'label': 'PERSON'},
#   'Kosten': {'count': 1, 'label': 'ORG'},
#   'Schäden': {'count': 1, 'label': 'GPE'},
#   'Auch': {'count': 1, 'label': 'ORG'},
#   'Zyniker': {'count': 1, 'label': 'PERSON'},
#   'Gremium nur Stückwerk': {'count': 1, 'label': 'ORG'},
#   'Ende': {'count': 2, 'label': 'LOC'},
#   'Energiekonzerne Steuermilliarden': {'count': 1, 'label': 'PERSON'},
#   'Ausstiegsplan': {'count': 1, 'label': 'PERSON'},
#   'Stabilisierung': {'count': 1, 'label': 'ORG'},
#   'Klimas': {'count': 1, 'label': 'ORG'},
#   'Handeln': {'count': 1, 'label': 'ORG'},
#   'Nutzen': {'count': 1, 'label': 'GPE'},
#   'Indien': {'count': 1, 'label': 'GPE'},
#   'EU': {'count': 1, 'label': 'ORG'},
#   'Weg': {'count': 1, 'label': 'PERSON'},
#   'Europa': {'count': 1, 'label': 'LOC'},
#   'Menschen': {'count': 1, 'label': 'PERSON'},
#   'Steuersenkungen': {'count': 1, 'label': 'ORG'},
#   'Investitionen': {'count': 1, 'label': 'ORG'},
#   'Infrastruktur': {'count': 1, 'label': 'ORG'},
#   'Weihnachtsschecks – dann': {'count': 1, 'label': 'PRODUCT'},
#   'System': {'count': 1, 'label': 'PRODUCT'},
#   'Emissionshandel': {'count': 1, 'label': 'ORG'},
#   'Beispiel': {'count': 1, 'label': 'GPE'},
#   'China': {'count': 1, 'label': 'GPE'},
#   'Kalifornien': {'count': 1, 'label': 'GPE'},
#   'Volkswirtschaft': {'count': 1, 'label': 'GPE'},
#   'Welt': {'count': 1, 'label': 'PERSON'},
#   'Heimat Schweden': {'count': 1, 'label': 'PERSON'},
#   'Gipfel': {'count': 1, 'label': 'ORG'},
#   'Rekordhitze': {'count': 1, 'label': 'PERSON'},
#   'Deutschland': {'count': 1, 'label': 'ORG'},
#   'Höhe': {'count': 1, 'label': 'GPE'},
#   'der': {'count': 6, 'POS': 'VERB'},
#   'm': {'count': 1, 'POS': 'VERB'},
#   'die': {'count': 8, 'POS': 'VERB'},
#   'aufhalten': {'count': 1, 'POS': 'VERB'},
#   'müssen': {'count': 3, 'POS': 'VERB'},
#   'grundlegend': {'count': 1, 'POS': 'VERB'},
#   'als': {'count': 1, 'POS': 'VERB'},
#   'vorbereiten': {'count': 1, 'POS': 'VERB'},
#   'stoppen': {'count': 1, 'POS': 'VERB'},
#   'bei': {'count': 1, 'POS': 'VERB'},
#   'globalen': {'count': 1, 'POS': 'VERB'},
#   'wie': {'count': 2, 'POS': 'VERB'},
#   'wissen': {'count': 1, 'POS': 'VERB'},
#   'durch': {'count': 2, 'POS': 'VERB'},
#   'den': {'count': 1, 'POS': 'VERB'},
#   'jedenfalls': {'count': 1, 'POS': 'VERB'},
#   'das': {'count': 1, 'POS': 'VERB'},
#   'unseres': {'count': 1, 'POS': 'VERB'},
#   'viel': {'count': 1, 'POS': 'VERB'},
#   'auch': {'count': 1, 'POS': 'VERB'},
#   'müssten': {'count': 1, 'POS': 'VERB'},
#   'oder': {'count': 1, 'POS': 'VERB'},
#   'dann': {'count': 1, 'POS': 'VERB'},
#   'dieses': {'count': 1, 'POS': 'VERB'},
#   'etwas': {'count': 1, 'POS': 'VERB'},
#   'und': {'count': 1, 'POS': 'VERB'}},
#  {'للتعاون': {'count': 1, 'POS': 'VERB'},
#   'اكتمال': {'count': 1, 'POS': 'VERB'},
#   'بنائها': {'count': 1, 'POS': 'VERB'},
#   'على': {'count': 1, 'POS': 'VERB'},
#   'إلى': {'count': 1, 'POS': 'VERB'},
#   'في': {'count': 2, 'POS': 'VERB'},
#   'الارتقاء': {'count': 1, 'POS': 'VERB'},
#   'الصناعي': {'count': 1, 'POS': 'VERB'},
#   'والفوز': {'count': 1, 'POS': 'VERB'},
#   'الصين': {'count': 1, 'POS': 'VERB'},
#   'دولار': {'count': 1, 'POS': 'VERB'}},
#  {'Little Falls': {'count': 1, 'label': 'PERSON'},
#   '56345': {'count': 1, 'label': 'DATE'}},
#  {'US Solar Companies': {'count': 1, 'label': 'ORG'},
#   'Compete': {'count': 1, 'POS': 'VERB'},
#   'China': {'count': 3, 'label': 'GPE'},
#   'a Bit of Innovation': {'count': 1, 'label': 'GPE'},
#   'US': {'count': 5, 'label': 'GPE'},
#   'Chinese': {'count': 3, 'label': 'NORP'},
#   'American': {'count': 2, 'label': 'NORP'},
#   'some 47%': {'count': 1, 'label': 'PERCENT'},
#   'last year': {'count': 1, 'label': 'DATE'},
#   'The Solar Renewable Energy Certificates': {'count': 1, 'label': 'PRODUCT'},
#   '1,000 kilowatt-hour': {'count': 1, 'label': 'QUANTITY'},
#   'SolarWorld': {'count': 1, 'label': 'ORG'},
#   'Europe': {'count': 1, 'label': 'LOC'},
#   'European': {'count': 1, 'label': 'NORP'},
#   'Do': {'count': 1, 'POS': 'VERB'},
#   'Give': {'count': 1, 'POS': 'VERB'},
#   'undergoing': {'count': 1, 'POS': 'VERB'},
#   'mergers': {'count': 1, 'POS': 'VERB'},
#   'believing': {'count': 1, 'POS': 'VERB'},
#   'compete': {'count': 1, 'POS': 'VERB'},
#   'benefitted': {'count': 1, 'POS': 'VERB'},
#   'taken': {'count': 1, 'POS': 'VERB'},
#   'falling': {'count': 1, 'POS': 'VERB'},
#   'means': {'count': 2, 'POS': 'VERB'},
#   'reducing': {'count': 1, 'POS': 'VERB'},
#   'improving': {'count': 1, 'POS': 'VERB'},
#   'installs': {'count': 1, 'POS': 'VERB'},
#   'sell': {'count': 1, 'POS': 'VERB'},
#   'generated': {'count': 1, 'POS': 'VERB'},
#   'According': {'count': 1, 'POS': 'VERB'},
#   'pursue': {'count': 1, 'POS': 'VERB'},
#   'dumping': {'count': 3, 'POS': 'VERB'},
#   'cooperating': {'count': 1, 'POS': 'VERB'},
#   'pursuing': {'count': 1, 'POS': 'VERB'},
#   'slapping': {'count': 1, 'POS': 'VERB'},
#   'biting': {'count': 1, 'POS': 'VERB'},
#   'feed': {'count': 1, 'POS': 'VERB'},
#   'finding': {'count': 1, 'POS': 'VERB'},
#   'survive': {'count': 1, 'POS': 'VERB'},
#   'intended': {'count': 1, 'POS': 'VERB'}},
#  {'Agropecuario': {'count': 1, 'label': 'PRODUCT'},
#   '5.20%': {'count': 1, 'label': 'PERCENT'},
#   '2018': {'count': 2, 'label': 'DATE'},
#   'Agrícola': {'count': 2, 'label': 'ORG'},
#   '5.41%': {'count': 1, 'label': 'PERCENT'},
#   '4.93%': {'count': 1, 'label': 'PERCENT'},
#   'INEI': {'count': 1, 'label': 'ORG'},
#   '63.4%': {'count': 1, 'label': 'PERCENT'},
#   '36.6%': {'count': 1, 'label': 'PERCENT'},
#   'En': {'count': 1, 'label': 'ORG'},
#   'Minería': {'count': 1, 'label': 'PRODUCT'},
#   '2.52%': {'count': 1, 'label': 'PERCENT'},
#   'Minería Metálica': {'count': 1, 'label': 'PERSON'},
#   '3.73%': {'count': 1, 'label': 'PERCENT'},
#   'sumó': {'count': 1, 'POS': 'VERB'},
#   'impulsado': {'count': 1, 'POS': 'VERB'},
#   'subsectores': {'count': 1, 'POS': 'VERB'},
#   'anunció': {'count': 1, 'POS': 'VERB'}},
#  {'WSTI': {'count': 1, 'label': 'ORG'},
#   'the S&P 500': {'count': 1, 'label': 'LAW'},
#   'believe': {'count': 1, 'POS': 'VERB'},
#   'underperform': {'count': 1, 'POS': 'VERB'}},
#  {'the Global Solar Photovoltaics Wafer Market': {'count': 1, 'label': 'FAC'},
#   '2019': {'count': 1, 'label': 'DATE'},
#   'Scope': {'count': 1, 'label': 'PERSON'},
#   'International': {'count': 1, 'label': 'ORG'},
#   'Analysis': {'count': 1, 'label': 'ORG'},
#   'Application': {'count': 1, 'label': 'ORG'},
#   'provided': {'count': 1, 'POS': 'VERB'},
#   'wafer': {'count': 10, 'POS': 'VERB'},
#   'require': {'count': 1, 'POS': 'VERB'},
#   'provides': {'count': 1, 'POS': 'VERB'},
#   'enriches': {'count': 1, 'POS': 'VERB'},
#   'boundary': {'count': 1, 'POS': 'VERB'},
#   'assesses': {'count': 1, 'POS': 'VERB'},
#   'causing': {'count': 1, 'POS': 'VERB'},
#   'run': {'count': 1, 'POS': 'VERB'},
#   'supply': {'count': 1, 'POS': 'VERB'},
#   'promote': {'count': 1, 'POS': 'VERB'},
#   'influencing': {'count': 1, 'POS': 'VERB'},
#   'believes': {'count': 1, 'POS': 'VERB'}},
#  {'each year': {'count': 1, 'label': 'DATE'},
#   'the Perils of Perception': {'count': 1, 'label': 'ORG'},
#   'Australians': {'count': 3, 'label': 'NORP'},
#   'Australia': {'count': 4, 'label': 'GPE'},
#   'Muslim': {'count': 1, 'label': 'NORP'},
#   '21 per cent': {'count': 1, 'label': 'MONEY'},
#   '2020': {'count': 1, 'label': 'DATE'},
#   'Muslims': {'count': 2, 'label': 'NORP'},
#   '2016': {'count': 1, 'label': 'DATE'},
#   '10 per cent': {'count': 1, 'label': 'MONEY'},
#   'year': {'count': 1, 'label': 'DATE'},
#   'Perils of Perception': {'count': 1, 'label': 'ORG'},
#   '37 per cent': {'count': 1, 'label': 'MONEY'},
#   '65 years or older': {'count': 1, 'label': 'DATE'},
#   '2050': {'count': 1, 'label': 'DATE'},
#   '51 per cent': {'count': 1, 'label': 'MONEY'},
#   'the World Bank': {'count': 1, 'label': 'ORG'},
#   '30th': {'count': 1, 'label': 'ORDINAL'},
#   'World Bank': {'count': 1, 'label': 'ORG'},
#   'US': {'count': 1, 'label': 'GPE'},
#   'exposed': {'count': 1, 'POS': 'VERB'},
#   'explores': {'count': 1, 'POS': 'VERB'},
#   'showed': {'count': 1, 'POS': 'VERB'},
#   'overestimate': {'count': 1, 'POS': 'VERB'},
#   'born': {'count': 1, 'POS': 'VERB'},
#   'surge': {'count': 1, 'POS': 'VERB'},
#   'comes': {'count': 3, 'POS': 'VERB'},
#   'jumped': {'count': 1, 'POS': 'VERB'},
#   'asked': {'count': 3, 'POS': 'VERB'},
#   'consumed': {'count': 1, 'POS': 'VERB'},
#   'aged': {'count': 2, 'POS': 'VERB'},
#   'projected': {'count': 1, 'POS': 'VERB'},
#   'gauging': {'count': 1, 'POS': 'VERB'},
#   'ranks': {'count': 1, 'POS': 'VERB'},
#   'measured': {'count': 1, 'POS': 'VERB'}},
#  {'NextEra Energy': {'count': 2, 'label': 'ORG'},
#   'Florida': {'count': 4, 'label': 'GPE'},
#   'Florida Power & Light Company': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'Gulf Power Company': {'count': 1, 'label': 'ORG'},
#   'New Hampshire': {'count': 1, 'label': 'GPE'},
#   'Iowa': {'count': 1, 'label': 'GPE'},
#   'Wisconsin': {'count': 1, 'label': 'GPE'},
#   'View': {'count': 1, 'label': 'ORG'},
#   'owns': {'count': 1, 'POS': 'VERB'},
#   'serves': {'count': 2, 'POS': 'VERB'},
#   'regulated': {'count': 1, 'POS': 'VERB'},
#   'generates': {'count': 1, 'POS': 'VERB'},
#   'download': {'count': 1, 'POS': 'VERB'}},
#  {'NYSE': {'count': 1, 'label': 'ORG'},
#   'NEE': {'count': 1, 'label': 'ORG'},
#   'Juno Beach': {'count': 1, 'label': 'GPE'},
#   'Florida': {'count': 5, 'label': 'GPE'},
#   'NextEra Energy': {'count': 2, 'label': 'ORG'},
#   'Florida Power & Light Company': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'Gulf Power Company': {'count': 1, 'label': 'ORG'},
#   'New Hampshire': {'count': 1, 'label': 'GPE'},
#   'Iowa': {'count': 1, 'label': 'GPE'},
#   'Wisconsin': {'count': 1, 'label': 'GPE'},
#   'leading': {'count': 1, 'POS': 'VERB'},
#   'headquartered': {'count': 1, 'POS': 'VERB'},
#   'owns': {'count': 1, 'POS': 'VERB'},
#   'serves': {'count': 2, 'POS': 'VERB'},
#   'regulated': {'count': 1, 'POS': 'VERB'},
#   'generates': {'count': 1, 'POS': 'VERB'}},
#  {'NYSE': {'count': 1, 'label': 'ORG'},
#   'NEE': {'count': 1, 'label': 'ORG'},
#   'Juno Beach': {'count': 1, 'label': 'GPE'},
#   'Florida': {'count': 5, 'label': 'GPE'},
#   'NextEra Energy': {'count': 2, 'label': 'ORG'},
#   'Florida Power & Light Company': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'Gulf Power Company': {'count': 1, 'label': 'ORG'},
#   'New Hampshire': {'count': 1, 'label': 'GPE'},
#   'Iowa': {'count': 1, 'label': 'GPE'},
#   'Wisconsin': {'count': 1, 'label': 'GPE'},
#   'leading': {'count': 1, 'POS': 'VERB'},
#   'headquartered': {'count': 1, 'POS': 'VERB'},
#   'owns': {'count': 1, 'POS': 'VERB'},
#   'serves': {'count': 2, 'POS': 'VERB'},
#   'regulated': {'count': 1, 'POS': 'VERB'},
#   'generates': {'count': 1, 'POS': 'VERB'}},
#  {'NYSE': {'count': 1, 'label': 'ORG'},
#   'NEE': {'count': 1, 'label': 'ORG'},
#   'Juno Beach': {'count': 1, 'label': 'GPE'},
#   'Florida': {'count': 5, 'label': 'GPE'},
#   'NextEra Energy': {'count': 2, 'label': 'ORG'},
#   'Florida Power & Light Company': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'Gulf Power Company': {'count': 1, 'label': 'ORG'},
#   'New Hampshire': {'count': 1, 'label': 'GPE'},
#   'Iowa': {'count': 1, 'label': 'GPE'},
#   'Wisconsin': {'count': 1, 'label': 'GPE'},
#   'leading': {'count': 1, 'POS': 'VERB'},
#   'headquartered': {'count': 1, 'POS': 'VERB'},
#   'owns': {'count': 1, 'POS': 'VERB'},
#   'serves': {'count': 2, 'POS': 'VERB'},
#   'regulated': {'count': 1, 'POS': 'VERB'},
#   'generates': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'JUNO BEACH': {'count': 1, 'label': 'GPE'},
#   'Fla.': {'count': 1, 'label': 'GPE'},
#   'Jan. 1, 2019': {'count': 1, 'label': 'DATE'},
#   'NextEra Energy, Inc.': {'count': 1, 'label': 'ORG'},
#   'NEE': {'count': 1, 'label': 'ORG'},
#   '0.34%': {'count': 1, 'label': 'PERCENT'},
#   'Gulf Power Company': {'count': 2, 'label': 'ORG'},
#   'Southern Company SO': {'count': 1, 'label': 'ORG'},
#   '0.32%': {'count': 1, 'label': 'PERCENT'},
#   'NextEra Energy': {'count': 2, 'label': 'ORG'},
#   'Florida': {'count': 4, 'label': 'GPE'},
#   'Florida Power & Light Company': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'New Hampshire': {'count': 1, 'label': 'GPE'},
#   'Iowa': {'count': 1, 'label': 'GPE'},
#   'Wisconsin': {'count': 1, 'label': 'GPE'},
#   'completed': {'count': 1, 'POS': 'VERB'},
#   'announced': {'count': 1, 'POS': 'VERB'},
#   'owns': {'count': 1, 'POS': 'VERB'},
#   'serves': {'count': 2, 'POS': 'VERB'},
#   'regulated': {'count': 1, 'POS': 'VERB'},
#   'generates': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Last year': {'count': 1, 'label': 'DATE'},
#   'Martinez': {'count': 6, 'label': 'GPE'},
#   '1960s': {'count': 1, 'label': 'DATE'},
#   'the South Gables': {'count': 1, 'label': 'LOC'},
#   'the City Beautiful': {'count': 1, 'label': 'ORG'},
#   '2035': {'count': 1, 'label': 'DATE'},
#   'the end of the century': {'count': 1, 'label': 'DATE'},
#   'over 20,000-square feet': {'count': 1, 'label': 'QUANTITY'},
#   'LEED': {'count': 1, 'label': 'PERSON'},
#   'Leen': {'count': 1, 'label': 'ORG'},
#   'South Miami': {'count': 1, 'label': 'LOC'},
#   '2050': {'count': 1, 'label': 'DATE'},
#   'Sierra Club': {'count': 1, 'label': 'ORG'},
#   'first': {'count': 1, 'label': 'ORDINAL'},
#   'Irma': {'count': 1, 'label': 'GPE'},
#   'Jody Finver': {'count': 1, 'label': 'PERSON'},
#   'Miami-Dade': {'count': 1, 'label': 'GPE'},
#   'Solar United Neighbors': {'count': 1, 'label': 'ORG'},
#   'Gables': {'count': 1, 'label': 'PERSON'},
#   'October': {'count': 1, 'label': 'DATE'},
#   'Kawalerski': {'count': 1, 'label': 'PERSON'},
#   'Martinez’': {'count': 1, 'label': 'PERSON'},
#   'a thousand feet': {'count': 1, 'label': 'QUANTITY'},
#   'decided': {'count': 2, 'POS': 'VERB'},
#   'install': {'count': 2, 'POS': 'VERB'},
#   'advocates': {'count': 1, 'POS': 'VERB'},
#   'vowed': {'count': 1, 'POS': 'VERB'},
#   'power': {'count': 1, 'POS': 'VERB'},
#   'requires': {'count': 1, 'POS': 'VERB'},
#   'certified': {'count': 1, 'POS': 'VERB'},
#   'lists': {'count': 1, 'POS': 'VERB'},
#   'installing': {'count': 1, 'POS': 'VERB'},
#   'reported': {'count': 1, 'POS': 'VERB'},
#   'dropped': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 7, 'POS': 'VERB'},
#   'violating': {'count': 1, 'POS': 'VERB'},
#   'adopted': {'count': 1, 'POS': 'VERB'},
#   'blocking': {'count': 1, 'POS': 'VERB'},
#   'allowing': {'count': 1, 'POS': 'VERB'},
#   'consider': {'count': 1, 'POS': 'VERB'},
#   'committing': {'count': 1, 'POS': 'VERB'},
#   'encourage': {'count': 1, 'POS': 'VERB'},
#   'helped': {'count': 1, 'POS': 'VERB'},
#   'select': {'count': 1, 'POS': 'VERB'},
#   'deals': {'count': 1, 'POS': 'VERB'},
#   '’re': {'count': 2, 'POS': 'VERB'},
#   'prohibiting': {'count': 1, 'POS': 'VERB'},
#   'turned': {'count': 1, 'POS': 'VERB'},
#   'told': {'count': 1, 'POS': 'VERB'},
#   'resubmit': {'count': 1, 'POS': 'VERB'},
#   'facing': {'count': 1, 'POS': 'VERB'},
#   'suggested': {'count': 1, 'POS': 'VERB'},
#   'contact': {'count': 1, 'POS': 'VERB'},
#   'ask': {'count': 1, 'POS': 'VERB'},
#   'submitted': {'count': 1, 'POS': 'VERB'},
#   'wants': {'count': 1, 'POS': 'VERB'},
#   'heard': {'count': 1, 'POS': 'VERB'},
#   'includes': {'count': 1, 'POS': 'VERB'},
#   'required': {'count': 1, 'POS': 'VERB'},
#   'provide': {'count': 1, 'POS': 'VERB'},
#   'want': {'count': 1, 'POS': 'VERB'}},
#  {'US$ 1.5 billion': {'count': 1, 'label': 'MONEY'},
#   'Golden Gate Capital': {'count': 1, 'label': 'ORG'},
#   'Koch Equity Development LLC': {'count': 1, 'label': 'ORG'},
#   'February 21, 2017': {'count': 1, 'label': 'DATE'},
#   'Koch Equity Development': {'count': 1, 'label': 'ORG'},
#   'US$ 2 billion': {'count': 1, 'label': 'MONEY'},
#   'Infor': {'count': 1, 'label': 'GPE'},
#   'raised': {'count': 1, 'POS': 'VERB'},
#   'existing': {'count': 1, 'POS': 'VERB'},
#   'invested': {'count': 1, 'POS': 'VERB'}},
#  {'California': {'count': 1, 'label': 'GPE'},
#   'RFS': {'count': 1, 'label': 'ORG'},
#   '’s': {'count': 1, 'POS': 'VERB'},
#   'happening': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {},
#  {'New Mexico': {'count': 4, 'label': 'GPE'},
#   'Michelle Lujan': {'count': 2, 'label': 'PERSON'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Tuesday': {'count': 3, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'multibillion-dollar': {'count': 1, 'label': 'MONEY'},
#   'Santa Fe’s': {'count': 1, 'label': 'ORG'},
#   'Lujan Grisham': {'count': 1, 'label': 'PERSON'},
#   'Lugan Grisham': {'count': 1, 'label': 'PERSON'},
#   'the pre-dawn hours': {'count': 1, 'label': 'TIME'},
#   'Capitol': {'count': 1, 'label': 'FAC'},
#   'Santa Fe': {'count': 1, 'label': 'ORG'},
#   'winter': {'count': 1, 'label': 'DATE'},
#   'inaugurated': {'count': 1, 'POS': 'VERB'},
#   'urging': {'count': 1, 'POS': 'VERB'},
#   'urged': {'count': 1, 'POS': 'VERB'},
#   'reimagine': {'count': 1, 'POS': 'VERB'},
#   'expand': {'count': 1, 'POS': 'VERB'},
#   'attending': {'count': 2, 'POS': 'VERB'},
#   'filed': {'count': 1, 'POS': 'VERB'},
#   'hear': {'count': 1, 'POS': 'VERB'},
#   'planned': {'count': 1, 'POS': 'VERB'}},
#  {'Michelle Lujan': {'count': 4, 'label': 'PERSON'},
#   '32nd': {'count': 2, 'label': 'DATE'},
#   'New Mexico': {'count': 7, 'label': 'GPE'},
#   'Tuesday, January 1, 2019': {'count': 2, 'label': 'DATE'},
#   'Capitol': {'count': 3, 'label': 'FAC'},
#   'Santa Fe': {'count': 3, 'label': 'ORG'},
#   'Luis Sánchez Saturno': {'count': 1, 'label': 'PERSON'},
#   'New Mexican': {'count': 1, 'label': 'NORP'},
#   'AP': {'count': 1, 'label': 'ORG'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Democratic': {'count': 1, 'label': 'NORP'},
#   "Santa Fe's": {'count': 1, 'label': 'ORG'},
#   'Tuesday': {'count': 2, 'label': 'DATE'},
#   "Lujan Grisham's": {'count': 1, 'label': 'PERSON'},
#   'Lugan Grisham': {'count': 1, 'label': 'PERSON'},
#   'the pre-dawn hours': {'count': 1, 'label': 'TIME'},
#   'winter': {'count': 1, 'label': 'DATE'},
#   'sworn': {'count': 2, 'POS': 'VERB'},
#   'inaugurated': {'count': 1, 'POS': 'VERB'},
#   'urging': {'count': 1, 'POS': 'VERB'},
#   'attending': {'count': 2, 'POS': 'VERB'},
#   'filed': {'count': 1, 'POS': 'VERB'},
#   'hear': {'count': 1, 'POS': 'VERB'},
#   'planned': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {},
#  {'PROVIDENCE': {'count': 1, 'label': 'GPE'},
#   'Gina Raimondo': {'count': 1, 'label': 'PERSON'},
#   'second': {'count': 1, 'label': 'ORDINAL'},
#   'Tuesday': {'count': 2, 'label': 'DATE'},
#   'Rhode Island': {'count': 3, 'label': 'GPE'},
#   'the State House': {'count': 1, 'label': 'ORG'},
#   'Raimondo': {'count': 4, 'label': 'GPE'},
#   "Rhode Island's": {'count': 1, 'label': 'GPE'},
#   'the past four years': {'count': 1, 'label': 'DATE'},
#   '47': {'count': 1, 'label': 'DATE'},
#   'first': {'count': 1, 'label': 'ORDINAL'},
#   '2015': {'count': 1, 'label': 'DATE'},
#   'this last election year': {'count': 1, 'label': 'DATE'},
#   'Rhode Islanders': {'count': 1, 'label': 'NORP'},
#   'the Great Recession': {'count': 1, 'label': 'FAC'},
#   'every Rhode Islander': {'count': 1, 'label': 'LOC'},
#   'began': {'count': 1, 'POS': 'VERB'},
#   'holding': {'count': 1, 'POS': 'VERB'},
#   'renewing': {'count': 1, 'POS': 'VERB'},
#   'taking': {'count': 2, 'POS': 'VERB'},
#   'celebrated': {'count': 1, 'POS': 'VERB'},
#   'cast': {'count': 1, 'POS': 'VERB'},
#   'hailed': {'count': 1, 'POS': 'VERB'},
#   'run': {'count': 1, 'POS': 'VERB'},
#   'took': {'count': 1, 'POS': 'VERB'},
#   'climbing': {'count': 1, 'POS': 'VERB'},
#   'let': {'count': 1, 'POS': 'VERB'},
#   'commit': {'count': 1, 'POS': 'VERB'},
#   'sustaining': {'count': 1, 'POS': 'VERB'},
#   'included': {'count': 1, 'POS': 'VERB'},
#   'making': {'count': 1, 'POS': 'VERB'},
#   'position': {'count': 1, 'POS': 'VERB'},
#   'driven': {'count': 1, 'POS': 'VERB'},
#   'called': {'count': 1, 'POS': 'VERB'},
#   'ban': {'count': 1, 'POS': 'VERB'},
#   'faced': {'count': 1, 'POS': 'VERB'},
#   'mention': {'count': 1, 'POS': 'VERB'},
#   'enshrining': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {},
#  {'Nevada': {'count': 2, 'label': 'GPE'},
#   'PUC Denies Apartment': {'count': 1, 'label': 'ORG'},
#   'the Nevada Independent': {'count': 1, 'label': 'ORG'},
#   'NV Energy': {'count': 1, 'label': 'ORG'},
#   'PUC': {'count': 1, 'label': 'ORG'},
#   'According': {'count': 1, 'POS': 'VERB'},
#   'decided': {'count': 1, 'POS': 'VERB'},
#   'opening': {'count': 1, 'POS': 'VERB'},
#   'rulemaking': {'count': 1, 'POS': 'VERB'},
#   'requested': {'count': 1, 'POS': 'VERB'},
#   'supply': {'count': 1, 'POS': 'VERB'},
#   'wants': {'count': 1, 'POS': 'VERB'},
#   'provide': {'count': 1, 'POS': 'VERB'},
#   '’s': {'count': 1, 'POS': 'VERB'},
#   'deciding': {'count': 1, 'POS': 'VERB'},
#   'protect': {'count': 1, 'POS': 'VERB'},
#   'making': {'count': 1, 'POS': 'VERB'},
#   'multiplied': {'count': 1, 'POS': 'VERB'},
#   'brought': {'count': 1, 'POS': 'VERB'},
#   'bear': {'count': 1, 'POS': 'VERB'}},
#  {'the third consecutive year': {'count': 1, 'label': 'DATE'},
#   'Greater Nevada Credit Union': {'count': 1, 'label': 'ORG'},
#   'the USDA National Business and Industry Lender of the Year': {'count': 1,
#    'label': 'ORG'},
#   'the U.S. Department of Agriculture': {'count': 1, 'label': 'ORG'},
#   'April': {'count': 1, 'label': 'DATE'},
#   'GCL': {'count': 1, 'label': 'ORG'},
#   'second': {'count': 1, 'label': 'ORDINAL'},
#   'National Rural Lenders Association Public Private Partnership': {'count': 1,
#    'label': 'ORG'},
#   'Lending Forum': {'count': 1, 'label': 'ORG'},
#   'Greater Nevada Field': {'count': 1, 'label': 'LOC'},
#   'GNCU': {'count': 1, 'label': 'ORG'},
#   'named': {'count': 1, 'POS': 'VERB'},
#   'hosted': {'count': 1, 'POS': 'VERB'}},
#  {'Democratic': {'count': 2, 'label': 'NORP'},
#   'New Mexico': {'count': 7, 'label': 'GPE'},
#   'Michelle Lujan': {'count': 2, 'label': 'PERSON'},
#   'Grisham': {'count': 2, 'label': 'ORG'},
#   'Tuesday': {'count': 4, 'label': 'DATE'},
#   'Jan. 1, 2019': {'count': 2, 'label': 'DATE'},
#   'Santa Fe': {'count': 2, 'label': 'GPE'},
#   'N.M.': {'count': 2, 'label': 'GPE'},
#   'Latina': {'count': 2, 'label': 'GPE'},
#   'Michelle Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   'Republican': {'count': 1, 'label': 'NORP'},
#   'Susana Martinez': {'count': 1, 'label': 'PERSON'},
#   'Morgan Lee': {'count': 2, 'label': 'PERSON'},
#   'AP': {'count': 2, 'label': 'ORG'},
#   'Democrat': {'count': 1, 'label': 'NORP'},
#   'Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   '1 / 10 Back to Gallery\n': {'count': 1, 'label': 'ORG'},
#   '50 percent': {'count': 1, 'label': 'PERCENT'},
#   '2030': {'count': 1, 'label': 'DATE'},
#   'urges': {'count': 2, 'POS': 'VERB'},
#   'passed': {'count': 3, 'POS': 'VERB'},
#   'succeeded': {'count': 1, 'POS': 'VERB'},
#   'termed': {'count': 1, 'POS': 'VERB'},
#   'takes': {'count': 1, 'POS': 'VERB'},
#   'took': {'count': 1, 'POS': 'VERB'},
#   'announcing': {'count': 1, 'POS': 'VERB'},
#   'spend': {'count': 2, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'needed': {'count': 1, 'POS': 'VERB'},
#   'wants': {'count': 1, 'POS': 'VERB'},
#   'provide': {'count': 1, 'POS': 'VERB'},
#   'looks': {'count': 1, 'POS': 'VERB'},
#   'endorsing': {'count': 1, 'POS': 'VERB'},
#   'produce': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'New Mexico': {'count': 3, 'label': 'GPE'},
#   'Latina': {'count': 2, 'label': 'GPE'},
#   'Michelle Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   'AP': {'count': 1, 'label': 'ORG'},
#   'Tuesday': {'count': 1, 'label': 'DATE'},
#   'Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   'Democrat': {'count': 1, 'label': 'NORP'},
#   'Susana Martinez': {'count': 1, 'label': 'PERSON'},
#   'Republican': {'count': 1, 'label': 'NORP'},
#   'Democratic': {'count': 1, 'label': 'NORP'},
#   'Congress': {'count': 1, 'label': 'ORG'},
#   'November': {'count': 1, 'label': 'DATE'},
#   '50 percent': {'count': 1, 'label': 'PERCENT'},
#   '2030': {'count': 1, 'label': 'DATE'},
#   'Lorna Samraj': {'count': 1, 'label': 'PERSON'},
#   'passed': {'count': 2, 'POS': 'VERB'},
#   'took': {'count': 3, 'POS': 'VERB'},
#   'announcing': {'count': 1, 'POS': 'VERB'},
#   'spend': {'count': 1, 'POS': 'VERB'},
#   'limited': {'count': 1, 'POS': 'VERB'},
#   'following': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'wants': {'count': 2, 'POS': 'VERB'},
#   'provide': {'count': 1, 'POS': 'VERB'},
#   'looks': {'count': 1, 'POS': 'VERB'},
#   'endorsing': {'count': 1, 'POS': 'VERB'},
#   'produce': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {},
#  {'보겠다”고': {'count': 1, 'label': 'ORG'},
#   '지난해 11월': {'count': 1, 'label': 'DATE'},
#   '없다”며': {'count': 2, 'label': 'ORG'},
#   '하소연했다.앞서': {'count': 1, 'label': 'PERSON'},
#   '38번, 40번에': {'count': 1, 'label': 'DATE'},
#   '10차례': {'count': 1, 'label': 'ORDINAL'},
#   '지난해 11월부터': {'count': 1, 'label': 'DATE'},
#   '규제전환’을': {'count': 1, 'POS': 'VERB'},
#   '세계적으로': {'count': 1, 'POS': 'VERB'},
#   '뒤처지고': {'count': 1, 'POS': 'VERB'},
#   '촉구했고': {'count': 1, 'POS': 'VERB'},
#   '상당수가': {'count': 1, 'POS': 'VERB'},
#   '작심비판을': {'count': 1, 'POS': 'VERB'},
#   '것이다.지난달에도': {'count': 1, 'POS': 'VERB'},
#   '추적해': {'count': 1, 'POS': 'VERB'},
#   '체감할': {'count': 1, 'POS': 'VERB'},
#   '최저임금법': {'count': 1, 'POS': 'VERB'},
#   '행보를': {'count': 1, 'POS': 'VERB'},
#   '재계': {'count': 1, 'POS': 'VERB'},
#   '관계자는': {'count': 1, 'POS': 'VERB'},
#   '전경련': {'count': 1, 'POS': 'VERB'},
#   '촉구하고': {'count': 1, 'POS': 'VERB'},
#   '살아나야': {'count': 1, 'POS': 'VERB'},
#   '가능한': {'count': 1, 'POS': 'VERB'},
#   '토로했다.가장': {'count': 1, 'POS': 'VERB'},
#   '네거티브': {'count': 1, 'POS': 'VERB'},
#   '가운데': {'count': 1, 'POS': 'VERB'},
#   '11월부터': {'count': 1, 'POS': 'VERB'},
#   '신기술의': {'count': 1, 'POS': 'VERB'},
#   '부처별': {'count': 1, 'POS': 'VERB'},
#   '성장이': {'count': 1, 'POS': 'VERB'},
#   '규제완화가': {'count': 1, 'POS': 'VERB'},
#   '육성하는': {'count': 1, 'POS': 'VERB'},
#   '장벽을': {'count': 1, 'POS': 'VERB'}},
#  {'March': {'count': 1, 'label': 'DATE'},
#   'Representative Town Meeting': {'count': 1, 'label': 'PRODUCT'},
#   'reports': {'count': 1, 'POS': 'VERB'},
#   'gathering': {'count': 1, 'POS': 'VERB'},
#   'voted': {'count': 1, 'POS': 'VERB'}},
#  {'de California': {'count': 1, 'label': 'ORG'},
#   '1 de enero': {'count': 1, 'label': 'QUANTITY'},
#   'leyes': {'count': 1, 'POS': 'VERB'},
#   'nuevos': {'count': 2, 'POS': 'VERB'},
#   'sobre': {'count': 1, 'POS': 'VERB'},
#   'restaurantes': {'count': 1, 'POS': 'VERB'},
#   'por': {'count': 1, 'POS': 'VERB'},
#   'trabajo': {'count': 1, 'POS': 'VERB'},
#   'establecimiento': {'count': 1, 'POS': 'VERB'},
#   'límites': {'count': 1, 'POS': 'VERB'}},
#  {'보겠다”고': {'count': 1, 'label': 'ORG'},
#   '지난해 11월': {'count': 1, 'label': 'DATE'},
#   '없다”며': {'count': 2, 'label': 'ORG'},
#   '하소연했다.앞서': {'count': 1, 'label': 'PERSON'},
#   '38번, 40번에': {'count': 1, 'label': 'DATE'},
#   '10차례': {'count': 1, 'label': 'ORDINAL'},
#   '지난해 11월부터': {'count': 1, 'label': 'DATE'},
#   '규제전환’을': {'count': 1, 'POS': 'VERB'},
#   '세계적으로': {'count': 1, 'POS': 'VERB'},
#   '뒤처지고': {'count': 1, 'POS': 'VERB'},
#   '촉구했고': {'count': 1, 'POS': 'VERB'},
#   '상당수가': {'count': 1, 'POS': 'VERB'},
#   '작심비판을': {'count': 1, 'POS': 'VERB'},
#   '것이다.지난달에도': {'count': 1, 'POS': 'VERB'},
#   '추적해': {'count': 1, 'POS': 'VERB'},
#   '체감할': {'count': 1, 'POS': 'VERB'},
#   '최저임금법': {'count': 1, 'POS': 'VERB'},
#   '행보를': {'count': 1, 'POS': 'VERB'},
#   '재계': {'count': 1, 'POS': 'VERB'},
#   '관계자는': {'count': 1, 'POS': 'VERB'},
#   '전경련': {'count': 1, 'POS': 'VERB'},
#   '촉구하고': {'count': 1, 'POS': 'VERB'},
#   '살아나야': {'count': 1, 'POS': 'VERB'},
#   '가능한': {'count': 1, 'POS': 'VERB'},
#   '토로했다.가장': {'count': 1, 'POS': 'VERB'},
#   '네거티브': {'count': 1, 'POS': 'VERB'},
#   '가운데': {'count': 1, 'POS': 'VERB'},
#   '11월부터': {'count': 1, 'POS': 'VERB'},
#   '신기술의': {'count': 1, 'POS': 'VERB'},
#   '부처별': {'count': 1, 'POS': 'VERB'},
#   '성장이': {'count': 1, 'POS': 'VERB'},
#   '규제완화가': {'count': 1, 'POS': 'VERB'},
#   '육성하는': {'count': 1, 'POS': 'VERB'},
#   '장벽을': {'count': 1, 'POS': 'VERB'}},
#  {'Benin Management CORP': {'count': 1, 'label': 'ORG'},
#   'General Electric': {'count': 11, 'label': 'ORG'},
#   'NYSE': {'count': 1, 'label': 'ORG'},
#   'GE': {'count': 1, 'label': 'ORG'},
#   '18.9%': {'count': 1, 'label': 'PERCENT'},
#   'the 3rd quarter': {'count': 3, 'label': 'DATE'},
#   'the Securities and Exchange Commission': {'count': 1, 'label': 'ORG'},
#   'Mount Yale Investment Advisors': {'count': 1, 'label': 'ORG'},
#   'the 1st quarter': {'count': 2, 'label': 'DATE'},
#   'approximately $116,000': {'count': 1, 'label': 'MONEY'},
#   'Beech Hill Advisors Inc.': {'count': 1, 'label': 'ORG'},
#   'approximately $119,000': {'count': 1, 'label': 'MONEY'},
#   'Archford Capital Strategies LLC': {'count': 1, 'label': 'ORG'},
#   'approximately $121,000': {'count': 1, 'label': 'MONEY'},
#   '133,000': {'count': 1, 'label': 'MONEY'},
#   'the current fiscal year': {'count': 1, 'label': 'DATE'},
#   'Cowen': {'count': 1, 'label': 'ORG'},
#   '14.50': {'count': 1, 'label': 'MONEY'},
#   'Monday, October 1st': {'count': 1, 'label': 'DATE'},
#   'Morningstar': {'count': 1, 'label': 'ORG'},
#   '15.70': {'count': 1, 'label': 'MONEY'},
#   'Tuesday, October 2nd': {'count': 2, 'label': 'DATE'},
#   'Barclays': {'count': 1, 'label': 'ORG'},
#   '16.00': {'count': 1, 'label': 'MONEY'},
#   'JPMorgan Chase & Co.': {'count': 1, 'label': 'ORG'},
#   '10.00': {'count': 1, 'label': 'MONEY'},
#   'Thursday, October 25th': {'count': 1, 'label': 'DATE'},
#   'H Lawrence Culp': {'count': 1, 'label': 'PERSON'},
#   'Jr.': {'count': 1, 'label': 'ORG'},
#   'Thursday': {'count': 1, 'label': 'DATE'},
#   'November 1st': {'count': 1, 'label': 'DATE'},
#   'reduced': {'count': 1, 'POS': 'VERB'},
#   'according': {'count': 1, 'POS': 'VERB'},
#   'acquired': {'count': 4, 'POS': 'VERB'},
#   'valued': {'count': 4, 'POS': 'VERB'},
#   'expect': {'count': 1, 'POS': 'VERB'},
#   'post': {'count': 1, 'POS': 'VERB'},
#   'reaffirmed': {'count': 1, 'POS': 'VERB'},
#   'issued': {'count': 1, 'POS': 'VERB'},
#   'set': {'count': 3, 'POS': 'VERB'},
#   'gave': {'count': 1, 'POS': 'VERB'},
#   'reissued': {'count': 1, 'POS': 'VERB'},
#   'restated': {'count': 1, 'POS': 'VERB'},
#   'bought': {'count': 1, 'POS': 'VERB'},
#   'dated': {'count': 1, 'POS': 'VERB'}},
#  {'New Mexico': {'count': 3, 'label': 'GPE'},
#   'Michelle Lujan': {'count': 2, 'label': 'PERSON'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   "Santa Fe's": {'count': 1, 'label': 'ORG'},
#   'Tuesday': {'count': 2, 'label': 'DATE'},
#   "Lujan Grisham's": {'count': 1, 'label': 'PERSON'},
#   'Lugan Grisham': {'count': 1, 'label': 'PERSON'},
#   'the pre-dawn hours': {'count': 1, 'label': 'TIME'},
#   'Capitol': {'count': 1, 'label': 'FAC'},
#   'Santa Fe': {'count': 1, 'label': 'ORG'},
#   'winter': {'count': 1, 'label': 'DATE'},
#   'Lujan Grisham': {'count': 1, 'label': 'PERSON'},
#   'Republican': {'count': 1, 'label': 'NORP'},
#   'Susana Martinez': {'count': 1, 'label': 'PERSON'},
#   'inaugurated': {'count': 1, 'POS': 'VERB'},
#   'urging': {'count': 1, 'POS': 'VERB'},
#   'attending': {'count': 2, 'POS': 'VERB'},
#   'filed': {'count': 1, 'POS': 'VERB'},
#   'hear': {'count': 1, 'POS': 'VERB'},
#   'planned': {'count': 1, 'POS': 'VERB'},
#   'succeeds': {'count': 1, 'POS': 'VERB'},
#   'termed': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Democratic': {'count': 2, 'label': 'NORP'},
#   'New Mexico': {'count': 7, 'label': 'GPE'},
#   'Michelle Lujan': {'count': 2, 'label': 'PERSON'},
#   'Grisham': {'count': 2, 'label': 'ORG'},
#   'Tuesday': {'count': 4, 'label': 'DATE'},
#   'Jan. 1, 2019': {'count': 2, 'label': 'DATE'},
#   'Santa Fe': {'count': 2, 'label': 'GPE'},
#   'N.M.': {'count': 2, 'label': 'GPE'},
#   'Latina': {'count': 2, 'label': 'GPE'},
#   'Michelle Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   'Republican': {'count': 1, 'label': 'NORP'},
#   'Susana Martinez': {'count': 1, 'label': 'PERSON'},
#   'Morgan Lee': {'count': 2, 'label': 'PERSON'},
#   'AP': {'count': 2, 'label': 'ORG'},
#   'Democrat': {'count': 1, 'label': 'NORP'},
#   'Lujan Grisham': {'count': 2, 'label': 'PERSON'},
#   '1 / 10 Back to Gallery\n': {'count': 1, 'label': 'ORG'},
#   '50 percent': {'count': 1, 'label': 'PERCENT'},
#   '2030': {'count': 1, 'label': 'DATE'},
#   'urges': {'count': 2, 'POS': 'VERB'},
#   'passed': {'count': 3, 'POS': 'VERB'},
#   'succeeded': {'count': 1, 'POS': 'VERB'},
#   'termed': {'count': 1, 'POS': 'VERB'},
#   'takes': {'count': 1, 'POS': 'VERB'},
#   'took': {'count': 1, 'POS': 'VERB'},
#   'announcing': {'count': 1, 'POS': 'VERB'},
#   'spend': {'count': 2, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'needed': {'count': 1, 'POS': 'VERB'},
# ...
#   'last year': {'count': 1, 'label': 'DATE'},
#   'Liang': {'count': 1, 'label': 'ORG'},
#   'the United States': {'count': 1, 'label': 'GPE'},
#   'China': {'count': 1, 'label': 'GPE'},
#   'expected': {'count': 1, 'POS': 'VERB'},
#   'benefit': {'count': 1, 'POS': 'VERB'},
#   'encouraging': {'count': 1, 'POS': 'VERB'},
#   'forecast': {'count': 1, 'POS': 'VERB'},
#   'weigh': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 3, 'POS': 'VERB'},
#   'reviewed': {'count': 1, 'POS': 'VERB'},
#   'discussed': {'count': 1, 'POS': 'VERB'},
#   'develop': {'count': 1, 'POS': 'VERB'},
#   'saw': {'count': 1, 'POS': 'VERB'},
#   'launch': {'count': 1, 'POS': 'VERB'},
#   'continue': {'count': 1, 'POS': 'VERB'},
#   'feel': {'count': 1, 'POS': 'VERB'},
#   'slowed': {'count': 1, 'POS': 'VERB'}},
#  {'2045': {'count': 4, 'label': 'DATE'},
#   'SB 100': {'count': 2, 'label': 'ORG'},
#   'California': {'count': 4, 'label': 'GPE'},
#   '100%': {'count': 3, 'label': 'PERCENT'},
#   'CPUC': {'count': 1, 'label': 'ORG'},
#   'California Independent System Operator': {'count': 1, 'label': 'ORG'},
#   'Anne Gonzales': {'count': 1, 'label': 'PERSON'},
#   'Utility Dive': {'count': 4, 'label': 'PERSON'},
#   'CAISO': {'count': 3, 'label': 'ORG'},
#   "CAISO's": {'count': 1, 'label': 'ORG'},
#   'Lorenzo Kristov': {'count': 1, 'label': 'PERSON'},
#   'CEC': {'count': 1, 'label': 'ORG'},
#   'Rocky Mountain Institute (': {'count': 1, 'label': 'ORG'},
#   'RMI': {'count': 1, 'label': 'ORG'},
#   'Rothleder': {'count': 1, 'label': 'PERSON'},
#   '60%': {'count': 1, 'label': 'PERCENT'},
#   'first': {'count': 1, 'label': 'ORDINAL'},
#   'PaulosAnalysis Principal Ben Paulos': {'count': 1, 'label': 'WORK_OF_ART'},
#   'Transportation': {'count': 1, 'label': 'ORG'},
#   "SB 100's": {'count': 1, 'label': 'ORG'},
#   'Hewlett Foundation Environmental Program': {'count': 1, 'label': 'ORG'},
#   'Anand Gopal': {'count': 1, 'label': 'PERSON'},
#   'design\u200b Kristov': {'count': 1, 'label': 'ORG'},
#   'DER': {'count': 1, 'label': 'ORG'},
#   'Kristov': {'count': 1, 'label': 'ORG'},
#   'Community Choice Aggregators': {'count': 1, 'label': 'ORG'},
#   'SB 100’s': {'count': 1, 'label': 'ORG'},
#   'reaching': {'count': 1, 'POS': 'VERB'},
#   'require': {'count': 2, 'POS': 'VERB'},
#   'including': {'count': 1, 'POS': 'VERB'},
#   'reducing': {'count': 1, 'POS': 'VERB'},
#   'taken': {'count': 1, 'POS': 'VERB'},
#   'reviewed': {'count': 1, 'POS': 'VERB'},
#   'told': {'count': 4, 'POS': 'VERB'},
#   'meeting': {'count': 2, 'POS': 'VERB'},
#   'includes': {'count': 2, 'POS': 'VERB'},
#   'distributed': {'count': 2, 'POS': 'VERB'},
#   'expanding': {'count': 1, 'POS': 'VERB'},
#   'moving': {'count': 1, 'POS': 'VERB'},
#   'eliminating': {'count': 1, 'POS': 'VERB'},
#   'led': {'count': 1, 'POS': 'VERB'},
#   'integrate': {'count': 3, 'POS': 'VERB'},
#   'said': {'count': 4, 'POS': 'VERB'},
#   'considered': {'count': 1, 'POS': 'VERB'},
#   'optimize': {'count': 1, 'POS': 'VERB'},
#   'sees': {'count': 1, 'POS': 'VERB'},
#   'according': {'count': 2, 'POS': 'VERB'},
#   'Getting': {'count': 1, 'POS': 'VERB'},
#   'needed': {'count': 5, 'POS': 'VERB'},
#   'scaling': {'count': 1, 'POS': 'VERB'},
#   'pursuing': {'count': 1, 'POS': 'VERB'},
#   'focuses': {'count': 1, 'POS': 'VERB'},
#   'generated': {'count': 1, 'POS': 'VERB'},
#   'delivered': {'count': 1, 'POS': 'VERB'},
#   'existing': {'count': 1, 'POS': 'VERB'},
#   'replace': {'count': 2, 'POS': 'VERB'},
#   'generating': {'count': 1, 'POS': 'VERB'},
#   'allow': {'count': 1, 'POS': 'VERB'},
#   'missing': {'count': 1, 'POS': 'VERB'},
#   'renewables': {'count': 1, 'POS': 'VERB'},
#   'powered': {'count': 1, 'POS': 'VERB'},
#   'cooling': {'count': 1, 'POS': 'VERB'},
#   'come': {'count': 1, 'POS': 'VERB'},
#   'support': {'count': 1, 'POS': 'VERB'},
#   'align': {'count': 1, 'POS': 'VERB'},
#   'achieve': {'count': 1, 'POS': 'VERB'},
#   'partner': {'count': 1, 'POS': 'VERB'},
#   'working': {'count': 1, 'POS': 'VERB'},
#   'leave': {'count': 1, 'POS': 'VERB'},
#   'delaying': {'count': 1, 'POS': 'VERB'},
#   'reach': {'count': 1, 'POS': 'VERB'}},
#  {},
#  {'Thursday': {'count': 1, 'label': 'DATE'},
#   'Donald Trump': {'count': 1, 'label': 'PERSON'},
#   'Mexico': {'count': 1, 'label': 'GPE'},
#   'Republican': {'count': 3, 'label': 'NORP'},
#   'Senate': {'count': 1, 'label': 'ORG'},
#   'the White House': {'count': 1, 'label': 'ORG'},
#   'House': {'count': 2, 'label': 'ORG'},
#   'Democrats': {'count': 3, 'label': 'NORP'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Trump': {'count': 5, 'label': 'NORP'},
#   'Hakeem Jeffries': {'count': 1, 'label': 'PERSON'},
#   'New York': {'count': 1, 'label': 'GPE'},
#   'November': {'count': 1, 'label': 'DATE'},
#   'Rep': {'count': 1, 'label': 'ORG'},
#   'Joe Neguse': {'count': 1, 'label': 'PERSON'},
#   'Colorado': {'count': 1, 'label': 'GPE'},
#   'weekly': {'count': 1, 'label': 'DATE'},
#   'Tuesday': {'count': 1, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'White House': {'count': 1, 'label': 'ORG'},
#   'Wednesday': {'count': 1, 'label': 'DATE'},
#   'Freedom Caucus': {'count': 1, 'label': 'ORG'},
#   'the shutdown days': {'count': 1, 'label': 'DATE'},
#   'Christmas': {'count': 1, 'label': 'DATE'},
#   'Kevin McCarthy': {'count': 1, 'label': 'PERSON'},
#   'California': {'count': 1, 'label': 'GPE'},
#   'pivot': {'count': 1, 'POS': 'VERB'},
#   'fund': {'count': 1, 'POS': 'VERB'},
#   'shuttered': {'count': 1, 'POS': 'VERB'},
#   "'s": {'count': 2, 'POS': 'VERB'},
#   'setting': {'count': 1, 'POS': 'VERB'},
#   'led': {'count': 1, 'POS': 'VERB'},
#   'testing': {'count': 1, 'POS': 'VERB'},
#   'focus': {'count': 1, 'POS': 'VERB'},
#   'divided': {'count': 1, 'POS': 'VERB'},
#   'end': {'count': 1, 'POS': 'VERB'},
#   'reopen': {'count': 3, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'appear': {'count': 1, 'POS': 'VERB'},
#   'unified': {'count': 1, 'POS': 'VERB'},
#   'vote': {'count': 1, 'POS': 'VERB'},
#   'demanding': {'count': 1, 'POS': 'VERB'},
#   'build': {'count': 1, 'POS': 'VERB'},
#   'rebuked': {'count': 1, 'POS': 'VERB'},
#   'given': {'count': 1, 'POS': 'VERB'},
#   'talk': {'count': 1, 'POS': 'VERB'},
#   'came': {'count': 1, 'POS': 'VERB'},
#   'tweeted': {'count': 1, 'POS': 'VERB'},
#   'Let': {'count': 1, 'POS': 'VERB'},
#   'invited': {'count': 1, 'POS': 'VERB'},
#   'urged': {'count': 1, 'POS': 'VERB'},
#   'fight': {'count': 1, 'POS': 'VERB'},
#   'reject': {'count': 1, 'POS': 'VERB'},
#   'prevented': {'count': 1, 'POS': 'VERB'},
#   'panned': {'count': 1, 'POS': 'VERB'}},
#  {'Thursday': {'count': 1, 'label': 'DATE'},
#   'Donald Trump': {'count': 1, 'label': 'PERSON'},
#   'Mexico': {'count': 1, 'label': 'GPE'},
#   'Republican': {'count': 2, 'label': 'NORP'},
#   'Senate': {'count': 1, 'label': 'ORG'},
#   'the White House': {'count': 1, 'label': 'ORG'},
#   'House': {'count': 4, 'label': 'ORG'},
#   'Democrats’': {'count': 3, 'label': 'ORG'},
#   'first': {'count': 1, 'label': 'ORDINAL'},
#   'Trump shutdown': {'count': 1, 'label': 'ORG'},
#   'Hakeem Jeffries': {'count': 1, 'label': 'PERSON'},
#   'New York': {'count': 1, 'label': 'GPE'},
#   'Democrats': {'count': 1, 'label': 'NORP'},
#   'Trump': {'count': 2, 'label': 'PERSON'},
#   'November': {'count': 1, 'label': 'DATE'},
#   'Rep.-elect': {'count': 1, 'label': 'PERSON'},
#   'Joe Neguse': {'count': 1, 'label': 'PERSON'},
#   'Colorado': {'count': 1, 'label': 'GPE'},
#   'weekly': {'count': 1, 'label': 'DATE'},
#   'Jan. 3rd': {'count': 1, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'Kevin McCarthy': {'count': 1, 'label': 'PERSON'},
#   'California': {'count': 1, 'label': 'GPE'},
#   'pivot': {'count': 1, 'POS': 'VERB'},
#   'fund': {'count': 1, 'POS': 'VERB'},
#   'shuttered': {'count': 1, 'POS': 'VERB'},
#   '’s': {'count': 2, 'POS': 'VERB'},
#   'setting': {'count': 1, 'POS': 'VERB'},
#   'led': {'count': 1, 'POS': 'VERB'},
#   'testing': {'count': 1, 'POS': 'VERB'},
#   'focus': {'count': 1, 'POS': 'VERB'},
#   'divided': {'count': 1, 'POS': 'VERB'},
#   'end': {'count': 2, 'POS': 'VERB'},
#   'open': {'count': 1, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'appear': {'count': 1, 'POS': 'VERB'},
#   'unified': {'count': 1, 'POS': 'VERB'},
#   'vote': {'count': 1, 'POS': 'VERB'},
#   'demanding': {'count': 1, 'POS': 'VERB'},
#   'build': {'count': 1, 'POS': 'VERB'},
#   'rebuked': {'count': 1, 'POS': 'VERB'},
#   'arrives': {'count': 1, 'POS': 'VERB'},
#   'bring': {'count': 1, 'POS': 'VERB'},
#   'signaled': {'count': 1, 'POS': 'VERB'},
#   'believing': {'count': 1, 'POS': 'VERB'},
#   'impair': {'count': 1, 'POS': 'VERB'},
#   'panned': {'count': 1, 'POS': 'VERB'}},
#  {'Thursday': {'count': 1, 'label': 'DATE'},
#   'Donald Trump': {'count': 1, 'label': 'PERSON'},
#   'Mexico': {'count': 1, 'label': 'GPE'},
#   'Republican': {'count': 3, 'label': 'NORP'},
#   'Senate': {'count': 1, 'label': 'ORG'},
#   'the White House': {'count': 1, 'label': 'ORG'},
#   'House': {'count': 2, 'label': 'ORG'},
#   'Democrats': {'count': 3, 'label': 'NORP'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Trump': {'count': 4, 'label': 'NORP'},
#   'Hakeem Jeffries': {'count': 1, 'label': 'PERSON'},
#   'New York': {'count': 2, 'label': 'GPE'},
#   'November': {'count': 1, 'label': 'DATE'},
#   'Rep': {'count': 1, 'label': 'ORG'},
#   'Joe Neguse': {'count': 1, 'label': 'PERSON'},
#   'Colorado': {'count': 1, 'label': 'GPE'},
#   'weekly': {'count': 1, 'label': 'DATE'},
#   'Tuesday': {'count': 1, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'White House': {'count': 1, 'label': 'ORG'},
#   'Wednesday': {'count': 1, 'label': 'DATE'},
#   'Alexandria': {'count': 1, 'label': 'GPE'},
#   'Ocasio-Cortez': {'count': 1, 'label': 'PERSON'},
#   'Select Committee': {'count': 1, 'label': 'ORG'},
#   'the Climate Crisis': {'count': 1, 'label': 'ORG'},
#   'Kevin McCarthy': {'count': 1, 'label': 'PERSON'},
#   'California': {'count': 1, 'label': 'GPE'},
#   'pivot': {'count': 1, 'POS': 'VERB'},
#   'fund': {'count': 1, 'POS': 'VERB'},
#   'shuttered': {'count': 1, 'POS': 'VERB'},
#   "'s": {'count': 2, 'POS': 'VERB'},
#   'setting': {'count': 1, 'POS': 'VERB'},
#   'led': {'count': 1, 'POS': 'VERB'},
#   'testing': {'count': 1, 'POS': 'VERB'},
#   'focus': {'count': 1, 'POS': 'VERB'},
#   'divided': {'count': 1, 'POS': 'VERB'},
#   'end': {'count': 1, 'POS': 'VERB'},
#   'reopen': {'count': 3, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'appear': {'count': 1, 'POS': 'VERB'},
#   'unified': {'count': 1, 'POS': 'VERB'},
#   'vote': {'count': 1, 'POS': 'VERB'},
#   'demanding': {'count': 1, 'POS': 'VERB'},
#   'build': {'count': 1, 'POS': 'VERB'},
#   'rebuked': {'count': 1, 'POS': 'VERB'},
#   'given': {'count': 1, 'POS': 'VERB'},
#   'talk': {'count': 1, 'POS': 'VERB'},
#   'came': {'count': 1, 'POS': 'VERB'},
#   'tweeted': {'count': 1, 'POS': 'VERB'},
#   'Let': {'count': 1, 'POS': 'VERB'},
#   'invited': {'count': 1, 'POS': 'VERB'},
#   'create': {'count': 1, 'POS': 'VERB'},
#   'panned': {'count': 1, 'POS': 'VERB'}},
#  {'Thursday': {'count': 1, 'label': 'DATE'},
#   'Donald Trump': {'count': 1, 'label': 'PERSON'},
#   'Mexico': {'count': 1, 'label': 'GPE'},
#   'Republican': {'count': 3, 'label': 'NORP'},
#   'Senate': {'count': 1, 'label': 'ORG'},
#   'the White House': {'count': 1, 'label': 'ORG'},
#   'House': {'count': 3, 'label': 'ORG'},
#   'Democrats’': {'count': 2, 'label': 'ORG'},
#   'first': {'count': 3, 'label': 'ORDINAL'},
#   'Trump': {'count': 4, 'label': 'NORP'},
#   'Hakeem Jeffries': {'count': 1, 'label': 'PERSON'},
#   'New York': {'count': 1, 'label': 'GPE'},
#   'Democrats': {'count': 1, 'label': 'NORP'},
#   'November': {'count': 1, 'label': 'DATE'},
#   'Rep.-elect': {'count': 1, 'label': 'PERSON'},
#   'Joe Neguse': {'count': 1, 'label': 'PERSON'},
#   'Colorado': {'count': 1, 'label': 'GPE'},
#   'weekly': {'count': 1, 'label': 'DATE'},
#   'Tuesday': {'count': 1, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'White House': {'count': 1, 'label': 'ORG'},
#   'Wednesday': {'count': 1, 'label': 'DATE'},
#   'Kevin McCarthy': {'count': 1, 'label': 'PERSON'},
#   'California': {'count': 1, 'label': 'GPE'},
#   'pivot': {'count': 1, 'POS': 'VERB'},
#   'fund': {'count': 1, 'POS': 'VERB'},
#   'shuttered': {'count': 1, 'POS': 'VERB'},
#   '’s': {'count': 2, 'POS': 'VERB'},
#   'setting': {'count': 1, 'POS': 'VERB'},
#   'led': {'count': 1, 'POS': 'VERB'},
#   'testing': {'count': 1, 'POS': 'VERB'},
#   'focus': {'count': 1, 'POS': 'VERB'},
#   'divided': {'count': 1, 'POS': 'VERB'},
#   'end': {'count': 1, 'POS': 'VERB'},
#   'reopen': {'count': 3, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'appear': {'count': 1, 'POS': 'VERB'},
#   'unified': {'count': 1, 'POS': 'VERB'},
#   'vote': {'count': 1, 'POS': 'VERB'},
#   'demanding': {'count': 1, 'POS': 'VERB'},
#   'build': {'count': 1, 'POS': 'VERB'},
#   'rebuked': {'count': 1, 'POS': 'VERB'},
#   'given': {'count': 1, 'POS': 'VERB'},
#   'talk': {'count': 1, 'POS': 'VERB'},
#   'came': {'count': 1, 'POS': 'VERB'},
#   'tweeted': {'count': 1, 'POS': 'VERB'},
#   'Let': {'count': 1, 'POS': 'VERB'},
#   'invited': {'count': 1, 'POS': 'VERB'},
#   'tackles': {'count': 1, 'POS': 'VERB'},
#   'panned': {'count': 1, 'POS': 'VERB'}},
#  {'House': {'count': 3, 'label': 'ORG'},
#   'Democrat': {'count': 1, 'label': 'NORP'},
#   'Nancy Pelosi': {'count': 1, 'label': 'PERSON'},
#   'this week': {'count': 1, 'label': 'DATE'},
#   'Thursday': {'count': 1, 'label': 'DATE'},
#   'Donald Trump': {'count': 1, 'label': 'PERSON'},
#   'Mexico': {'count': 1, 'label': 'GPE'},
#   'Republican': {'count': 3, 'label': 'NORP'},
#   'Senate': {'count': 1, 'label': 'ORG'},
#   'the White House': {'count': 1, 'label': 'ORG'},
#   'Democrats': {'count': 3, 'label': 'NORP'},
#   'first': {'count': 2, 'label': 'ORDINAL'},
#   'Trump': {'count': 4, 'label': 'NORP'},
#   'Hakeem Jeffries': {'count': 1, 'label': 'PERSON'},
#   'New York': {'count': 2, 'label': 'GPE'},
#   'November': {'count': 1, 'label': 'DATE'},
#   'Rep': {'count': 1, 'label': 'ORG'},
#   'Joe Neguse': {'count': 1, 'label': 'PERSON'},
#   'Colorado': {'count': 1, 'label': 'GPE'},
#   'weekly': {'count': 1, 'label': 'DATE'},
#   'Tuesday': {'count': 1, 'label': 'DATE'},
#   'Democratic': {'count': 2, 'label': 'NORP'},
#   'White House': {'count': 1, 'label': 'ORG'},
#   'Wednesday': {'count': 1, 'label': 'DATE'},
#   'Alexandria': {'count': 1, 'label': 'GPE'},
#   'Ocasio-Cortez': {'count': 1, 'label': 'PERSON'},
#   'Select Committee': {'count': 1, 'label': 'ORG'},
#   'the Climate Crisis': {'count': 1, 'label': 'ORG'},
#   'Kevin McCarthy': {'count': 1, 'label': 'PERSON'},
#   'California': {'count': 1, 'label': 'GPE'},
#   'led': {'count': 2, 'POS': 'VERB'},
#   'gavels': {'count': 1, 'POS': 'VERB'},
#   'end': {'count': 2, 'POS': 'VERB'},
#   'pivot': {'count': 1, 'POS': 'VERB'},
#   'fund': {'count': 1, 'POS': 'VERB'},
#   'shuttered': {'count': 1, 'POS': 'VERB'},
#   "'s": {'count': 2, 'POS': 'VERB'},
#   'setting': {'count': 1, 'POS': 'VERB'},
#   'testing': {'count': 1, 'POS': 'VERB'},
#   'focus': {'count': 1, 'POS': 'VERB'},
#   'divided': {'count': 1, 'POS': 'VERB'},
#   'reopen': {'count': 3, 'POS': 'VERB'},
#   'said': {'count': 2, 'POS': 'VERB'},
#   'appear': {'count': 1, 'POS': 'VERB'},
#   'unified': {'count': 1, 'POS': 'VERB'},
#   'vote': {'count': 1, 'POS': 'VERB'},
#   'demanding': {'count': 1, 'POS': 'VERB'},
#   'build': {'count': 1, 'POS': 'VERB'},
#   'rebuked': {'count': 1, 'POS': 'VERB'},
#   'given': {'count': 1, 'POS': 'VERB'},
#   'talk': {'count': 1, 'POS': 'VERB'},
#   'came': {'count': 1, 'POS': 'VERB'},
#   'tweeted': {'count': 1, 'POS': 'VERB'},
#   'Let': {'count': 1, 'POS': 'VERB'},
#   'invited': {'count': 1, 'POS': 'VERB'},
#   'create': {'count': 1, 'POS': 'VERB'},
#   'panned': {'count': 1, 'POS': 'VERB'}},
#  {'Pennsylvania': {'count': 2, 'label': 'GPE'},
#   'Solar United Neighbors': {'count': 2, 'label': 'ORG'},
#   'Indiana': {'count': 1, 'label': 'GPE'},
#   'Crawford': {'count': 1, 'label': 'ORG'},
#   'Mercer counties': {'count': 1, 'label': 'PERSON'},
#   'exists': {'count': 1, 'POS': 'VERB'},
#   'popping': {'count': 1, 'POS': 'VERB'},
#   'help': {'count': 1, 'POS': 'VERB'},
#   'helped': {'count': 1, 'POS': 'VERB'},
#   'launch': {'count': 1, 'POS': 'VERB'},
#   'coming': {'count': 1, 'POS': 'VERB'},
#   'launched': {'count': 1, 'POS': 'VERB'},
#   'formed': {'count': 1, 'POS': 'VERB'},
#   'selected': {'count': 1, 'POS': 'VERB'}},
#  ...]

# %%
### save as pickle

with open('outputs/step5_nlpDic.pickle', 'wb') as handle:
    pickle.dump(nlpDic, handle, protocol=pickle.HIGHEST_PROTOCOL)
