# %%
import pandas as pd
import numpy as np
from lib.utility import get_text,ProcessPipeline
### Part 2 Package
from gensim import corpora, models
from IPython.display import Image
import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Part 1: get raw text data

# %%
### read pickle file
with open('outputs/step2_news_raw.pickle', 'rb') as handle:
    texts = pickle.load(handle)

# %%
pipeline = ProcessPipeline(texts)

textsProcessed = pipeline.run()
# Out:
# language is en
# language is en
# language is bg
# language is de
# language is en
# Not able to detect language
# language is en
# language is vi
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is ar
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is es
# language is ko
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pl
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sl
# language is es
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is pt
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is ro
# language is es
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is es
# language is en
# language is es
# language is es
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is de
# language is ko
# language is ko
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is he
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is id
# language is ko
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is ar
# language is hr
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# Not able to detect language
# language is pl
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is ar
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is nl
# Not able to detect language
# language is es
# Not able to detect language
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ar
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is hu
# language is hu
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is it
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is ar
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is he
# language is ko
# language is en
# language is en
# Not able to detect language
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is bg
# language is nl
# Not able to detect language
# language is el
# language is es
# language is en
# language is en
# Not able to detect language
# language is en
# language is he
# language is de
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is pl
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is tr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# language is es
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is pt
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is tr
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is fr
# language is ko
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sv
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is da
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is ru
# language is zh-cn
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is de
# language is de
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is hu
# language is zh-cn
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hu
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is zh-cn
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is tr
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is zh-cn
# language is en
# language is en
# language is en
# language is en
# language is en
# language is zh-cn
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ru
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is ru
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# Not able to detect language
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is tr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is es
# language is es
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is de
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is he
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is ar
# language is hu
# language is pt
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is pt
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hu
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is es
# language is pt
# language is cs
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is it
# language is en
# language is zh-tw
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ar
# language is en
# language is en
# language is en
# language is nl
# language is el
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is de
# language is es
# Not able to detect language
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is it
# language is en
# Not able to detect language
# language is bg
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is hu
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is de
# language is fr
# language is en
# language is ko
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is de
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is de
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# language is pt
# Not able to detect language
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is de
# language is da
# language is en
# language is en
# language is en
# language is en
# language is de
# language is fr
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is de
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ru
# language is en
# language is en
# Not able to detect language
# language is el
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is sv
# language is en
# language is en
# language is pt
# language is ru
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is hr
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pt
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is id
# language is fr
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is es
# language is en
# language is en
# language is en
# language is fr
# language is fr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# Not able to detect language
# language is es
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# Not able to detect language
# language is en
# Not able to detect language
# language is hu
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is fr
# language is es
# language is ar
# language is ar
# language is en
# Not able to detect language
# language is en
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is el
# language is en
# Not able to detect language
# language is es
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is fr
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is he
# language is en
# language is en
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is ko
# language is en
# language is en
# Not able to detect language
# language is hr
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is hr
# language is nl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is de
# language is hu
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# Not able to detect language
# language is pt
# language is es
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is es
# language is en
# language is en
# language is ko
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is pl
# language is en
# language is en
# language is en
# language is en
# language is en
# language is en
# language is el
# language is en
# language is en
# language is en
# language is en
# language is tr
# Not able to detect language
# Not able to detect language
# language is tr
# language is tr
# Not able to detect language
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is es
# Not able to detect language
# language is en
# language is tr
# language is en
# language is en
# language is fi
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# Not able to detect language
# language is en
# language is en
# language is it
# language is en
# language is en
# language is en
# language is en
# language is en
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is en
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is sv
# language is en
# language is en
# language is en
# language is pl
# language is es
# language is en
# language is en
# language is en
# Not able to detect language
# language is de
# language is en
# language is de
# language is fr
# Not able to detect language
# language is en
# language is en
# language is en
# language is en
# language is ar
# Not able to detect language
# language is de
# language is en

# %% [markdown]
# #### lambda version <br>
# processor = Processor()
# translatedList = []
# for text in texts:
#     translatedList.append(processor.translate(text))
#
# textsSummarized = list(map(lambda x:processor.summarize(x),translated))
#
# textsProcessed = list(map(lambda x:processor.pre_process(x,return_str=False),textsSummarized))

# %%
indexNotNone = np.where([x!="" for x in textsProcessed])
textsProcessed = np.array(textsProcessed)[indexNotNone]
print(textsProcessed)
print(len(textsProcessed))
# Out:
# [list(['forum', 'address', 'one', 'press', 'issu', 'lifetim', 'global', 'energi', 'climat', 'chang', 'india’', 'develop', 'undoubtedli', 'fuell', 'increas', 'energi', 'consumpt', 'econom', 'develop', 'beli', 'grow', 'problem', 'climat', 'chang', 'caus', 'CO', 'emiss', 'includ', 'increas', 'earth’', 'mean', 'surfac', 'temperatur', 'also', 'known', 'global', 'warm', 'rise', 'sea', 'level', 'acidif', 'extrem', 'weather', 'event', 'increas', 'global', 'temperatur', 'loss', 'polar', 'ice', 'strongli', 'link', 'anthropogen', 'activ', 'particularli', 'CO', 'emiss', 'consensu', 'among', 'research', 'link', 'extrem', 'weather', 'event', 'forest', 'fire', 'cyclon', 'drought', 'etc', 'anthropogen', 'caus', 'concern', 'timelin', 'expect', 'global', 'temperatur', 'increas', 'degre', 'C', 'emiss', 'continu', 'well', 'within', 'lifetim', 'u', 'read', 'articl', 'million', 'indian', 'live', 'electr', 'grid', 'solar', 'energi', 'potenti', 'transform', 'life', 'contribut', 'emiss', 'global', 'energi', 'forum', 'video', 'public', 'avail'])
#  list([]) list([]) ... list([]) list([])
#  list(['southern', 'indiana', 'citi', 'plan', 'solar', 'farm', 'power', 'sewag', 'plant'])]
# 2988

# %% [markdown]
# # Part 2: NLP analysis: topic modeling with LDA<br>

# %% [markdown]
# #### LDA intro:
# LDA assumes that each document mix with various topics and every topic mix with various words.<br>
# Documents are produced from a mixture of topics. Those topics then generate words based on their probability distribution. In other words, LDA assumes a document is made from the following steps:
#
# 1. Determine the number of words in a document. Let’s say our document has 6 words.
# 2. Determine the mixture of topics in that document. For example, the document might contain 1/2 the topic “health” and 1/2 the topic “vegetables.”
# 3. Using each topic’s multinomial distribution, output words to fill the document’s word slots. In our example, the “health” topic is 1/2 our document, or 3 words. The “health” topic might have the word “diet” at 20% probability or “exercise” at 15%, so it will fill the document word slots based on those probabilities.
#
# Given this assumption of how documents are created, LDA backtracks and tries to figure out what topics would create those documents in the first place

# %% [markdown]
# #### Intuitively, you can image that we have two layer of aggregations.
# 1. First layer is the distribution of categories.
# > For example, we have finance news, weather news and political news.
# 2. Second layer is distribution of words within the category.
# > For instance, we can find “sunny” and “cloud” in weather news while “money” and “stock” exists in finance news.
#
# ##### How doc is generated:
# - Based on topic distribution(θ), select topic t
# - Based on topic t, selecting corresponding word from ϕ.

# %% [markdown]
# Code steps:
# 1. Create unique dictionary for the texts, since we need to vectorize all docs: Detaisl: We will create dictionary for our texts.
# 2. Constructing a document-term matrix: To generate an LDA model, we need to understand how frequently each term occurs within each document. To do that, we need to construct a document-term matrix with a package called gensim:

# %%
from gensim import corpora, models
import gensim
from gensim.models import CoherenceModel

# %%
"""
Create a dictionary from ‘textsProcessed’ containing the number of times a word appears in the training set.
The Dictionary() function traverses texts, assigning a unique integer id to each unique token while also collecting word counts and relevant statistics. 
    To see each token’s unique integer id, try print(dictionary.token2id).
""" 
dictionary = corpora.Dictionary(textsProcessed)

# %%
dictionary.token2id
# Out:
# {'C': 0,
#  'CO': 1,
#  'acidif': 2,
#  'activ': 3,
#  'address': 4,
#  'also': 5,
#  'among': 6,
#  'anthropogen': 7,
#  'articl': 8,
#  'avail': 9,
#  'beli': 10,
#  'caus': 11,
#  'chang': 12,
#  'climat': 13,
#  'concern': 14,
#  'consensu': 15,
#  'consumpt': 16,
#  'continu': 17,
#  'contribut': 18,
#  'cyclon': 19,
#  'degre': 20,
#  'develop': 21,
#  'drought': 22,
#  'earth’': 23,
#  'econom': 24,
#  'electr': 25,
#  'emiss': 26,
#  'energi': 27,
#  'etc': 28,
#  'event': 29,
#  'expect': 30,
#  'extrem': 31,
#  'fire': 32,
#  'forest': 33,
#  'forum': 34,
#  'fuell': 35,
#  'global': 36,
#  'grid': 37,
#  'grow': 38,
#  'ice': 39,
#  'includ': 40,
#  'increas': 41,
#  'indian': 42,
#  'india’': 43,
#  'issu': 44,
#  'known': 45,
#  'level': 46,
#  'life': 47,
#  'lifetim': 48,
#  'link': 49,
#  'live': 50,
#  'loss': 51,
#  'mean': 52,
#  'million': 53,
#  'one': 54,
#  'particularli': 55,
#  'polar': 56,
#  'potenti': 57,
#  'press': 58,
#  'problem': 59,
#  'public': 60,
#  'read': 61,
#  'research': 62,
#  'rise': 63,
#  'sea': 64,
#  'solar': 65,
#  'strongli': 66,
#  'surfac': 67,
#  'temperatur': 68,
#  'timelin': 69,
#  'transform': 70,
#  'u': 71,
#  'undoubtedli': 72,
#  'video': 73,
#  'warm': 74,
#  'weather': 75,
#  'well': 76,
#  'within': 77,
#  'benefit': 78,
#  'bid': 79,
#  'biomass': 80,
#  'built': 81,
#  'commit': 82,
#  'compani': 83,
#  'competit': 84,
#  'cost': 85,
#  'customers”': 86,
#  'director': 87,
#  'diversifi': 88,
#  'effect': 89,
#  'georgia': 90,
#  'mallard': 91,
#  'maxim': 92,
#  'megawatt': 93,
#  'obtain': 94,
#  'part': 95,
#  'power': 96,
#  'principl': 97,
#  'procur': 98,
#  'propos': 99,
#  'proud': 100,
#  'redi': 101,
#  'renew': 102,
#  'resourc': 103,
#  'said': 104,
#  'seek': 105,
#  'sourc': 106,
#  'upon': 107,
#  'wilson': 108,
#  'wind': 109,
#  '“we': 110,
#  'DC': 111,
#  'GW': 112,
#  'act': 113,
#  'afford': 114,
#  'altern': 115,
#  'amend': 116,
#  'approv': 117,
#  'around': 118,
#  'assist': 119,
#  'bill': 120,
#  'build': 121,
#  'citi': 122,
#  'city’': 123,
#  'clean': 124,
#  'council': 125,
#  'current': 126,
#  'demand': 127,
#  'district’': 128,
#  'doubl': 129,
#  'energyrel': 130,
#  'enough': 131,
#  'entir': 132,
#  'final': 133,
#  'follow': 134,
#  'fund': 135,
#  'gave': 136,
#  'get': 137,
#  'go': 138,
#  'hous': 139,
#  'improv': 140,
#  'incomequalifi': 141,
#  'initi': 142,
#  'instal': 143,
#  'mandat': 144,
#  'meet': 145,
#  'motion': 146,
#  'move': 147,
#  'new': 148,
#  'note': 149,
#  'omnibu': 150,
#  'perform': 151,
#  'portion': 152,
#  'promot': 153,
#  'provid': 154,
#  'provis': 155,
#  'realli': 156,
#  'resid': 157,
#  'set': 158,
#  'standard': 159,
#  'suppli': 160,
#  'support': 161,
#  'unanim': 162,
#  'washington': 163,
#  'workforc': 164,
#  'year': 165,
#  '–': 166,
#  'barchart': 167,
#  'data': 168,
#  'delay': 169,
#  'host': 170,
#  'least': 171,
#  'market': 172,
#  'minut': 173,
#  'solut': 174,
#  '©': 175,
#  'AJ': 176,
#  'advis': 177,
#  'alexand': 178,
#  'america’': 179,
#  'andrew': 180,
#  'announc': 181,
#  'bonovich': 182,
#  'close': 183,
#  'distribut': 184,
#  'engi': 185,
#  'gatesman': 186,
#  'gillespi': 187,
#  'goldman': 188,
#  'group': 189,
#  'invest': 190,
#  'katherin': 191,
#  'manag': 192,
#  'matthew': 193,
#  'mullin': 194,
#  'north': 195,
#  'partnership': 196,
#  'pictur': 197,
#  'ratt': 198,
#  'robinson': 199,
#  'sachs’': 200,
#  'sheppard': 201,
#  'team': 202,
#  'today': 203,
#  'transact': 204,
#  'Co': 205,
#  'Dr': 206,
#  'age': 207,
#  'analysi': 208,
#  'analyst': 209,
#  'anticip': 210,
#  'ask': 211,
#  'averag': 212,
#  'baod': 213,
#  'buy': 214,
#  'buzz': 215,
#  'chief': 216,
#  'china': 217,
#  'commun': 218,
#  'coverag': 219,
#  'decemb': 220,
#  'dengyuan': 221,
#  'earn': 222,
#  'equiti': 223,
#  'exchang': 224,
#  'folow': 225,
#  'found': 226,
#  'frequent': 227,
#  'futur': 228,
#  'green': 229,
#  'headlin': 230,
#  'headquart': 231,
#  'hold': 232,
#  'immedi': 233,
#  'infotri': 234,
#  'limit': 235,
#  'ltd': 236,
#  'marketbeat': 237,
#  'media': 238,
#  'monday': 239,
#  'month': 240,
#  'neg': 241,
#  'news': 242,
#  'next': 243,
#  'nyse': 244,
#  'nyseyg': 245,
#  'object': 246,
#  'offic': 247,
#  'open': 248,
#  'peopl': 249,
#  'price': 250,
#  'question': 251,
#  'rate': 252,
#  'reach': 253,
#  'recent': 254,
#  'releas': 255,
#  'report': 256,
#  'republ': 257,
#  'result': 258,
#  'revers': 259,
#  'sentiment': 260,
#  'share': 261,
#  'somewhat': 262,
#  'song': 263,
#  'split': 264,
#  'stock': 265,
#  'symbol': 266,
#  'technolog': 267,
#  'th': 268,
#  'ticker': 269,
#  'trade': 270,
#  'trend': 271,
#  'tuesday': 272,
#  'unlik': 273,
#  'yge': 274,
#  'yingli': 275,
#  'york': 276,
#  'Mr': 277,
#  'SP': 278,
#  'assign': 279,
#  'believ': 280,
#  'closest': 281,
#  'favor': 282,
#  'financi': 283,
#  'firm': 284,
#  'five': 285,
#  'impact': 286,
#  'indic': 287,
#  'interim': 288,
#  'long': 289,
#  'medium': 290,
#  'michael': 291,
#  'near': 292,
#  'otcmkt': 293,
#  'outperform': 294,
#  'product': 295,
#  'publiclytrad': 296,
#  'rank': 297,
#  'receiv': 298,
#  'ringstad': 299,
#  'scale': 300,
#  'score': 301,
#  'term': 302,
#  'transport': 303,
#  'underperform': 304,
#  'vote': 305,
#  'websit': 306,
#  'zaap': 307,
#  'zap': 308,
#  'zapworldcom': 309,
#  'accordingli': 310,
#  'actual': 311,
#  'america': 312,
#  'assur': 313,
#  'billion': 314,
#  'capac': 315,
#  'caution': 316,
#  'certain': 317,
#  'combin': 318,
#  'content': 319,
#  'control': 320,
#  'cubic': 321,
#  'custom': 322,
#  'differ': 323,
#  'disclaim': 324,
#  'download': 325,
#  'expressli': 326,
#  'factor': 327,
#  'foot': 328,
#  'forwardlook': 329,
#  'ga': 330,
#  'gener': 331,
#  'guarante': 332,
#  'inform': 333,
#  'mani': 334,
#  'materi': 335,
#  'multimediahttpwwwprnewswirecomnewsreleasessoutherncompanyclosessaleofgulfpowertonexteraenergyhtml': 336,
#  'natur': 337,
#  'number': 338,
#  'oblig': 339,
#  'origin': 340,
#  'outsid': 341,
#  'premier': 342,
#  'put': 343,
#  'reader': 344,
#  'realiz': 345,
#  'relianc': 346,
#  'serv': 347,
#  'southern': 348,
#  'subject': 349,
#  'subsidiari': 350,
#  'suggest': 351,
#  'throughput': 352,
#  'uncertainti': 353,
#  'undu': 354,
#  'updat': 355,
#  'view': 356,
#  'volum': 357,
#  'agenc': 358,
#  'copyright': 359,
#  'esa': 360,
#  'european': 361,
#  'space': 362,
#  'across': 363,
#  'fiber': 364,
#  'forward‐look': 365,
#  'four': 366,
#  'nation': 367,
#  'nyseso': 368,
#  'oper': 369,
#  'optic': 370,
#  'recogn': 371,
#  'reliabl': 372,
#  'safe': 373,
#  'state': 374,
#  'three': 375,
#  'wholesal': 376,
#  'wireless': 377,
#  'US': 378,
#  'allow': 379,
#  'allterrain': 380,
#  'annual': 381,
#  'armi': 382,
#  'armori': 383,
#  'ascrib': 384,
#  'asset': 385,
#  'augment': 386,
#  'award': 387,
#  'base': 388,
#  'becam': 389,
#  'began': 390,
#  'budget': 391,
#  'car': 392,
#  'center': 393,
#  'chosen': 394,
#  'clackama': 395,
#  'complet': 396,
#  'compound': 397,
#  'congress': 398,
#  'conserv': 399,
#  'construct': 400,
#  'could': 401,
#  'cover': 402,
#  'critic': 403,
#  'cuttingedg': 404,
#  'decad': 405,
#  'defens': 406,
#  'depart': 407,
#  'dod': 408,
#  'dramat': 409,
#  'effici': 410,
#  'enabl': 411,
#  'environment': 412,
#  'essenti': 413,
#  'everi': 414,
#  'execut': 415,
#  'expand': 416,
#  'facil': 417,
#  'first': 418,
#  'goal': 419,
#  'gone': 420,
#  'growth': 421,
#  'guard': 422,
#  'help': 423,
#  'hour': 424,
#  'hub': 425,
#  'ideal': 426,
#  'import': 427,
#  'jeff': 428,
#  'kenneth': 429,
#  'kilowatt': 430,
#  'list': 431,
#  'local': 432,
#  'longterm': 433,
#  'lot': 434,
#  'mach': 435,
#  'made': 436,
#  'medic': 437,
#  'militari': 438,
#  'mission': 439,
#  'must': 440,
#  'need': 441,
#  'net': 442,
#  'nonrooftop': 443,
#  'ongo': 444,
#  'order': 445,
#  'oregon': 446,
#  'overal': 447,
#  'oversea': 448,
#  'panel': 449,
#  'park': 450,
#  'particip': 451,
#  'percent': 452,
#  'pilot': 453,
#  'plan': 454,
#  'play': 455,
#  'program': 456,
#  'project': 457,
#  'protect': 458,
#  'reduc': 459,
#  'requir': 460,
#  'respond': 461,
#  'respons': 462,
#  'role': 463,
#  'save': 464,
#  'secur': 465,
#  'selfsuffici': 466,
#  'site': 467,
#  'specifi': 468,
#  'strateg': 469,
#  'studi': 470,
#  'sustain': 471,
#  'system': 472,
#  'target': 473,
#  'train': 474,
#  'two': 475,
#  'uptod': 476,
#  'use': 477,
#  'util': 478,
#  'vehicl': 479,
#  'vital': 480,
#  'weaponri': 481,
#  'work': 482,
#  'written': 483,
#  'zero': 484,
#  'MN': 485,
#  'cold': 486,
#  'eden': 487,
#  'prairi': 488,
#  'becom': 489,
#  'clear': 490,
#  'even': 491,
#  'mostli': 492,
#  'overcast': 493,
#  'overnight': 494,
#  'sky': 495,
#  'access': 496,
#  'accord': 497,
#  'aggress': 498,
#  'american': 499,
#  'anyon': 500,
#  'avenu': 501,
#  'bankruptci': 502,
#  'beyond': 503,
#  'big': 504,
#  'bit': 505,
#  'bite': 506,
#  'bless': 507,
#  'cannot': 508,
#  'case': 509,
#  'cash': 510,
#  'certif': 511,
#  'chines': 512,
#  'cleanenergi': 513,
#  'compet': 514,
#  'cooper': 515,
#  'creativ': 516,
#  'credit': 517,
#  'debat': 518,
#  'don’t': 519,
#  'due': 520,
#  'dump': 521,
#  'europ': 522,
#  'fall': 523,
#  'feed': 524,
#  'find': 525,
#  'forev': 526,
#  'give': 527,
#  'grant': 528,
#  'hand': 529,
#  'hit': 530,
#  'industri': 531,
#  'innov': 532,
#  'intend': 533,
#  'investmentsand': 534,
#  'kilowatthour': 535,
#  'last': 536,
#  'manufactur': 537,
#  'meanwhil': 538,
#  'merger': 539,
#  'necessari': 540,
#  'never': 541,
#  'oversuppli': 542,
#  'pain': 543,
#  'process': 544,
#  'pursu': 545,
#  'quit': 546,
#  'real': 547,
#  'sell': 548,
#  'seriou': 549,
#  'simpli': 550,
#  'slap': 551,
#  'solarworld': 552,
#  'srec': 553,
#  'subsidi': 554,
#  'surviv': 555,
#  'taken': 556,
#  'tantamount': 557,
#  'tariff': 558,
#  'undergo': 559,
#  'way': 560,
#  'yet': 561,
#  '“antidumping”': 562,
#  '“antisubsidy”': 563,
#  '“dumping”': 564,
#  'SH': 565,
#  'techsh': 566,
#  'windstream': 567,
#  'wsti': 568,
#  'addit': 569,
#  'applic': 570,
#  'ass': 571,
#  'autonom': 572,
#  'belief': 573,
#  'boundari': 574,
#  'busi': 575,
#  'creation': 576,
#  'direct': 577,
#  'dynam': 578,
#  'enrich': 579,
#  'environ': 580,
#  'exhaust': 581,
#  'extent': 582,
#  'function': 583,
#  'fundament': 584,
#  'futurist': 585,
#  'ground': 586,
#  'hindranc': 587,
#  'indepth': 588,
#  'influenc': 589,
#  'intent': 590,
#  'intern': 591,
#  'notabl': 592,
#  'pathway': 593,
#  'photovolta': 594,
#  'posit': 595,
#  'progress': 596,
#  'regard': 597,
#  'replet': 598,
#  'revenu': 599,
#  'risk': 600,
#  'run': 601,
#  'scope': 602,
#  'size': 603,
#  'step': 604,
#  'summari': 605,
#  'techniqu': 606,
#  'tendenc': 607,
#  'understand': 608,
#  'valu': 609,
#  'variabl': 610,
#  'wafer': 611,
#  'australia': 612,
#  'australian': 613,
#  'bank': 614,
#  'born': 615,
#  'cent': 616,
#  'collect': 617,
#  'come': 618,
#  'consum': 619,
#  'demograph': 620,
#  'dollar': 621,
#  'economi': 622,
#  'erron': 623,
#  'explor': 624,
#  'expos': 625,
#  'figur': 626,
#  'gap': 627,
#  'gaug': 628,
#  'gdp': 629,
#  'guess': 630,
#  'higher': 631,
#  'ignor': 632,
#  'jump': 633,
#  'largest': 634,
#  'load': 635,
#  'measur': 636,
#  'migrat': 637,
#  'muslim': 638,
#  'older': 639,
#  'overestim': 640,
#  'people’': 641,
#  'per': 642,
#  'percept': 643,
#  'peril': 644,
#  'pessimist': 645,
#  'place': 646,
#  'popul': 647,
#  'profession': 648,
#  'pronounc': 649,
#  'proport': 650,
#  'realiti': 651,
#  'seven': 652,
#  'show': 653,
#  'sinc': 654,
#  'six': 655,
#  'surg': 656,
#  'survey': 657,
#  'time': 658,
#  'vastli': 659,
#  'world': 660,
#  'year’': 661,
#  'account': 662,
#  'approxim': 663,
#  'commerci': 664,
#  'counti': 665,
#  'eight': 666,
#  'emissionsfre': 667,
#  'florida': 668,
#  'gulf': 669,
#  'hampshir': 670,
#  'iowa': 671,
#  'light': 672,
#  'multimediahttpwwwprnewswirecomnewsreleasesnexteraenergycompletesacquisitionofgulfpowerfromsoutherncompanyhtml': 673,
#  'nextera': 674,
#  'northwest': 675,
#  'nuclear': 676,
#  'own': 677,
#  'rateregul': 678,
#  'serf': 679,
#  'throughout': 680,
#  'unit': 681,
#  'wisconsin': 682,
#  'beach': 683,
#  'juno': 684,
#  'lead': 685,
#  'nee': 686,
#  'acquisit': 687,
#  'fla': 688,
#  'inc': 689,
#  'jan': 690,
#  'previous': 691,
#  'prnewswir': 692,
#  'adopt': 693,
#  'advoc': 694,
#  'aesthet': 695,
#  'appeal': 696,
#  'architect': 697,
#  'architectur': 698,
#  'associ': 699,
#  'beauti': 700,
#  'behalf': 701,
#  'block': 702,
#  'board': 703,
#  'campaign': 704,
#  'centuri': 705,
#  'club': 706,
#  'consid': 707,
#  'contact': 708,
#  'contractor': 709,
#  'coop’': 710,
#  'deal': 711,
#  'decid': 712,
#  'didn’t': 713,
#  'drop': 714,
#  'easi': 715,
#  'easier': 716,
#  'encourag': 717,
#  'end': 718,
#  'finver': 719,
#  'gabl': 720,
#  'hadn’t': 721,
#  'hear': 722,
#  'heard': 723,
#  'homeown': 724,
#  'individu': 725,
#  'irma': 726,
#  'jodi': 727,
#  'kawalerski': 728,
#  'label': 729,
#  'law': 730,
#  'leedcertifi': 731,
#  'leen': 732,
#  'letter': 733,
#  'mail': 734,
#  'martinez': 735,
#  'martinez’': 736,
#  'master': 737,
#  'miami': 738,
#  'miamidad': 739,
#  'neighbor': 740,
#  'neighborhood': 741,
#  'octob': 742,
#  'page': 743,
#  'placement': 744,
#  'polici': 745,
#  'prohibit': 746,
#  'publicli': 747,
#  'ranch': 748,
#  'restrict': 749,
#  'resubmit': 750,
#  'review': 751,
#  'right': 752,
#  'rule': 753,
#  'say': 754,
#  'select': 755,
#  'sierra': 756,
#  'soon': 757,
#  'south': 758,
#  'special': 759,
#  'squar': 760,
#  'streetfac': 761,
#  'submit': 762,
#  'they’r': 763,
#  'this”': 764,
#  'thousand': 765,
#  'togeth': 766,
#  'told': 767,
#  'tonier': 768,
#  'turn': 769,
#  'unfeas': 770,
#  'violat': 771,
#  'vow': 772,
#  'want': 773,
#  'web': 774,
#  'without': 775,
#  '“they': 776,
#  'capit': 777,
#  'exist': 778,
#  'februari': 779,
#  'gate': 780,
#  'golden': 781,
#  'infor': 782,
#  'koch': 783,
#  'llc': 784,
#  'rais': 785,
#  'sharehold': 786,
#  'california’': 787,
#  'digest’': 788,
#  'guid': 789,
#  'happen': 790,
#  'lcf': 791,
#  'multislid': 792,
#  'rf': 793,
#  'what’': 794,
#  'Fe': 795,
#  'amid': 796,
#  'approach': 797,
#  'attend': 798,
#  'cannabi': 799,
#  'capitol': 800,
#  'ceremoni': 801,
#  'childhood': 802,
#  'convent': 803,
#  'democrat': 804,
#  'downtown': 805,
#  'earli': 806,
#  'educ': 807,
#  'fe’': 808,
#  'file': 809,
#  'folk': 810,
#  'forecast': 811,
#  'gov': 812,
#  'governor': 813,
#  'greater': 814,
#  'grisham': 815,
#  'grisham’': 816,
#  'gun': 817,
#  'inaugur': 818,
#  'incom': 819,
#  'insid': 820,
#  'lowincom': 821,
#  'lugan': 822,
#  'lujan': 823,
#  'mariachi': 824,
#  'mexico': 825,
#  'michel': 826,
#  'multibilliondollar': 827,
#  'music': 828,
#  'newli': 829,
#  'northern': 830,
#  'oath': 831,
#  'pay': 832,
#  'polit': 833,
#  'predawn': 834,
#  'regul': 835,
#  'reimagin': 836,
#  'safeti': 837,
#  'santa': 838,
#  'shift': 839,
#  'snowstorm': 840,
#  'sound': 841,
#  'spectat': 842,
#  'speech': 843,
#  'spend': 844,
#  'state’': 845,
#  'take': 846,
#  'tap': 847,
#  'toward': 848,
#  'urg': 849,
#  'winter': 850,
#  'worker': 851,
#  'AP': 852,
#  'fe': 853,
#  'januari': 854,
#  'lui': 855,
#  'mexican': 856,
#  'nd': 857,
#  'saturnoth': 858,
#  'sworn': 859,
#  'sánchez': 860,
#  'via': 861,
#  'abort': 862,
#  'assault': 863,
#  'ban': 864,
#  'better': 865,
#  'call': 866,
#  'cast': 867,
#  'celebr': 868,
#  'choic': 869,
#  'climb': 870,
#  'comeback': 871,
#  'countri': 872,
#  'detaildriven': 873,
#  'discours': 874,
#  'divid': 875,
#  'divis': 876,
#  'elect': 877,
#  'enshrin': 878,
#  'face': 879,
#  'femal': 880,
#  'gina': 881,
#  'great': 882,
#  'gunright': 883,
#  'hail': 884,
#  'haul': 885,
#  'highcapac': 886,
#  'island': 887,
#  'lawmak': 888,
#  'leader': 889,
#  'leadership': 890,
#  'legisl': 891,
#  'let’': 892,
#  'magazin': 893,
#  'make': 894,
#  'mention': 895,
#  'much': 896,
#  'oasi': 897,
#  'optimist': 898,
#  'past': 899,
#  'plaza': 900,
#  'point': 901,
#  'prioriti': 902,
#  'pushback': 903,
#  'raimondo': 904,
#  'recess': 905,
#  'record': 906,
#  'recoveri': 907,
#  'rhode': 908,
#  'second': 909,
#  'shape': 910,
#  'stronger': 911,
#  'success': 912,
#  'themat': 913,
#  'took': 914,
#  'tough': 915,
#  'walk': 916,
#  'weapon': 917,
#  'woman': 918,
#  'word': 919,
#  '—': 920,
#  'NV': 921,
#  'antirooftopsolar': 922,
#  'apart': 923,
#  'bear': 924,
#  'behind': 925,
#  'brought': 926,
#  'cowardic': 927,
#  'decis': 928,
#  'deni': 929,
#  'dweller': 930,
#  'effort': 931,
#  'exercis': 932,
#  'fact': 933,
#  'here’': 934,
#  'independ': 935,
#  'might': 936,
#  'modul': 937,
#  'multipli': 938,
#  'nevada': 939,
#  'notori': 940,
#  'otherwis': 941,
#  'owner': 942,
#  'pressur': 943,
#  'puc': 944,
#  'request': 945,
#  'roof': 946,
#  'rooftop': 947,
#  'rulemak': 948,
#  'tenant': 949,
#  'thing': 950,
#  'P': 951,
#  'agricultur': 952,
#  'april': 953,
#  'consecut': 954,
#  'field': 955,
#  'gcl': 956,
#  'gncu': 957,
#  'lend': 958,
#  'lender': 959,
#  'name': 960,
#  'privat': 961,
#  'rural': 962,
#  'sponsor': 963,
#  'third': 964,
#  'titl': 965,
#  'union': 966,
#  'usda': 967,
#  'NM': 968,
#  'anoth': 969,
#  'back': 970,
#  'boom': 971,
#  'caption': 972,
#  'endors': 973,
#  'exampl': 974,
#  'galleri': 975,
#  'govern': 976,
#  'imag': 977,
#  'job': 978,
#  'latina': 979,
#  'le': 980,
#  'lee': 981,
#  'like': 982,
#  'look': 983,
#  'money': 984,
#  'morgan': 985,
#  'oil': 986,
#  'pass': 987,
#  'photo': 988,
#  'produc': 989,
#  'republican': 990,
#  'revolut': 991,
#  'salari': 992,
#  'succeed': 993,
#  'surplu': 994,
#  'susana': 995,
#  'termedout': 996,
#  'top': 997,
#  'turbin': 998,
#  'urgent': 999,
#  ...}

# %%
### The doc2bow() function converts dictionary into a bag-of-words. The result, corpus, is a list of vectors equal to the number of documents. In each document vector is a series of tuples. As an example, print(corpus[0]) results in the following:
corpus = [dictionary.doc2bow(text) for text in textsProcessed]

# %%
### This list of tuples represents our first document, doc_a. The tuples are (term ID, term frequency) pairs, so if  print(dictionary.token2id) says brocolli’s id is 0, then the first tuple indicates that brocolli appeared twice in doc_a. doc2bow() only includes terms that actually occur: terms that do not occur in a document will not appear in that document’s vector.
print(corpus[0])
# Out:
# [(0, 1), (1, 2), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1), (7, 2), (8, 1), (9, 1), (10, 1), (11, 2), (12, 2), (13, 2), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 2), (22, 1), (23, 1), (24, 1), (25, 1), (26, 4), (27, 4), (28, 1), (29, 2), (30, 1), (31, 2), (32, 1), (33, 1), (34, 2), (35, 1), (36, 5), (37, 1), (38, 1), (39, 1), (40, 1), (41, 4), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 2), (49, 2), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 1), (63, 1), (64, 1), (65, 1), (66, 1), (67, 1), (68, 3), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 2), (76, 1), (77, 1)]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=3, id2word = dictionary, passes=20)

# %%
ldamodel.print_topics(num_topics=3, num_words=10)
# Out:
# [(0,
#   '0.020*"energi" + 0.010*"compani" + 0.009*"power" + 0.008*"share" + 0.008*"market" + 0.008*"renew" + 0.008*"solar" + 0.007*"electr" + 0.006*"gener" + 0.006*"new"'),
#  (1,
#   '0.011*"new" + 0.010*"said" + 0.009*"state" + 0.009*"climat" + 0.007*"chang" + 0.006*"year" + 0.006*"would" + 0.005*"energi" + 0.005*"work" + 0.004*"green"'),
#  (2,
#   '0.031*"hous" + 0.026*"new" + 0.022*"trump" + 0.021*"democrat" + 0.017*"speaker" + 0.017*"pelosi" + 0.016*"govern" + 0.013*"congress" + 0.012*"—" + 0.012*"leader"')]

# %% [markdown]
# ### Evaluate LDA model based on Perplexity & Coherece Score

# %%
# Compute Perplexity
print('\nPerplexity: ', ldamodel.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=ldamodel, texts=textsProcessed, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.146134438320815
#
# Coherence Score:  0.5447340917020819

# %%
### Check each document and its topics
for i in range(len(corpus)):
    tmpTopic = ldamodel[corpus[i]]
    print(f"For doc {i}, corresponding topics & probability are {tmpTopic}")
# Out:
# For doc 0, corresponding topics & probability are [(0, 0.732434), (1, 0.26424813)]
# For doc 1, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 3, corresponding topics & probability are [(0, 0.9207168), (1, 0.07190533)]
# For doc 4, corresponding topics & probability are [(0, 0.7734179), (1, 0.18009305), (2, 0.046489056)]
# For doc 5, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 6, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 7, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 8, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 9, corresponding topics & probability are [(0, 0.937283), (1, 0.032162026), (2, 0.030554982)]
# For doc 10, corresponding topics & probability are [(0, 0.9788255), (2, 0.011466333)]
# For doc 11, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 12, corresponding topics & probability are [(0, 0.9952363)]
# For doc 13, corresponding topics & probability are [(0, 0.99070364)]
# For doc 14, corresponding topics & probability are [(0, 0.99074894)]
# For doc 15, corresponding topics & probability are [(0, 0.2438954), (1, 0.7139605), (2, 0.04214412)]
# For doc 16, corresponding topics & probability are [(0, 0.24389108), (1, 0.7139648), (2, 0.042144112)]
# For doc 17, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 18, corresponding topics & probability are [(0, 0.99305546)]
# For doc 19, corresponding topics & probability are [(0, 0.9935891)]
# For doc 20, corresponding topics & probability are [(0, 0.9935881)]
# For doc 21, corresponding topics & probability are [(0, 0.9935887)]
# For doc 22, corresponding topics & probability are [(0, 0.96745527), (1, 0.024997005)]
# For doc 23, corresponding topics & probability are [(0, 0.51062644), (1, 0.06758252), (2, 0.42179102)]
# For doc 24, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 25, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 26, corresponding topics & probability are [(0, 0.23910813), (1, 0.42634755), (2, 0.33454436)]
# For doc 27, corresponding topics & probability are [(0, 0.8153056), (1, 0.18247111)]
# For doc 28, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 29, corresponding topics & probability are [(0, 0.5322753), (1, 0.44736314), (2, 0.02036156)]
# For doc 30, corresponding topics & probability are [(0, 0.99570763)]
# For doc 31, corresponding topics & probability are [(0, 0.76440555), (1, 0.23275964)]
# For doc 32, corresponding topics & probability are [(0, 0.9845183)]
# For doc 33, corresponding topics & probability are [(0, 0.98714805)]
# For doc 34, corresponding topics & probability are [(0, 0.9871465)]
# For doc 35, corresponding topics & probability are [(0, 0.987148)]
# For doc 36, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 37, corresponding topics & probability are [(0, 0.9889148)]
# For doc 38, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 39, corresponding topics & probability are [(0, 0.4668793), (1, 0.5210628), (2, 0.012057918)]
# For doc 40, corresponding topics & probability are [(0, 0.73437756), (1, 0.24971475), (2, 0.015907716)]
# For doc 41, corresponding topics & probability are [(0, 0.8677016), (1, 0.095201045), (2, 0.0370974)]
# For doc 42, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 43, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 44, corresponding topics & probability are [(1, 0.99343765)]
# For doc 45, corresponding topics & probability are [(1, 0.94116783), (2, 0.056184232)]
# For doc 46, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 47, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 48, corresponding topics & probability are [(1, 0.9401484), (2, 0.057247397)]
# For doc 49, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 50, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 51, corresponding topics & probability are [(0, 0.8061017), (1, 0.18885434)]
# For doc 52, corresponding topics & probability are [(0, 0.9801277), (1, 0.011109102)]
# For doc 53, corresponding topics & probability are [(1, 0.9952138)]
# For doc 54, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 55, corresponding topics & probability are [(1, 0.9535451), (2, 0.04284167)]
# For doc 56, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 57, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 58, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 59, corresponding topics & probability are [(0, 0.025919784), (1, 0.95096385), (2, 0.02311636)]
# For doc 60, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 61, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 62, corresponding topics & probability are [(0, 0.99557805)]
# For doc 63, corresponding topics & probability are [(1, 0.9929833)]
# For doc 64, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 65, corresponding topics & probability are [(1, 0.99521434)]
# For doc 66, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 67, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 68, corresponding topics & probability are [(0, 0.96887577), (1, 0.029010791)]
# For doc 69, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 70, corresponding topics & probability are [(0, 0.9910281)]
# For doc 71, corresponding topics & probability are [(1, 0.9795849), (2, 0.01888475)]
# For doc 72, corresponding topics & probability are [(0, 0.06705831), (1, 0.8299243), (2, 0.10301738)]
# For doc 73, corresponding topics & probability are [(0, 0.07500768), (1, 0.92128325)]
# For doc 74, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 75, corresponding topics & probability are [(0, 0.22827119), (1, 0.76376116)]
# For doc 76, corresponding topics & probability are [(0, 0.9943298)]
# For doc 77, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 78, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 79, corresponding topics & probability are [(0, 0.22827132), (1, 0.7637618)]
# For doc 80, corresponding topics & probability are [(0, 0.85498583), (1, 0.14360185)]
# For doc 81, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 82, corresponding topics & probability are [(0, 0.60370284), (1, 0.39071676)]
# For doc 83, corresponding topics & probability are [(0, 0.9591953), (1, 0.023030287), (2, 0.017774405)]
# For doc 84, corresponding topics & probability are [(0, 0.9468168), (1, 0.025797918), (2, 0.027385315)]
# For doc 85, corresponding topics & probability are [(0, 0.04257513), (1, 0.9523834)]
# For doc 86, corresponding topics & probability are [(0, 0.9940613)]
# For doc 87, corresponding topics & probability are [(0, 0.1722342), (1, 0.8254622)]
# For doc 88, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 89, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 90, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 91, corresponding topics & probability are [(0, 0.77630335), (1, 0.11254951), (2, 0.11114714)]
# For doc 92, corresponding topics & probability are [(0, 0.32444477), (1, 0.67437434)]
# For doc 93, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 94, corresponding topics & probability are [(0, 0.7716826), (1, 0.22250508)]
# For doc 95, corresponding topics & probability are [(0, 0.99708325)]
# For doc 96, corresponding topics & probability are [(0, 0.92076105), (1, 0.07551626)]
# For doc 97, corresponding topics & probability are [(0, 0.9951138)]
# For doc 98, corresponding topics & probability are [(0, 0.24627975), (1, 0.7511429)]
# For doc 99, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 100, corresponding topics & probability are [(0, 0.059937693), (1, 0.9312605)]
# For doc 101, corresponding topics & probability are [(0, 0.9372815), (1, 0.03216348), (2, 0.030554987)]
# For doc 102, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 103, corresponding topics & probability are [(0, 0.5620223), (1, 0.41224122), (2, 0.025736429)]
# For doc 104, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 105, corresponding topics & probability are [(0, 0.06193409), (1, 0.9325137)]
# For doc 106, corresponding topics & probability are [(0, 0.9950342)]
# For doc 107, corresponding topics & probability are [(0, 0.9372822), (1, 0.032162834), (2, 0.030554982)]
# For doc 108, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 109, corresponding topics & probability are [(0, 0.028910937), (1, 0.9687808)]
# For doc 110, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 111, corresponding topics & probability are [(0, 0.81252164), (1, 0.18564989)]
# For doc 112, corresponding topics & probability are [(0, 0.9372816), (1, 0.03216342), (2, 0.030554986)]
# For doc 113, corresponding topics & probability are [(0, 0.7758962), (1, 0.22316517)]
# For doc 114, corresponding topics & probability are [(0, 0.8376617), (1, 0.1583432)]
# For doc 115, corresponding topics & probability are [(0, 0.23615226), (1, 0.76331717)]
# For doc 116, corresponding topics & probability are [(0, 0.8125243), (1, 0.18564723)]
# For doc 117, corresponding topics & probability are [(0, 0.4240799), (1, 0.57372254)]
# For doc 118, corresponding topics & probability are [(0, 0.93728155), (1, 0.032163527), (2, 0.030554986)]
# For doc 119, corresponding topics & probability are [(0, 0.5222425), (1, 0.45999283), (2, 0.017764712)]
# For doc 120, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 121, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 122, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 123, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 124, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 125, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 126, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 127, corresponding topics & probability are [(0, 0.057007585), (1, 0.8868136), (2, 0.056178812)]
# For doc 128, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 129, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 130, corresponding topics & probability are [(0, 0.6727423), (1, 0.30537167), (2, 0.021886017)]
# For doc 131, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 132, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 133, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 134, corresponding topics & probability are [(0, 0.7874249), (1, 0.20991619)]
# For doc 135, corresponding topics & probability are [(0, 0.9948994)]
# For doc 136, corresponding topics & probability are [(0, 0.99481803)]
# For doc 137, corresponding topics & probability are [(1, 0.90701085), (2, 0.08926122)]
# For doc 138, corresponding topics & probability are [(0, 0.7343815), (1, 0.24971078), (2, 0.01590771)]
# For doc 139, corresponding topics & probability are [(0, 0.9690003), (1, 0.02873832)]
# For doc 140, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 141, corresponding topics & probability are [(0, 0.8997712), (1, 0.09543178)]
# For doc 142, corresponding topics & probability are [(0, 0.6269604), (1, 0.37161893)]
# For doc 143, corresponding topics & probability are [(0, 0.5656835), (1, 0.39548892), (2, 0.038827583)]
# For doc 144, corresponding topics & probability are [(0, 0.63337094), (1, 0.36302528)]
# For doc 145, corresponding topics & probability are [(0, 0.99338824)]
# For doc 146, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 147, corresponding topics & probability are [(1, 0.9929834)]
# For doc 148, corresponding topics & probability are [(1, 0.94116807), (2, 0.056184)]
# For doc 149, corresponding topics & probability are [(1, 0.94116837), (2, 0.056183647)]
# For doc 150, corresponding topics & probability are [(1, 0.94116884), (2, 0.056183264)]
# For doc 151, corresponding topics & probability are [(1, 0.9411671), (2, 0.056184996)]
# For doc 152, corresponding topics & probability are [(0, 0.9626594), (1, 0.020624831), (2, 0.016715785)]
# For doc 153, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 154, corresponding topics & probability are [(0, 0.9372732), (1, 0.03217177), (2, 0.030554999)]
# For doc 155, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 156, corresponding topics & probability are [(0, 0.025943257), (1, 0.9509403), (2, 0.023116423)]
# For doc 157, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 158, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 159, corresponding topics & probability are [(1, 0.98156476), (2, 0.016832175)]
# For doc 160, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 161, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 162, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 163, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 164, corresponding topics & probability are [(1, 0.9402684), (2, 0.05707539)]
# For doc 165, corresponding topics & probability are [(0, 0.2577617), (1, 0.7379993)]
# For doc 166, corresponding topics & probability are [(0, 0.011550935), (1, 0.9778235), (2, 0.010625552)]
# For doc 167, corresponding topics & probability are [(0, 0.77418274), (1, 0.22390015)]
# For doc 168, corresponding topics & probability are [(1, 0.90655684), (2, 0.091332555)]
# For doc 169, corresponding topics & probability are [(0, 0.74229217), (1, 0.20404217), (2, 0.05366562)]
# For doc 170, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 171, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 172, corresponding topics & probability are [(0, 0.9879669)]
# For doc 173, corresponding topics & probability are [(0, 0.23153345), (1, 0.76792085)]
# For doc 174, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 175, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 176, corresponding topics & probability are [(0, 0.96825475), (1, 0.016364815), (2, 0.015380416)]
# For doc 177, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 178, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 179, corresponding topics & probability are [(0, 0.9879671)]
# For doc 180, corresponding topics & probability are [(0, 0.9072842), (1, 0.05085492), (2, 0.0418609)]
# For doc 181, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 182, corresponding topics & probability are [(0, 0.7982513), (1, 0.19719596)]
# For doc 183, corresponding topics & probability are [(0, 0.76091135), (1, 0.23046294)]
# For doc 184, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 185, corresponding topics & probability are [(0, 0.019541852), (1, 0.88892215), (2, 0.09153601)]
# For doc 186, corresponding topics & probability are [(0, 0.8349877), (1, 0.16328344)]
# For doc 187, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 188, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 189, corresponding topics & probability are [(0, 0.9302188), (1, 0.03643355), (2, 0.03334763)]
# For doc 190, corresponding topics & probability are [(0, 0.9920728)]
# For doc 191, corresponding topics & probability are [(0, 0.6743688), (1, 0.32202038)]
# For doc 192, corresponding topics & probability are [(0, 0.8598884), (1, 0.13300139)]
# For doc 193, corresponding topics & probability are [(1, 0.95877224), (2, 0.037268233)]
# For doc 194, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 195, corresponding topics & probability are [(0, 0.9188264), (1, 0.045785014), (2, 0.035388537)]
# For doc 196, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 197, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 198, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 199, corresponding topics & probability are [(0, 0.11981805), (1, 0.8756435)]
# For doc 200, corresponding topics & probability are [(0, 0.36915407), (1, 0.59625626), (2, 0.03458966)]
# For doc 201, corresponding topics & probability are [(0, 0.3126917), (1, 0.68424344)]
# For doc 202, corresponding topics & probability are [(0, 0.94420785), (1, 0.03373899), (2, 0.022053137)]
# For doc 203, corresponding topics & probability are [(0, 0.9087204), (1, 0.08746915)]
# For doc 204, corresponding topics & probability are [(0, 0.9087251), (1, 0.08746442)]
# For doc 205, corresponding topics & probability are [(0, 0.99501157)]
# For doc 206, corresponding topics & probability are [(0, 0.35119298), (1, 0.6326574), (2, 0.016149636)]
# For doc 207, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 208, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 209, corresponding topics & probability are [(1, 0.9695759), (2, 0.028373638)]
# For doc 210, corresponding topics & probability are [(0, 0.97999865), (1, 0.017673025)]
# For doc 211, corresponding topics & probability are [(0, 0.99204165)]
# For doc 212, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 213, corresponding topics & probability are [(2, 0.9956728)]
# For doc 214, corresponding topics & probability are [(2, 0.9960011)]
# For doc 215, corresponding topics & probability are [(2, 0.99600106)]
# For doc 216, corresponding topics & probability are [(2, 0.9960011)]
# For doc 217, corresponding topics & probability are [(2, 0.99600077)]
# For doc 218, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 219, corresponding topics & probability are [(2, 0.99471897)]
# For doc 220, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 221, corresponding topics & probability are [(2, 0.99567264)]
# For doc 222, corresponding topics & probability are [(0, 0.16872467), (1, 0.8201546), (2, 0.011120691)]
# For doc 223, corresponding topics & probability are [(0, 0.33612528), (1, 0.6602217)]
# For doc 224, corresponding topics & probability are [(0, 0.33527374), (1, 0.6613185)]
# For doc 225, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 226, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 227, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 228, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 229, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 230, corresponding topics & probability are [(0, 0.85751784), (1, 0.14047872)]
# For doc 231, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 232, corresponding topics & probability are [(0, 0.41317934), (1, 0.30592746), (2, 0.2808932)]
# For doc 233, corresponding topics & probability are [(0, 0.03603577), (1, 0.7921715), (2, 0.17179272)]
# For doc 234, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 235, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 236, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 237, corresponding topics & probability are [(0, 0.023128068), (1, 0.023502346), (2, 0.9533696)]
# For doc 238, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 239, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 240, corresponding topics & probability are [(0, 0.075127445), (1, 0.088064305), (2, 0.8368082)]
# For doc 241, corresponding topics & probability are [(0, 0.11265451), (1, 0.7762061), (2, 0.11113939)]
# For doc 242, corresponding topics & probability are [(0, 0.16678259), (1, 0.66642207), (2, 0.16679537)]
# For doc 243, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 244, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 245, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 246, corresponding topics & probability are [(2, 0.9960007)]
# For doc 247, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 248, corresponding topics & probability are [(0, 0.118065916), (1, 0.77073693), (2, 0.11119714)]
# For doc 249, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 250, corresponding topics & probability are [(2, 0.99575275)]
# For doc 251, corresponding topics & probability are [(2, 0.9957517)]
# For doc 252, corresponding topics & probability are [(2, 0.9956731)]
# For doc 253, corresponding topics & probability are [(2, 0.9956737)]
# For doc 254, corresponding topics & probability are [(0, 0.16870566), (1, 0.8201737), (2, 0.011120699)]
# For doc 255, corresponding topics & probability are [(1, 0.033204086), (2, 0.9634984)]
# For doc 256, corresponding topics & probability are [(2, 0.994773)]
# For doc 257, corresponding topics & probability are [(0, 0.33611688), (1, 0.66023004)]
# For doc 258, corresponding topics & probability are [(0, 0.9986394)]
# For doc 259, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 260, corresponding topics & probability are [(2, 0.99567276)]
# For doc 261, corresponding topics & probability are [(2, 0.99567264)]
# For doc 262, corresponding topics & probability are [(2, 0.9956725)]
# For doc 263, corresponding topics & probability are [(2, 0.9957527)]
# For doc 264, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 265, corresponding topics & probability are [(0, 0.8281682), (1, 0.087850735), (2, 0.08398109)]
# For doc 266, corresponding topics & probability are [(0, 0.33527744), (1, 0.6613148)]
# For doc 267, corresponding topics & probability are [(0, 0.9955701)]
# For doc 268, corresponding topics & probability are [(2, 0.9956725)]
# For doc 269, corresponding topics & probability are [(2, 0.9956736)]
# For doc 270, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 271, corresponding topics & probability are [(2, 0.994724)]
# For doc 272, corresponding topics & probability are [(2, 0.99600124)]
# For doc 273, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 274, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 275, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 276, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 277, corresponding topics & probability are [(1, 0.96676105), (2, 0.030278316)]
# For doc 278, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 279, corresponding topics & probability are [(2, 0.99472016)]
# For doc 280, corresponding topics & probability are [(0, 0.9954253)]
# For doc 281, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 282, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 283, corresponding topics & probability are [(2, 0.99600077)]
# For doc 284, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 285, corresponding topics & probability are [(0, 0.33612356), (1, 0.66022336)]
# For doc 286, corresponding topics & probability are [(2, 0.9956725)]
# For doc 287, corresponding topics & probability are [(2, 0.9956737)]
# For doc 288, corresponding topics & probability are [(2, 0.9947762)]
# For doc 289, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 290, corresponding topics & probability are [(2, 0.99600095)]
# For doc 291, corresponding topics & probability are [(2, 0.99600124)]
# For doc 292, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 293, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 294, corresponding topics & probability are [(0, 0.51035905), (1, 0.48458746)]
# For doc 295, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 296, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 297, corresponding topics & probability are [(0, 0.99094045)]
# For doc 298, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 299, corresponding topics & probability are [(0, 0.9909429)]
# For doc 300, corresponding topics & probability are [(1, 0.9927322)]
# For doc 301, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 302, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 303, corresponding topics & probability are [(0, 0.072979435), (1, 0.9223427)]
# For doc 304, corresponding topics & probability are [(0, 0.17918931), (1, 0.8165021)]
# For doc 305, corresponding topics & probability are [(0, 0.98826265)]
# For doc 306, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 307, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 308, corresponding topics & probability are [(0, 0.01233028), (1, 0.81019765), (2, 0.17747207)]
# For doc 309, corresponding topics & probability are [(1, 0.99273276)]
# For doc 310, corresponding topics & probability are [(0, 0.8204412), (1, 0.17091802)]
# For doc 311, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 312, corresponding topics & probability are [(0, 0.79860425), (1, 0.194944)]
# For doc 313, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 314, corresponding topics & probability are [(1, 0.992736)]
# For doc 315, corresponding topics & probability are [(1, 0.9927325)]
# For doc 316, corresponding topics & probability are [(1, 0.9927324)]
# For doc 317, corresponding topics & probability are [(0, 0.99506044)]
# For doc 318, corresponding topics & probability are [(0, 0.9948026)]
# For doc 319, corresponding topics & probability are [(0, 0.7358317), (1, 0.26076975)]
# For doc 320, corresponding topics & probability are [(0, 0.5972486), (1, 0.36080348), (2, 0.041947905)]
# For doc 321, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 322, corresponding topics & probability are [(0, 0.8487407), (1, 0.1444213)]
# For doc 323, corresponding topics & probability are [(0, 0.780382), (1, 0.21185459)]
# For doc 324, corresponding topics & probability are [(0, 0.8035699), (1, 0.18670881)]
# For doc 325, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 326, corresponding topics & probability are [(1, 0.957455), (2, 0.036843274)]
# For doc 327, corresponding topics & probability are [(0, 0.8158224), (1, 0.17219105), (2, 0.011986569)]
# For doc 328, corresponding topics & probability are [(0, 0.49275005), (1, 0.5036033)]
# For doc 329, corresponding topics & probability are [(0, 0.9933391)]
# For doc 330, corresponding topics & probability are [(0, 0.9948318)]
# For doc 331, corresponding topics & probability are [(0, 0.30186254), (1, 0.6906363)]
# For doc 332, corresponding topics & probability are [(0, 0.9461796), (1, 0.052428648)]
# For doc 333, corresponding topics & probability are [(0, 0.67000294), (1, 0.32874075)]
# For doc 334, corresponding topics & probability are [(0, 0.08104722), (1, 0.901761), (2, 0.017191807)]
# For doc 335, corresponding topics & probability are [(0, 0.5659155), (1, 0.4313272)]
# For doc 336, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 337, corresponding topics & probability are [(0, 0.9949995)]
# For doc 338, corresponding topics & probability are [(1, 0.99151295)]
# For doc 339, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 340, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 341, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 342, corresponding topics & probability are [(0, 0.19619381), (1, 0.8028623)]
# For doc 343, corresponding topics & probability are [(0, 0.9332178), (1, 0.06301931)]
# For doc 344, corresponding topics & probability are [(0, 0.324445), (1, 0.6743741)]
# For doc 345, corresponding topics & probability are [(0, 0.99703693)]
# For doc 346, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 347, corresponding topics & probability are [(0, 0.7457854), (1, 0.22657898), (2, 0.027635595)]
# For doc 348, corresponding topics & probability are [(0, 0.26843467), (1, 0.7291146)]
# For doc 349, corresponding topics & probability are [(0, 0.025960304), (1, 0.9509232), (2, 0.023116475)]
# For doc 350, corresponding topics & probability are [(0, 0.19559832), (1, 0.79132456), (2, 0.0130771035)]
# For doc 351, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 352, corresponding topics & probability are [(0, 0.19281474), (1, 0.8068621)]
# For doc 353, corresponding topics & probability are [(0, 0.15395321), (1, 0.838412)]
# For doc 354, corresponding topics & probability are [(0, 0.96659446), (1, 0.031132676)]
# For doc 355, corresponding topics & probability are [(0, 0.97163165), (1, 0.015349758), (2, 0.0130185485)]
# For doc 356, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 357, corresponding topics & probability are [(1, 0.9856498)]
# For doc 358, corresponding topics & probability are [(0, 0.025949674), (1, 0.9509339), (2, 0.023116445)]
# For doc 359, corresponding topics & probability are [(0, 0.025938585), (1, 0.950945), (2, 0.023116415)]
# For doc 360, corresponding topics & probability are [(0, 0.06729971), (1, 0.45689207), (2, 0.47580823)]
# For doc 361, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 362, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 363, corresponding topics & probability are [(0, 0.9014304), (1, 0.050856944), (2, 0.04771262)]
# For doc 364, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 365, corresponding topics & probability are [(0, 0.03810537), (1, 0.9426839), (2, 0.019210748)]
# For doc 366, corresponding topics & probability are [(0, 0.53228265), (1, 0.44735563), (2, 0.020361662)]
# For doc 367, corresponding topics & probability are [(0, 0.1590965), (1, 0.83995575)]
# For doc 368, corresponding topics & probability are [(0, 0.034153007), (1, 0.9617767)]
# For doc 369, corresponding topics & probability are [(1, 0.99614835)]
# For doc 370, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 371, corresponding topics & probability are [(0, 0.031254902), (1, 0.798611), (2, 0.17013417)]
# For doc 372, corresponding topics & probability are [(0, 0.9372622), (1, 0.032182794), (2, 0.030555017)]
# For doc 373, corresponding topics & probability are [(1, 0.95339006), (2, 0.04295098)]
# For doc 374, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 375, corresponding topics & probability are [(0, 0.7542844), (1, 0.22072065), (2, 0.024994945)]
# For doc 376, corresponding topics & probability are [(1, 0.95955473), (2, 0.036858797)]
# For doc 377, corresponding topics & probability are [(1, 0.99521255)]
# For doc 378, corresponding topics & probability are [(0, 0.978028), (1, 0.01920658)]
# For doc 379, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 380, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 381, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 382, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 383, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 384, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 385, corresponding topics & probability are [(0, 0.9947238)]
# For doc 386, corresponding topics & probability are [(1, 0.9941298)]
# For doc 387, corresponding topics & probability are [(0, 0.05750451), (1, 0.8439219), (2, 0.098573625)]
# For doc 388, corresponding topics & probability are [(0, 0.9493112), (1, 0.02383152), (2, 0.026857309)]
# For doc 389, corresponding topics & probability are [(0, 0.18955609), (1, 0.7795037), (2, 0.03094021)]
# For doc 390, corresponding topics & probability are [(0, 0.66403127), (1, 0.33274648)]
# For doc 391, corresponding topics & probability are [(0, 0.24324866), (1, 0.7562188)]
# For doc 392, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 393, corresponding topics & probability are [(1, 0.90826154), (2, 0.08747327)]
# For doc 394, corresponding topics & probability are [(0, 0.796641), (1, 0.20049961)]
# For doc 395, corresponding topics & probability are [(1, 0.99273354)]
# For doc 396, corresponding topics & probability are [(1, 0.96163), (2, 0.03215288)]
# For doc 397, corresponding topics & probability are [(1, 0.9717718), (2, 0.025037559)]
# For doc 398, corresponding topics & probability are [(0, 0.06030096), (1, 0.87509006), (2, 0.06460896)]
# For doc 399, corresponding topics & probability are [(0, 0.9880179)]
# For doc 400, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 401, corresponding topics & probability are [(1, 0.9874514), (2, 0.010690697)]
# For doc 402, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 403, corresponding topics & probability are [(0, 0.98826385)]
# For doc 404, corresponding topics & probability are [(1, 0.9201873), (2, 0.07764222)]
# For doc 405, corresponding topics & probability are [(0, 0.82302487), (1, 0.17311227)]
# For doc 406, corresponding topics & probability are [(0, 0.9955352)]
# For doc 407, corresponding topics & probability are [(1, 0.95955485), (2, 0.036858678)]
# For doc 408, corresponding topics & probability are [(0, 0.9797494), (1, 0.011204413)]
# For doc 409, corresponding topics & probability are [(0, 0.8876557), (2, 0.103637174)]
# For doc 410, corresponding topics & probability are [(0, 0.82303566), (1, 0.17310151)]
# For doc 411, corresponding topics & probability are [(0, 0.2860281), (1, 0.6812187), (2, 0.032753255)]
# For doc 412, corresponding topics & probability are [(0, 0.5448597), (1, 0.45018175)]
# For doc 413, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 414, corresponding topics & probability are [(0, 0.45319968), (1, 0.542652)]
# For doc 415, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 416, corresponding topics & probability are [(0, 0.24392638), (1, 0.71392953), (2, 0.042144146)]
# For doc 417, corresponding topics & probability are [(0, 0.24381496), (1, 0.714041), (2, 0.04214404)]
# For doc 418, corresponding topics & probability are [(0, 0.9909513)]
# For doc 419, corresponding topics & probability are [(0, 0.6760123), (1, 0.32292628)]
# For doc 420, corresponding topics & probability are [(0, 0.9944586)]
# For doc 421, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 422, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 423, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 424, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 425, corresponding topics & probability are [(0, 0.98814714)]
# For doc 426, corresponding topics & probability are [(0, 0.88058174), (1, 0.11173032)]
# For doc 427, corresponding topics & probability are [(0, 0.9947943)]
# For doc 428, corresponding topics & probability are [(0, 0.95490766), (1, 0.022816557), (2, 0.022275764)]
# For doc 429, corresponding topics & probability are [(0, 0.97860324), (1, 0.0104809245), (2, 0.010915779)]
# For doc 430, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 431, corresponding topics & probability are [(0, 0.8370205), (1, 0.1612285)]
# For doc 432, corresponding topics & probability are [(0, 0.99536884)]
# For doc 433, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 434, corresponding topics & probability are [(0, 0.9715423), (1, 0.026817417)]
# For doc 435, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 436, corresponding topics & probability are [(0, 0.8549845), (1, 0.14360309)]
# For doc 437, corresponding topics & probability are [(0, 0.14829355), (1, 0.8475927)]
# For doc 438, corresponding topics & probability are [(0, 0.99428827)]
# For doc 439, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 440, corresponding topics & probability are [(0, 0.30939353), (1, 0.688206)]
# For doc 441, corresponding topics & probability are [(0, 0.97467655), (1, 0.010943444), (2, 0.014380049)]
# For doc 442, corresponding topics & probability are [(0, 0.99082005)]
# For doc 443, corresponding topics & probability are [(0, 0.9960642)]
# For doc 444, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 445, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 446, corresponding topics & probability are [(0, 0.6252822), (1, 0.34680924), (2, 0.02790849)]
# For doc 447, corresponding topics & probability are [(1, 0.9631719), (2, 0.030886946)]
# For doc 448, corresponding topics & probability are [(0, 0.011954238), (1, 0.97684085), (2, 0.011204899)]
# For doc 449, corresponding topics & probability are [(0, 0.40637782), (1, 0.5903759)]
# For doc 450, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 451, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 452, corresponding topics & probability are [(0, 0.97062445), (1, 0.015313582), (2, 0.014061929)]
# For doc 453, corresponding topics & probability are [(1, 0.9595545), (2, 0.036859047)]
# For doc 454, corresponding topics & probability are [(0, 0.996142)]
# For doc 455, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 456, corresponding topics & probability are [(0, 0.99132603)]
# For doc 457, corresponding topics & probability are [(0, 0.841659), (1, 0.15512668)]
# For doc 458, corresponding topics & probability are [(0, 0.54884666), (1, 0.3677462), (2, 0.08340716)]
# For doc 459, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 460, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 461, corresponding topics & probability are [(0, 0.99439794)]
# For doc 462, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 463, corresponding topics & probability are [(0, 0.8474383), (1, 0.10890934), (2, 0.043652344)]
# For doc 464, corresponding topics & probability are [(0, 0.4119688), (1, 0.5793024)]
# For doc 465, corresponding topics & probability are [(0, 0.99290043)]
# For doc 466, corresponding topics & probability are [(1, 0.99496365)]
# For doc 467, corresponding topics & probability are [(1, 0.9949632)]
# For doc 468, corresponding topics & probability are [(0, 0.26704186), (1, 0.6984494), (2, 0.0345088)]
# For doc 469, corresponding topics & probability are [(0, 0.29944652), (1, 0.69963944)]
# For doc 470, corresponding topics & probability are [(0, 0.95502263), (2, 0.04268542)]
# For doc 471, corresponding topics & probability are [(0, 0.9550241), (2, 0.042685483)]
# For doc 472, corresponding topics & probability are [(0, 0.9563551), (2, 0.041608002)]
# For doc 473, corresponding topics & probability are [(0, 0.11199635), (1, 0.8452957), (2, 0.042707946)]
# For doc 474, corresponding topics & probability are [(0, 0.41529766), (1, 0.56791073), (2, 0.016791651)]
# For doc 475, corresponding topics & probability are [(0, 0.7578655), (1, 0.21665812), (2, 0.025476417)]
# For doc 476, corresponding topics & probability are [(0, 0.8755344), (1, 0.12315325)]
# For doc 477, corresponding topics & probability are [(0, 0.44991848), (1, 0.5459449)]
# For doc 478, corresponding topics & probability are [(0, 0.992576)]
# For doc 479, corresponding topics & probability are [(0, 0.06030224), (1, 0.8750887), (2, 0.06460911)]
# For doc 480, corresponding topics & probability are [(0, 0.85524756), (1, 0.11300031), (2, 0.03175216)]
# For doc 481, corresponding topics & probability are [(0, 0.056618787), (1, 0.74684423), (2, 0.19653694)]
# For doc 482, corresponding topics & probability are [(0, 0.43965358), (1, 0.5594735)]
# For doc 483, corresponding topics & probability are [(0, 0.34487727), (1, 0.6417312), (2, 0.013391564)]
# For doc 484, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 485, corresponding topics & probability are [(0, 0.7808565), (1, 0.20991483)]
# For doc 486, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 487, corresponding topics & probability are [(0, 0.8642834), (1, 0.13255635)]
# For doc 488, corresponding topics & probability are [(0, 0.99154645)]
# For doc 489, corresponding topics & probability are [(0, 0.7457948), (1, 0.20562026), (2, 0.048584964)]
# For doc 490, corresponding topics & probability are [(0, 0.06546481), (1, 0.9327234)]
# For doc 491, corresponding topics & probability are [(0, 0.4257231), (1, 0.57036644)]
# For doc 492, corresponding topics & probability are [(0, 0.7663563), (1, 0.23060702)]
# For doc 493, corresponding topics & probability are [(0, 0.44378987), (1, 0.55021185)]
# For doc 494, corresponding topics & probability are [(0, 0.9372829), (1, 0.032162145), (2, 0.030554986)]
# For doc 495, corresponding topics & probability are [(0, 0.052316673), (1, 0.9053121), (2, 0.04237126)]
# For doc 496, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 497, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 498, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 499, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 500, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 501, corresponding topics & probability are [(0, 0.6963543), (1, 0.2991923)]
# For doc 502, corresponding topics & probability are [(0, 0.9886046)]
# For doc 503, corresponding topics & probability are [(0, 0.42796123), (1, 0.52065986), (2, 0.051378895)]
# For doc 504, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 505, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 506, corresponding topics & probability are [(0, 0.013858813), (1, 0.97332424), (2, 0.012816964)]
# For doc 507, corresponding topics & probability are [(1, 0.95936954), (2, 0.03667197)]
# For doc 508, corresponding topics & probability are [(0, 0.024922341), (1, 0.8596517), (2, 0.11542599)]
# For doc 509, corresponding topics & probability are [(0, 0.97388715), (1, 0.013646398), (2, 0.012466457)]
# For doc 510, corresponding topics & probability are [(0, 0.6963573), (1, 0.29918936)]
# For doc 511, corresponding topics & probability are [(0, 0.99553543)]
# For doc 512, corresponding topics & probability are [(0, 0.90733), (1, 0.010173827), (2, 0.08249625)]
# For doc 513, corresponding topics & probability are [(0, 0.3766403), (1, 0.5856235), (2, 0.037736252)]
# For doc 514, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 515, corresponding topics & probability are [(0, 0.9896764)]
# For doc 516, corresponding topics & probability are [(0, 0.6664251), (1, 0.32918197)]
# For doc 517, corresponding topics & probability are [(0, 0.31601933), (1, 0.68224007)]
# For doc 518, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 519, corresponding topics & probability are [(0, 0.98860085)]
# For doc 520, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 521, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# ...
# For doc 2817, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2818, corresponding topics & probability are [(0, 0.6807714), (1, 0.31297565)]
# For doc 2819, corresponding topics & probability are [(0, 0.5868507), (1, 0.4108829)]
# For doc 2820, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2821, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2822, corresponding topics & probability are [(0, 0.97955155), (2, 0.016460415)]
# For doc 2823, corresponding topics & probability are [(0, 0.5732166), (1, 0.41820768)]
# For doc 2824, corresponding topics & probability are [(0, 0.8937088), (1, 0.08551615), (2, 0.020775009)]
# For doc 2825, corresponding topics & probability are [(0, 0.9895279)]
# For doc 2826, corresponding topics & probability are [(0, 0.1687324), (1, 0.8201469), (2, 0.011120691)]
# For doc 2827, corresponding topics & probability are [(0, 0.77951145), (1, 0.2100617), (2, 0.010426869)]
# For doc 2828, corresponding topics & probability are [(0, 0.058675926), (1, 0.93879133)]
# For doc 2829, corresponding topics & probability are [(0, 0.27258134), (1, 0.72259974)]
# For doc 2830, corresponding topics & probability are [(0, 0.94701594), (1, 0.052033894)]
# For doc 2831, corresponding topics & probability are [(0, 0.9908058)]
# For doc 2832, corresponding topics & probability are [(0, 0.9714114), (1, 0.013967021), (2, 0.01462161)]
# For doc 2833, corresponding topics & probability are [(0, 0.4432669), (1, 0.55164486)]
# For doc 2834, corresponding topics & probability are [(0, 0.96893233), (1, 0.015896238), (2, 0.015171366)]
# For doc 2835, corresponding topics & probability are [(1, 0.98862934)]
# For doc 2836, corresponding topics & probability are [(1, 0.90544105), (2, 0.09186908)]
# For doc 2837, corresponding topics & probability are [(0, 0.93728274), (1, 0.032162316), (2, 0.030554986)]
# For doc 2838, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2839, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2840, corresponding topics & probability are [(0, 0.9725955), (2, 0.026362343)]
# For doc 2841, corresponding topics & probability are [(0, 0.9022038), (1, 0.09465977)]
# For doc 2842, corresponding topics & probability are [(0, 0.941852), (1, 0.03368773), (2, 0.024460271)]
# For doc 2843, corresponding topics & probability are [(0, 0.07810554), (1, 0.9194231)]
# For doc 2844, corresponding topics & probability are [(0, 0.5706605), (1, 0.4155694), (2, 0.013770096)]
# For doc 2845, corresponding topics & probability are [(0, 0.9725952), (2, 0.02636209)]
# For doc 2846, corresponding topics & probability are [(0, 0.792588), (1, 0.16864571), (2, 0.038766317)]
# For doc 2847, corresponding topics & probability are [(0, 0.9881853)]
# For doc 2848, corresponding topics & probability are [(0, 0.98984355)]
# For doc 2849, corresponding topics & probability are [(1, 0.9457286), (2, 0.052789982)]
# For doc 2850, corresponding topics & probability are [(1, 0.8321784), (2, 0.16623534)]
# For doc 2851, corresponding topics & probability are [(0, 0.85133845), (1, 0.1310666), (2, 0.017594956)]
# For doc 2852, corresponding topics & probability are [(0, 0.9940128)]
# For doc 2853, corresponding topics & probability are [(0, 0.99437237)]
# For doc 2854, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2855, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2856, corresponding topics & probability are [(0, 0.9978055)]
# For doc 2857, corresponding topics & probability are [(0, 0.99292487)]
# For doc 2858, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2859, corresponding topics & probability are [(1, 0.9894021)]
# For doc 2860, corresponding topics & probability are [(0, 0.99694294)]
# For doc 2861, corresponding topics & probability are [(0, 0.73026615), (1, 0.24099985), (2, 0.028733972)]
# For doc 2862, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2863, corresponding topics & probability are [(0, 0.56856036), (1, 0.29349047), (2, 0.1379492)]
# For doc 2864, corresponding topics & probability are [(0, 0.80171424), (1, 0.07499071), (2, 0.12329508)]
# For doc 2865, corresponding topics & probability are [(0, 0.9372616), (1, 0.032183442), (2, 0.030555017)]
# For doc 2866, corresponding topics & probability are [(0, 0.9372824), (1, 0.032162625), (2, 0.030554982)]
# For doc 2867, corresponding topics & probability are [(0, 0.99412596)]
# For doc 2868, corresponding topics & probability are [(0, 0.99180025)]
# For doc 2869, corresponding topics & probability are [(0, 0.9406272), (1, 0.022540415), (2, 0.036832348)]
# For doc 2870, corresponding topics & probability are [(0, 0.038111024), (1, 0.94267815), (2, 0.019210799)]
# For doc 2871, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2872, corresponding topics & probability are [(0, 0.7004691), (1, 0.29551065)]
# For doc 2873, corresponding topics & probability are [(0, 0.02204771), (1, 0.65650713), (2, 0.3214452)]
# For doc 2874, corresponding topics & probability are [(0, 0.18853243), (1, 0.8042027)]
# For doc 2875, corresponding topics & probability are [(0, 0.9937852)]
# For doc 2876, corresponding topics & probability are [(0, 0.20909457), (1, 0.68581873), (2, 0.10508669)]
# For doc 2877, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2878, corresponding topics & probability are [(0, 0.93668985), (1, 0.059348002)]
# For doc 2879, corresponding topics & probability are [(0, 0.88719755), (1, 0.10728781)]
# For doc 2880, corresponding topics & probability are [(0, 0.9937858)]
# For doc 2881, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2882, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2883, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2884, corresponding topics & probability are [(0, 0.95095146), (1, 0.025096035), (2, 0.023952547)]
# For doc 2885, corresponding topics & probability are [(0, 0.99201494)]
# For doc 2886, corresponding topics & probability are [(0, 0.75424093), (1, 0.22076471), (2, 0.02499434)]
# For doc 2887, corresponding topics & probability are [(0, 0.994151)]
# For doc 2888, corresponding topics & probability are [(0, 0.91420835), (1, 0.044036943), (2, 0.041754644)]
# For doc 2889, corresponding topics & probability are [(1, 0.97889555), (2, 0.019104395)]
# For doc 2890, corresponding topics & probability are [(0, 0.94034106), (1, 0.016531656), (2, 0.04312726)]
# For doc 2891, corresponding topics & probability are [(0, 0.99267393)]
# For doc 2892, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2893, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2894, corresponding topics & probability are [(1, 0.99487627)]
# For doc 2895, corresponding topics & probability are [(0, 0.6333036), (1, 0.36256424)]
# For doc 2896, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2897, corresponding topics & probability are [(0, 0.9960493)]
# For doc 2898, corresponding topics & probability are [(0, 0.9946543)]
# For doc 2899, corresponding topics & probability are [(0, 0.99612284)]
# For doc 2900, corresponding topics & probability are [(0, 0.6331949), (1, 0.36193365)]
# For doc 2901, corresponding topics & probability are [(0, 0.24565664), (1, 0.74651706)]
# For doc 2902, corresponding topics & probability are [(1, 0.9061561), (2, 0.08891744)]
# For doc 2903, corresponding topics & probability are [(0, 0.43195665), (1, 0.56403124)]
# For doc 2904, corresponding topics & probability are [(0, 0.15690579), (1, 0.8303048), (2, 0.0127893975)]
# For doc 2905, corresponding topics & probability are [(0, 0.99415076)]
# For doc 2906, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2907, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2908, corresponding topics & probability are [(0, 0.015935319), (1, 0.92009395), (2, 0.06397072)]
# For doc 2909, corresponding topics & probability are [(0, 0.99658656)]
# For doc 2910, corresponding topics & probability are [(0, 0.9960619)]
# For doc 2911, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2912, corresponding topics & probability are [(0, 0.43101263), (1, 0.4841727), (2, 0.08481466)]
# For doc 2913, corresponding topics & probability are [(0, 0.16873285), (1, 0.8201465), (2, 0.01112069)]
# For doc 2914, corresponding topics & probability are [(0, 0.8049113), (1, 0.19242372)]
# For doc 2915, corresponding topics & probability are [(0, 0.9946496)]
# For doc 2916, corresponding topics & probability are [(0, 0.9934416)]
# For doc 2917, corresponding topics & probability are [(0, 0.51203716), (1, 0.48391008)]
# For doc 2918, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2919, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2920, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2921, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2922, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2923, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2924, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2925, corresponding topics & probability are [(0, 0.24928713), (1, 0.74822736)]
# For doc 2926, corresponding topics & probability are [(0, 0.9142176), (1, 0.044035695), (2, 0.04174674)]
# For doc 2927, corresponding topics & probability are [(0, 0.91422606), (1, 0.044019286), (2, 0.041754633)]
# For doc 2928, corresponding topics & probability are [(0, 0.9056534), (1, 0.052613556), (2, 0.041733027)]
# For doc 2929, corresponding topics & probability are [(0, 0.9128278), (1, 0.045437742), (2, 0.041734517)]
# For doc 2930, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2931, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2932, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2933, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2934, corresponding topics & probability are [(0, 0.99131805)]
# For doc 2935, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2936, corresponding topics & probability are [(1, 0.94898707), (2, 0.04866917)]
# For doc 2937, corresponding topics & probability are [(0, 0.32533044), (1, 0.5495713), (2, 0.12509826)]
# For doc 2938, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2939, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2940, corresponding topics & probability are [(0, 0.060572676), (1, 0.9365031)]
# For doc 2941, corresponding topics & probability are [(0, 0.77888817), (1, 0.21482249)]
# For doc 2942, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2943, corresponding topics & probability are [(0, 0.53226125), (1, 0.4473775), (2, 0.020361267)]
# For doc 2944, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2945, corresponding topics & probability are [(0, 0.99534595)]
# For doc 2946, corresponding topics & probability are [(0, 0.9898271)]
# For doc 2947, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2948, corresponding topics & probability are [(0, 0.086746715), (1, 0.9122446)]
# For doc 2949, corresponding topics & probability are [(0, 0.937264), (1, 0.03218095), (2, 0.030555015)]
# For doc 2950, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2951, corresponding topics & probability are [(0, 0.93726057), (1, 0.032184437), (2, 0.030555017)]
# For doc 2952, corresponding topics & probability are [(0, 0.9427608), (1, 0.05451174)]
# For doc 2953, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2954, corresponding topics & probability are [(0, 0.73317426), (1, 0.042630628), (2, 0.22419512)]
# For doc 2955, corresponding topics & probability are [(0, 0.99267966)]
# For doc 2956, corresponding topics & probability are [(0, 0.9125547), (1, 0.04569082), (2, 0.04175444)]
# For doc 2957, corresponding topics & probability are [(0, 0.18364279), (1, 0.76275206), (2, 0.05360515)]
# For doc 2958, corresponding topics & probability are [(0, 0.12148745), (1, 0.864225), (2, 0.014287546)]
# For doc 2959, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2960, corresponding topics & probability are [(1, 0.9888709)]
# For doc 2961, corresponding topics & probability are [(1, 0.9888632)]
# For doc 2962, corresponding topics & probability are [(0, 0.8865708), (1, 0.02363774), (2, 0.08979143)]
# For doc 2963, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2964, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2965, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2966, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2967, corresponding topics & probability are [(0, 0.9921163)]
# For doc 2968, corresponding topics & probability are [(1, 0.9948764)]
# For doc 2969, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2970, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2971, corresponding topics & probability are [(0, 0.9954965)]
# For doc 2972, corresponding topics & probability are [(0, 0.9366577), (1, 0.011841883), (2, 0.051500376)]
# For doc 2973, corresponding topics & probability are [(0, 0.99322593)]
# For doc 2974, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2975, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2976, corresponding topics & probability are [(0, 0.99434495)]
# For doc 2977, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2978, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2979, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2980, corresponding topics & probability are [(0, 0.99239033)]
# For doc 2981, corresponding topics & probability are [(0, 0.99239105)]
# For doc 2982, corresponding topics & probability are [(0, 0.40723446), (1, 0.5807297), (2, 0.012035794)]
# For doc 2983, corresponding topics & probability are [(0, 0.97896814), (2, 0.019129751)]
# For doc 2984, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2985, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2986, corresponding topics & probability are [(0, 0.33333334), (1, 0.33333334), (2, 0.33333334)]
# For doc 2987, corresponding topics & probability are [(0, 0.9265407), (1, 0.03842094), (2, 0.035038352)]

# %% [markdown]
# ### Visualize topics-keyword
#
# ##### Notation
# - Each bubble on the left-hand side plot represents a topic. The larger the bubble, the more prevalent is that topic.
# - A good topic model will have fairly big, non-overlapping bubbles scattered throughout the chart instead of being clustered in one quadrant.
# - A model with too many topics, will typically have many overlaps, small sized bubbles clustered in one region of the chart.

# %%
# Visualize the topics
from pyLDAvis import gensim as pyLDAvis_gensim
import pyLDAvis
pyLDAvis.enable_notebook()
vis = pyLDAvis_gensim.prepare(ldamodel, corpus, dictionary)
vis
# Out:
# /Users/zili/anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.187849  0.107491       1        1  34.504910
# 2      0.303489  0.018519       2        1  34.376602
# 1     -0.115639 -0.126010       3        1  31.118488, topic_info=     Category         Freq      Term        Total  loglift  logprob
# term
# 139   Default  3193.000000      hous  3193.000000  30.0000  30.0000
# 2036  Default  2245.000000     trump  2245.000000  29.0000  29.0000
# 2783  Default  1723.000000   speaker  1723.000000  28.0000  28.0000
# 3346  Default  1701.000000    pelosi  1701.000000  27.0000  27.0000
# 804   Default  2366.000000  democrat  2366.000000  26.0000  26.0000
# 398   Default  1351.000000  congress  1351.000000  25.0000  25.0000
# 27    Default  2493.000000    energi  2493.000000  24.0000  24.0000
# 976   Default  1992.000000    govern  1992.000000  23.0000  23.0000
# 83    Default  1052.000000   compani  1052.000000  22.0000  22.0000
# 889   Default  1361.000000    leader  1361.000000  21.0000  21.0000
# 172   Default   790.000000    market   790.000000  20.0000  20.0000
# 1858  Default   800.000000      wall   800.000000  19.0000  19.0000
# 261   Default   821.000000     share   821.000000  18.0000  18.0000
# 3343  Default   816.000000     white   816.000000  17.0000  17.0000
# 3335  Default   988.000000     senat   988.000000  16.0000  16.0000
# 13    Default   903.000000    climat   903.000000  15.0000  15.0000
# 148   Default  4185.000000       new  4185.000000  14.0000  14.0000
# 3025  Default   668.000000    border   668.000000  13.0000  13.0000
# 2194  Default   839.000000     parti   839.000000  12.0000  12.0000
# 1336  Default   916.000000    return   916.000000  11.0000  11.0000
# 920   Default  1624.000000         —  1624.000000  10.0000  10.0000
# 3336  Default   617.000000  shutdown   617.000000   9.0000   9.0000
# 127   Default  1105.000000    demand  1105.000000   8.0000   8.0000
# 2310  Default   710.000000   histori   710.000000   7.0000   7.0000
# 1329  Default   609.000000     readi   609.000000   6.0000   6.0000
# 2460  Default   580.000000     nanci   580.000000   5.0000   5.0000
# 102   Default   931.000000     renew   931.000000   4.0000   4.0000
# 3082  Default   631.000000       rep   631.000000   3.0000   3.0000
# 65    Default   890.000000     solar   890.000000   2.0000   2.0000
# 3325  Default   537.000000     minor   537.000000   1.0000   1.0000
# ...       ...          ...       ...          ...      ...      ...
# 1697   Topic3   289.836761       tax   393.743988   0.8610  -5.7538
# 978    Topic3   190.110229       job   235.239059   0.9544  -6.1755
# 703    Topic3   208.363785     board   265.185516   0.9262  -6.0839
# 104    Topic3   878.299377      said  1725.583008   0.4920  -4.6452
# 833    Topic3   210.181183     polit   271.838623   0.9101  -6.0752
# 1199   Topic3   180.648163    health   223.056595   0.9565  -6.2266
# 60     Topic3   272.388153    public   409.040955   0.7608  -5.8159
# 711    Topic3   246.253616      deal   359.739258   0.7884  -5.9168
# 165    Topic3   558.145996      year  1507.134766   0.1740  -5.0985
# 148    Topic3  1011.914062       new  4185.867188  -0.2525  -4.5035
# 665    Topic3   165.407150    counti   203.381989   0.9607  -6.3147
# 482    Topic3   413.589874      work  1047.625244   0.2380  -5.3983
# 560    Topic3   196.381363       way   277.965759   0.8199  -6.1431
# 982    Topic3   259.922211      like   473.710693   0.5672  -5.8628
# 1631   Topic3   178.697693   pipelin   236.662872   0.8864  -6.2374
# 367    Topic3   219.473602    nation   362.883118   0.6645  -6.0319
# 454    Topic3   338.577057      plan   912.831055   0.1756  -5.5984
# 54     Topic3   270.807800       one   580.609375   0.4047  -5.8217
# 27     Topic3   496.960876    energi  2493.924561  -0.4457  -5.2146
# 247    Topic3   312.989594     offic   969.814087   0.0364  -5.6770
# 330    Topic3   254.808655        ga   551.206909   0.3958  -5.8826
# 40     Topic3   277.768494    includ   896.163025  -0.0040  -5.7964
# 1518   Topic3   210.713669    carbon   348.760834   0.6635  -6.0726
# 441    Topic3   215.256012      need   407.419922   0.5294  -6.0513
# 920    Topic3   265.653656         —  1624.668213  -0.6435  -5.8409
# 804    Topic3   279.681488  democrat  2366.444336  -0.9681  -5.7895
# 457    Topic3   234.399994   project   721.276428   0.0434  -5.9661
# 418    Topic3   239.110779     first  1325.565918  -0.5453  -5.9462
# 477    Topic3   219.308716       use   487.897308   0.3677  -6.0327
# 976    Topic3   240.698776    govern  1992.935913  -0.9464  -5.9396
#
# [240 rows x 6 columns], token_table=       Topic      Freq      Term
# term
# 12116      1  0.989241        CC
# 795        3  0.992889        Fe
# 2911       1  0.997216        MW
# 1025       1  0.990251    acquir
# 569        1  0.846411     addit
# 569        3  0.152419     addit
# 4451       3  0.976856   alaskan
# 5          1  0.594394      also
# 5          2  0.001968      also
# 5          3  0.405448      also
# 2503       2  0.995475       aoc
# 663        1  0.985742  approxim
# 1066       1  0.121400      area
# 1066       3  0.872927      area
# 385        1  0.995530     asset
# 2257       3  0.986185    atlant
# 864        3  0.987108       ban
# 703        1  0.211173     board
# 703        3  0.784357     board
# 3025       1  0.002990    border
# 3025       2  0.994240    border
# 3025       3  0.001495    border
# 7583       2  0.998431   broadli
# 3357       3  0.996397        bu
# 12124      1  0.989241    byncsa
# 315        1  0.987301     capac
# 315        3  0.006953     capac
# 1518       1  0.395687    carbon
# 1518       3  0.604999    carbon
# 1407       3  0.996806     carri
# ...      ...       ...       ...
# 1454       2  0.930453     voter
# 1454       3  0.068392     voter
# 1858       1  0.007499      wall
# 1858       2  0.987384      wall
# 1858       3  0.004999      wall
# 773        1  0.043719      want
# 773        3  0.950898      want
# 560        1  0.291403       way
# 560        3  0.705123       way
# 3343       2  0.976464     white
# 3343       3  0.023278     white
# 109        1  0.736849      wind
# 109        2  0.178173      wind
# 109        3  0.084556      wind
# 482        1  0.093545      work
# 482        2  0.511633      work
# 482        3  0.395179      work
# 1583       1  0.994136     worth
# 1022       1  0.174731     would
# 1022       2  0.014561     would
# 1022       3  0.809586     would
# 165        1  0.356969      year
# 165        2  0.272703      year
# 165        3  0.370239      year
# 9173       2  0.998400    yorker
# 10976      3  0.988555    zeller
# 920        1  0.060320         —
# 920        2  0.776158         —
# 920        3  0.163726         —
# 1059       1  0.983363     “buy”
#
# [350 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 2])

# %% [markdown]
# ### Find the optimal number of topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Func:
        Compute c_v coherence for various number of topics
    Input:
        dictionary : Gensim dictionary
        corpus : Gensim corpus
        texts : List of input texts
        limit : Max num of topics
    Returns:
        model_list : List of LDA topic models
        coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus, num_topics=num_topics, id2word = dictionary)
#         model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=textsProcessed, start=2, limit=40, step=6)
# Out:
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
# ...
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /Users/zili/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)

# %%
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# # Part 3: Modulize

# %%
from gensim import corpora, models
import gensim
from gensim.models import CoherenceModel
from pyLDAvis import gensim as pyLDAvis_gensim
import pyLDAvis

class LDA:
    def __init__(self,texts,num_topics=3):
        ### input texts: list of texts eg: [["jason","while"],["bay","wheel"]]
        self.texts = texts
        self.dictionary = corpora.Dictionary(texts)
        self.corpus = [self.dictionary.doc2bow(text) for text in texts]
        
        self.ldamodel = gensim.models.ldamodel.LdaModel(self.corpus, num_topics=num_topics, id2word = self.dictionary, passes=20)
        
    def get_topics(self,num_topics=3,num_words=5):
        topics = self.ldamodel.print_topics(num_topics=num_topics, num_words=num_words)
        print(f"topics: {topics}")
    def get_doc_topics(self,docId=0):
        tmpTopic = ldamodel[corpus[docId]]
        print(f"For doc {docId}, corresponding topics & probability are {tmpTopic}")
        return tmpTopic
    
    def get_perplexity(self):
        return self.ldamodel.log_perplexity(self.corpus)  # a measure of how good the model is. lower the better.

    def get_coherence(self):
        # Compute Coherence Score
        coherence_model_lda = CoherenceModel(model=self.ldamodel, texts=self.texts, dictionary=self.dictionary, coherence='c_v')
        coherence_lda = coherence_model_lda.get_coherence()
        print('\nCoherence Score: ', coherence_lda)
        return self.coherence_lda

    def plot(self):
        # Visualize the topics
        pyLDAvis.enable_notebook()
        vis = pyLDAvis_gensim.prepare(self.ldamodel,self.corpus, self.dictionary)
        return vis
